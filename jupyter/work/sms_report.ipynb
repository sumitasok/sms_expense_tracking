# %%
from pymongo import MongoClient
import os
import bson

def mongoCollection(connstr, db, collection):
    client = MongoClient(connstr)
    db = client[db]
    return db[collection]

import re
import datetime

collection = mongoCollection(os.environ.get('MONGODB_CONN_STR'), 'smsinfo', 'transactions')

hdfcCreditCardInterpreterFormatStr = '%Y-%m-%d:%H:%M:%S'

# ALERT: You've spent Rs.5605.00  on CREDIT Card xx3690 at AARKITHA on 2020-02-22:12:09:36.Avl bal - Rs.286107.00, curr o/s - Rs.13893.00.Not you? Call 18002586161.
def hdfcCreditCardInterpreter(txn):
    x = re.search("ALERT: You\'ve spent Rs.([0-9.]+)\s+on\s+([a-zA-Z0-9\s._]+)? on (\d{4}-\d{2}-\d{2}:\d{2}:\d{2}:\d{2}).Avl bal - Rs.([0-9.]+), curr o\/s - Rs.([0-9]+.[0-9]+).", txn)
    return {
        'expense_amount': float(x.group(1)),
        'payment_mode': x.group(2).split('at', 1)[0].strip(),
        'merchant': x.group(2).split('at', 1)[1].strip(),
        'datetime': datetime.datetime.strptime(x.group(3), hdfcCreditCardInterpreterFormatStr),
        'available_balance': float(x.group(4)),
        'outstanding_amount': float(x.group(5))
    } if x != None else {}

# ALERT:You've spent Rs.428.00 on CREDIT Card xx3690 at FRESHTOH3631510 in BANGALORE on 2020-02-15:16:46:51.Not you?Call 18002586161.
def hdfcCreditCardInterpreter2(txn):
    x = re.search("ALERT:You\'ve spent Rs.([0-9.]+)\s+on\s+([a-zA-Z0-9\s._//]+)? on (\d{4}-\d{2}-\d{2}:\d{2}:\d{2}:\d{2}).", txn)
    return {
        'expense_amount': float(x.group(1)),
        'payment_mode': x.group(2).split('at', 1)[0].strip(),
        'merchant': x.group(2).split('at', 1)[1].strip(),
        'datetime': datetime.datetime.strptime(x.group(3), hdfcCreditCardInterpreterFormatStr)
    } if x != None else {}

# ALERT:You've spent Rs.3638.00 via Debit Card xx6504 at www.lenskart.c on 2019-01-14:20:29:59.Avl Bal Rs.264666.51.Not you?Call 18002586161.
def hdfcCreditCardInterpreterVia(txn):
    x = re.search("ALERT:You\'ve spent Rs.([0-9.]+)\s+via\s+([a-zA-Z0-9\s._//]+)? on (\d{4}-\d{2}-\d{2}:\d{2}:\d{2}:\d{2}).", txn)
    return {
        'expense_amount': float(x.group(1)),
        'payment_mode': x.group(2).split('at', 1)[0].strip(),
        'merchant': x.group(2).split('at', 1)[1].strip(),
        'datetime': datetime.datetime.strptime(x.group(3), hdfcCreditCardInterpreterFormatStr)
    } if x != None else {}

from IPython.display import HTML, display
import tabulate

def extract_transactions(i):
    keys = ['expense_amount', 'payment_mode', 'merchant', 'datetime', 'category', 'sub_category']
#     return list(i[1]['transaction'].values()) + [str(i[1]['_id'])]
    return [i[1]['transaction'].get(key, None) for key in keys]

def mark_duplicate(collection, _id):
    result = collection.update_one({'_id': bson.ObjectId(_id)}, {'$set' : {'status': {'duplicate': True}}})
    print('success' if result.modified_count == 1 else 'failed')
    return result

def add_category_info(collection, _id, category='', sub_category=''):
    result = collection.update_one(
        {'_id': bson.ObjectId(_id)}, 
        {'$set' : {'transaction.category': category, 'transaction.sub_category': sub_category}})
    print('success' if result.modified_count == 1 else 'failed')
    return result

# %%
paytmInterpreterFormatStr = '%b %d, %Y %H:%M:%S'
# Paid Rs. 106.76 to UBER on Feb 10, 2020 11:33:28 with Ref: 28811759158. For more details, visit https://p-y.tm/1Q-bnfM
def paytmInterpreter(txn):
    x = re.search("Paid Rs. ([0-9.]+) to\s+([a-zA-Z0-9\s._//]+)? on (([a-zA-Z]){3} \d{1,2}, (\d{4} \d{2}:\d{2}:\d{2}))", txn)
    return {
        'expense_amount': float(x.group(1)),
        'payment_mode': 'PAYTM',
        'merchant': x.group(2).strip(),
        'datetime': datetime.datetime.strptime(x.group(3), paytmInterpreterFormatStr)
    } if x != None else {}

for _item in list(
    enumerate(
        collection.find({
            "message.text": {'$regex': 'Paid Rs. ([0-9.]+) to'},
            "status.analysis_done": {'$ne': True}}
        ).sort([("message.date",1)]))):
    print("message", _item[1])
    _transaction = paytmInterpreter(_item[1]['message']['text'])
    print("analysis", _transaction, "\n\n")
    result = collection.update_one(
        {'_id': bson.ObjectId(str(_item[1]['_id']))},
        {'$set' : {'transaction': _transaction, 'status': {'analysis_done': True}}})
    print('success' if result.modified_count == 1 else 'unsuccessful')
# Out:
# message {'_id': ObjectId('5e46a9363fdf437c9b43e294'), 'message': {'text': 'Paid Rs. 106.73 to UBER on Oct 1, 2019 19:00:09 with Ref: 26704838359. For more details, visit https://p-y.tm/ns8-MTj', 'date': 591629411167417984, 'guid': 'A99FE6B4-4FBA-46AB-F640-A0F7C7788C05'}}
# analysis {'expense_amount': 106.73, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 1, 19, 0, 9)}
#
#
# message {'_id': ObjectId('5e46a9373fdf437c9b43e296'), 'message': {'text': 'Paid Rs. 104.56 to UBER on Oct 2, 2019 10:38:06 with Ref: 26713391394. For more details, visit https://p-y.tm/cqXu-oa', 'date': 591685689347947008, 'guid': '7751B722-DAE8-D7A9-5E41-0943F0DD5AB9'}}
# analysis {'expense_amount': 104.56, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 2, 10, 38, 6)}
#
#
# message {'_id': ObjectId('5e46a9373fdf437c9b43e297'), 'message': {'text': 'Paid Rs. 546.49 to UBER on Oct 2, 2019 18:46:58 with Ref: 26721720845. For more details, visit https://p-y.tm/r0-RfkW', 'date': 591715019310184960, 'guid': '0373D2CC-867D-4F35-5AEA-130C69D2F139'}}
# analysis {'expense_amount': 546.49, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 2, 18, 46, 58)}
#
#
# message {'_id': ObjectId('5e46a9373fdf437c9b43e29a'), 'message': {'text': 'Paid Rs. 338 to swiggy on Oct 7, 2019 14:11:45 with Ref: 26798381081. For more details, visit https://p-y.tm/qZL-dwx', 'date': 592130507549443968, 'guid': 'F732BF5A-E7C8-82EC-3690-45DD279AA96F'}}
# analysis {'expense_amount': 338.0, 'payment_mode': 'PAYTM', 'merchant': 'swiggy', 'datetime': datetime.datetime(2019, 10, 7, 14, 11, 45)}
#
#
# message {'_id': ObjectId('5e46a9373fdf437c9b43e29d'), 'message': {'text': 'Paid Rs. 99 to UBER on Oct 8, 2019 09:54:39 with Ref: 26809389085. For more details, visit https://p-y.tm/Qcad-HY', 'date': 592201480929272064, 'guid': 'C4CB878B-4610-13D8-8EF1-76AA8022D378'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 8, 9, 54, 39)}
#
#
# message {'_id': ObjectId('5e46a9373fdf437c9b43e29e'), 'message': {'text': 'Paid Rs. 83.88 to UBER on Oct 8, 2019 10:19:28 with Ref: 26809664135. For more details, visit https://p-y.tm/PQa-euw', 'date': 592202969356210048, 'guid': 'CB1BCE7D-AE3D-BC40-4CE8-2925C2AC17E6'}}
# analysis {'expense_amount': 83.88, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 8, 10, 19, 28)}
#
#
# message {'_id': ObjectId('5e46a9373fdf437c9b43e29f'), 'message': {'text': 'Paid Rs. 79.2 to UBER on Oct 8, 2019 15:35:07 with Ref: 26814741759. For more details, visit https://p-y.tm/7Vld-ob', 'date': 592221910602692992, 'guid': '6109D753-37AB-455C-9C69-D25FF1CF533A'}}
# analysis {'expense_amount': 79.2, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 8, 15, 35, 7)}
#
#
# message {'_id': ObjectId('5e46a9373fdf437c9b43e2a2'), 'message': {'text': 'Paid Rs. 79.2 to UBER on Oct 9, 2019 11:29:19 with Ref: 26825231313. For more details, visit https://p-y.tm/CsX-17o', 'date': 592293561580376960, 'guid': '395017B4-1E5A-FB0A-2BCF-D6E09FC06030'}}
# analysis {'expense_amount': 79.2, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 9, 11, 29, 19)}
#
#
# message {'_id': ObjectId('5e46a9373fdf437c9b43e2a3'), 'message': {'text': 'Paid Rs. 85.29 to UBER on Oct 9, 2019 16:26:11 with Ref: 26830473680. For more details, visit https://p-y.tm/v-aN0qO', 'date': 592311379080024960, 'guid': '276AA66D-72EA-8401-9F6B-3F2D94C325CF'}}
# analysis {'expense_amount': 85.29, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 9, 16, 26, 11)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2a5'), 'message': {'text': 'Paid Rs. 79.2 to UBER on Oct 11, 2019 14:33:08 with Ref: 26862739903. For more details, visit https://p-y.tm/7S8-OFs', 'date': 592477391887624960, 'guid': 'FEB5C423-D24C-6966-61C6-8FD3EF59385D'}}
# analysis {'expense_amount': 79.2, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 11, 14, 33, 8)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2a7'), 'message': {'text': 'Paid Rs. 83.62 to UBER on Oct 14, 2019 11:55:45 with Ref: 26907044385. For more details, visit https://p-y.tm/BfX-rk9', 'date': 592727146910889088, 'guid': '367EC4C4-D166-7226-443D-C143F9C70BF1'}}
# analysis {'expense_amount': 83.62, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 14, 11, 55, 45)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2a8'), 'message': {'text': 'Paid Rs. 79.2 to UBER on Oct 14, 2019 16:39:58 with Ref: 26912128613. For more details, visit https://p-y.tm/0u2-92F', 'date': 592744199717154048, 'guid': 'D6BF28DF-F15D-FA67-2206-718BA97695E0'}}
# analysis {'expense_amount': 79.2, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 14, 16, 39, 58)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2aa'), 'message': {'text': 'Paid Rs. 79.2 to UBER on Oct 16, 2019 21:56:31 with Ref: 26951110184. For more details, visit https://p-y.tm/7E-vX6O', 'date': 592936016492651008, 'guid': 'D8CE16DB-F44F-4000-ADA4-87580CE0CCF0'}}
# analysis {'expense_amount': 79.2, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 16, 21, 56, 31)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2a9'), 'message': {'text': 'Paid Rs. 79.2 to UBER on Oct 16, 2019 21:56:31 with Ref: 26951110184. For more details, visit https://p-y.tm/7E-vX6O', 'date': 592936033250707072, 'guid': '80C4F18A-60CA-D0A9-825D-6AC435899CAC'}}
# analysis {'expense_amount': 79.2, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 16, 21, 56, 31)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2ab'), 'message': {'text': 'Paid Rs. 105.13 to UBER on Oct 19, 2019 17:40:47 with Ref: 26995276952. For more details, visit https://p-y.tm/3r-gaL7', 'date': 593179849031473024, 'guid': '9E123894-3107-7CFB-E586-F3D6D31F6934'}}
# analysis {'expense_amount': 105.13, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 19, 17, 40, 47)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2ac'), 'message': {'text': 'Paid Rs. 101.27 to UBER on Oct 19, 2019 20:55:53 with Ref: 26998881817. For more details, visit https://p-y.tm/1-8wWfT', 'date': 593191555583407104, 'guid': 'C7E7C0A6-6BCC-7DFF-BFFC-84F72E15127E'}}
# analysis {'expense_amount': 101.27, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 19, 20, 55, 53)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2ad'), 'message': {'text': 'Paid Rs. 79.2 to UBER on Oct 21, 2019 11:29:54 with Ref: 27019884745. For more details, visit https://p-y.tm/E-sFF2q', 'date': 593330476716611072, 'guid': 'C2EF7383-155D-95D0-44D7-22D99236EFED'}}
# analysis {'expense_amount': 79.2, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 21, 11, 29, 54)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2ae'), 'message': {'text': 'Paid Rs. 80.71 to UBER on Oct 21, 2019 17:16:16 with Ref: 27025968921. For more details, visit https://p-y.tm/L-1ZF4Y', 'date': 593351180510414976, 'guid': 'FF5F9165-0609-D0EA-3BE5-A371A5B13361'}}
# analysis {'expense_amount': 80.71, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 21, 17, 16, 16)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2b0'), 'message': {'text': 'Paid Rs. 79.2 to UBER on Oct 22, 2019 11:08:24 with Ref: 27035942126. For more details, visit https://p-y.tm/q-3RL1J', 'date': 593415509215489024, 'guid': '7D345770-5F57-6231-BD73-51010E17C66A'}}
# analysis {'expense_amount': 79.2, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 22, 11, 8, 24)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2b1'), 'message': {'text': 'Paid Rs. 97.16 to UBER on Oct 22, 2019 17:48:04 with Ref: 27042949105. For more details, visit https://p-y.tm/gz-3P6x', 'date': 593439487400120960, 'guid': '985E11BE-206E-4198-7240-05A16685EE03'}}
# analysis {'expense_amount': 97.16, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 22, 17, 48, 4)}
#
#
# message {'_id': ObjectId('5e46a9383fdf437c9b43e2b3'), 'message': {'text': 'Paid Rs. 99 to UBER on Oct 23, 2019 11:53:06 with Ref: 27053153169. For more details, visit https://p-y.tm/Dno7-gO', 'date': 593504588927906048, 'guid': '86E079FE-5E9D-45C0-6E97-3FC8BC541D85'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 23, 11, 53, 6)}
#
#
# message {'_id': ObjectId('5e46a9393fdf437c9b43e2b4'), 'message': {'text': 'Paid Rs. 99 to UBER on Oct 23, 2019 17:35:14 with Ref: 27059237315. For more details, visit https://p-y.tm/Dmy6-CI', 'date': 593525116177037952, 'guid': '15CC9027-BD7B-E988-E9E1-41D4363D1135'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 10, 23, 17, 35, 14)}
#
#
# message {'_id': ObjectId('5e46a9393fdf437c9b43e2b6'), 'message': {'text': 'Paid Rs. 132 to MK Retail Kaggadasapura on Oct 29, 2019 10:23:03 with Ref: 27144760177. For more details, visit https://p-y.tm/us-nY5s', 'date': 594017585004407040, 'guid': '1944F23D-A5CA-EFDB-4D67-88F23F3CB04D'}}
# analysis {'expense_amount': 132.0, 'payment_mode': 'PAYTM', 'merchant': 'MK Retail Kaggadasapura', 'datetime': datetime.datetime(2019, 10, 29, 10, 23, 3)}
#
#
# message {'_id': ObjectId('5e46a9393fdf437c9b43e2b7'), 'message': {'text': 'Paid Rs. 50 to Solanki medicals on Oct 31, 2019 14:28:18 with Ref: 27178652082. For more details, visit https://p-y.tm/Haa-rvH', 'date': 594205099870177024, 'guid': '46340AA9-C4B1-9F53-D2BE-97E97104D40F'}}
# analysis {'expense_amount': 50.0, 'payment_mode': 'PAYTM', 'merchant': 'Solanki medicals', 'datetime': datetime.datetime(2019, 10, 31, 14, 28, 18)}
#
#
# message {'_id': ObjectId('5e46a9393fdf437c9b43e2b8'), 'message': {'text': 'Paid Rs. 50 to MK Retail Kaggadasapura on Nov 1, 2019 20:07:13 with Ref: 27199453799. For more details, visit https://p-y.tm/Cy-7dSm', 'date': 594311834987560960, 'guid': '99D3F7DE-FA9F-899A-3D09-4B82B4B8208B'}}
# analysis {'expense_amount': 50.0, 'payment_mode': 'PAYTM', 'merchant': 'MK Retail Kaggadasapura', 'datetime': datetime.datetime(2019, 11, 1, 20, 7, 13)}
#
#
# message {'_id': ObjectId('5e46a9393fdf437c9b43e2bd'), 'message': {'text': 'Paid Rs. 104 to Kailash Parbat Phoenix Mall on Nov 10, 2019 19:43:10 with Ref: 27339572443. For more details, visit https://p-y.tm/cU-7VyP', 'date': 595087994983713024, 'guid': '31F70A4C-6113-1CD6-D3DA-32062CC5936B'}}
# analysis {'expense_amount': 104.0, 'payment_mode': 'PAYTM', 'merchant': 'Kailash Parbat Phoenix Mall', 'datetime': datetime.datetime(2019, 11, 10, 19, 43, 10)}
#
#
# message {'_id': ObjectId('5e46a9393fdf437c9b43e2c0'), 'message': {'text': 'Paid Rs. 99 to UBER on Nov 13, 2019 19:56:58 with Ref: 27387042939. For more details, visit https://p-y.tm/avZr-Ho', 'date': 595348020295586944, 'guid': 'AB35EA1C-AB38-22B8-D21E-537B45700ABF'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 11, 13, 19, 56, 58)}
#
#
# message {'_id': ObjectId('5e46a93a3fdf437c9b43e2c4'), 'message': {'text': 'Paid Rs. 73.58 to UBER on Nov 20, 2019 07:20:51 with Ref: 27487591728. For more details, visit https://p-y.tm/E-YQfRS', 'date': 595907453557476992, 'guid': 'EA02CD54-288D-21E5-870B-78AE237ED6B3'}}
# analysis {'expense_amount': 73.58, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 11, 20, 7, 20, 51)}
#
#
# message {'_id': ObjectId('5e46a93a3fdf437c9b43e2c5'), 'message': {'text': 'Paid Rs. 163.06 to UBER on Nov 20, 2019 08:28:03 with Ref: 27488098011. For more details, visit https://p-y.tm/yR-pHJj', 'date': 595911485790710016, 'guid': '4B0A5558-E874-24E1-5B82-4E2B2986E65A'}}
# analysis {'expense_amount': 163.06, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2019, 11, 20, 8, 28, 3)}
#
#
# message {'_id': ObjectId('5e46a93a3fdf437c9b43e2cb'), 'message': {'text': 'Paid Rs. 79 to MK Retail Kaggadasapura on Dec 2, 2019 10:16:16 with Ref: 27681103997. For more details, visit https://p-y.tm/hr-4lPd', 'date': 596954777966179072, 'guid': '9EFA603F-6DC5-9EE2-7CFC-8620F3908097'}}
# analysis {'expense_amount': 79.0, 'payment_mode': 'PAYTM', 'merchant': 'MK Retail Kaggadasapura', 'datetime': datetime.datetime(2019, 12, 2, 10, 16, 16)}
#
#
# message {'_id': ObjectId('5e46a93a3fdf437c9b43e2cd'), 'message': {'text': 'Paid Rs. 77 to Gelato Italiano PMC BLR on Dec 9, 2019 20:34:03 with Ref: 27806509368. For more details, visit https://p-y.tm/Kcrd-QY', 'date': 597596644589662976, 'guid': '678AEC29-F401-A6D0-5813-CD26BB34D0E6'}}
# analysis {'expense_amount': 77.0, 'payment_mode': 'PAYTM', 'merchant': 'Gelato Italiano PMC BLR', 'datetime': datetime.datetime(2019, 12, 9, 20, 34, 3)}
#
#
# message {'_id': ObjectId('5e46a93a3fdf437c9b43e2ce'), 'message': {'text': 'Paid Rs. 76 to Gelato Italiano PMC BLR on Dec 9, 2019 20:35:09 with Ref: 27806530552. For more details, visit https://p-y.tm/bbT-gKe', 'date': 597596711508924032, 'guid': 'B9F042EE-6CCA-B112-6CB6-84240E5D3092'}}
# analysis {'expense_amount': 76.0, 'payment_mode': 'PAYTM', 'merchant': 'Gelato Italiano PMC BLR', 'datetime': datetime.datetime(2019, 12, 9, 20, 35, 9)}
#
#
# message {'_id': ObjectId('5e46a93a3fdf437c9b43e2d1'), 'message': {'text': 'Paid Rs. 170 to The lassi club on Dec 12, 2019 19:07:00 with Ref: 27852289339. For more details, visit https://p-y.tm/Luq-nwk', 'date': 597850621798269952, 'guid': 'B8AE63F8-D962-4E5E-21B2-F43B172E6EC0'}}
# analysis {'expense_amount': 170.0, 'payment_mode': 'PAYTM', 'merchant': 'The lassi club', 'datetime': datetime.datetime(2019, 12, 12, 19, 7)}
#
#
# message {'_id': ObjectId('5e46a93b3fdf437c9b43e2d3'), 'message': {'text': 'Paid Rs. 80 to MANOJ E S on Dec 28, 2019 11:18:33 with Ref: 28095122942. For more details, visit https://p-y.tm/D-FX1bq', 'date': 599204915173940992, 'guid': 'B5716051-E117-C585-BDB0-477ABA9E11F1'}}
# analysis {'expense_amount': 80.0, 'payment_mode': 'PAYTM', 'merchant': 'MANOJ E S', 'datetime': datetime.datetime(2019, 12, 28, 11, 18, 33)}
#
#
# message {'_id': ObjectId('5e46a93b3fdf437c9b43e2d5'), 'message': {'text': 'Paid Rs. 99 to UBER on Jan 6, 2020 11:01:12 with Ref: 28257812137. For more details, visit https://p-y.tm/x-YLVKE', 'date': 599981473478163968, 'guid': '9D1C0F98-24A0-543D-408D-92BC960D7B32'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 6, 11, 1, 12)}
#
#
# message {'_id': ObjectId('5e46a93b3fdf437c9b43e2d6'), 'message': {'text': 'Paid Rs. 96.51 to UBER on Jan 6, 2020 17:05:35 with Ref: 28264119591. For more details, visit https://p-y.tm/g97P-JX', 'date': 600003336842224896, 'guid': '3667BF56-0610-7EB8-C3FD-476F2054CA50'}}
# analysis {'expense_amount': 96.51, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 6, 17, 5, 35)}
#
#
# message {'_id': ObjectId('5e46a93b3fdf437c9b43e2d7'), 'message': {'text': 'Paid Rs. 112.13 to UBER on Jan 7, 2020 11:07:19 with Ref: 28273584004. For more details, visit https://p-y.tm/cxhn-bw', 'date': 600068241102305024, 'guid': 'C49D164D-D198-16A0-66CB-3A31969F5610'}}
# analysis {'expense_amount': 112.13, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 7, 11, 7, 19)}
#
#
# message {'_id': ObjectId('5e46a93b3fdf437c9b43e2d8'), 'message': {'text': 'Paid Rs. 93.06 to UBER on Jan 7, 2020 14:08:49 with Ref: 28276843470. For more details, visit https://p-y.tm/dV-bgiI', 'date': 600079131276089984, 'guid': '55F314CF-BAC0-B933-7CFA-DCCC6FB758F9'}}
# analysis {'expense_amount': 93.06, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 7, 14, 8, 49)}
#
#
# message {'_id': ObjectId('5e46a93b3fdf437c9b43e2dc'), 'message': {'text': 'Paid Rs. 112.89 to UBER on Jan 9, 2020 12:40:16 with Ref: 28306968865. For more details, visit https://p-y.tm/P-B96BE', 'date': 600246617619452928, 'guid': 'BAFC66B2-F69A-3EBF-CBED-CE372022D35E'}}
# analysis {'expense_amount': 112.89, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 9, 12, 40, 16)}
#
#
# message {'_id': ObjectId('5e46a93b3fdf437c9b43e2dd'), 'message': {'text': 'Paid Rs. 107.49 to UBER on Jan 9, 2020 16:54:50 with Ref: 28311476825. For more details, visit https://p-y.tm/wC-tqZJ', 'date': 600261892898450048, 'guid': '6E473CFF-BD90-82F2-E182-62D5EC6456CC'}}
# analysis {'expense_amount': 107.49, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 9, 16, 54, 50)}
#
#
# message {'_id': ObjectId('5e46a93b3fdf437c9b43e2de'), 'message': {'text': 'Paid Rs. 53 to Solanki medicals on Jan 9, 2020 19:31:37 with Ref: 28314264236. For more details, visit https://p-y.tm/a-e40vo', 'date': 600271299278694016, 'guid': '8BB9EDCA-0295-EF5E-DE85-1CA29A2DF566'}}
# analysis {'expense_amount': 53.0, 'payment_mode': 'PAYTM', 'merchant': 'Solanki medicals', 'datetime': datetime.datetime(2020, 1, 9, 19, 31, 37)}
#
#
# message {'_id': ObjectId('5e46a93b3fdf437c9b43e2e0'), 'message': {'text': 'Paid Rs. 30 to Solanki medicals on Jan 11, 2020 18:45:37 with Ref: 28346224207. For more details, visit https://p-y.tm/CEx-ws5', 'date': 600441338752622976, 'guid': 'F9A249D6-D0A3-B489-2A38-672D46FF2A50'}}
# analysis {'expense_amount': 30.0, 'payment_mode': 'PAYTM', 'merchant': 'Solanki medicals', 'datetime': datetime.datetime(2020, 1, 11, 18, 45, 37)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2e1'), 'message': {'text': 'Paid Rs. 99 to UBER on Jan 14, 2020 17:24:23 with Ref: 28391001784. For more details, visit https://p-y.tm/il0D-qY', 'date': 600695664756402944, 'guid': '5142496B-9B1C-AF06-B4D3-982D2FC60AD9'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 14, 17, 24, 23)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2e3'), 'message': {'text': 'Paid Rs. 106.48 to UBER on Jan 15, 2020 11:16:18 with Ref: 28399824017. For more details, visit https://p-y.tm/m2Oe-0N', 'date': 600759998826012928, 'guid': '08652CE7-A4FF-7586-4845-BFDFE47470BA'}}
# analysis {'expense_amount': 106.48, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 15, 11, 16, 18)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2e4'), 'message': {'text': 'Paid Rs. 118.98 to UBER on Jan 15, 2020 18:33:40 with Ref: 28407458509. For more details, visit https://p-y.tm/V30-2Vt', 'date': 600786222296365952, 'guid': 'FB4C168B-FEC4-0D93-6519-80CAA822A52A'}}
# analysis {'expense_amount': 118.98, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 15, 18, 33, 40)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2e5'), 'message': {'text': 'Paid Rs. 99 to UBER on Jan 15, 2020 19:38:43 with Ref: 28408754457. For more details, visit https://p-y.tm/f0-IEIT', 'date': 600790125208584960, 'guid': '266B2B30-08FD-DB61-E0B4-AC999F583CD5'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 15, 19, 38, 43)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2e6'), 'message': {'text': 'Paid Rs. 45 to Lokesh on Jan 16, 2020 16:40:30 with Ref: 28422025231. For more details, visit https://p-y.tm/vYV-Cyn', 'date': 600865834773817984, 'guid': '5A646211-AEF5-67C2-A6A9-7DD23D179F3D'}}
# analysis {'expense_amount': 45.0, 'payment_mode': 'PAYTM', 'merchant': 'Lokesh', 'datetime': datetime.datetime(2020, 1, 16, 16, 40, 30)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2e8'), 'message': {'text': 'Paid Rs. 115.78 to UBER on Jan 20, 2020 11:33:14 with Ref: 28479945929. For more details, visit https://p-y.tm/x-XVMSk', 'date': 601192996240993920, 'guid': 'DCA17704-FAFE-A362-9502-8539FA9DD7F6'}}
# analysis {'expense_amount': 115.78, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 20, 11, 33, 14)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2e9'), 'message': {'text': 'Paid Rs. 109.85 to UBER on Jan 20, 2020 15:44:12 with Ref: 28484550144. For more details, visit https://p-y.tm/m4-FcBa', 'date': 601208053404888064, 'guid': 'D0C33A8D-2A99-8E0E-621A-2F6727898508'}}
# analysis {'expense_amount': 109.85, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 20, 15, 44, 12)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2ea'), 'message': {'text': 'Paid Rs. 142.02 to UBER on Jan 20, 2020 17:07:49 with Ref: 28485842074. For more details, visit https://p-y.tm/38r-9zn', 'date': 601213070486366080, 'guid': 'F5A48EA9-F4E3-78CF-6C4D-766C3C35EC22'}}
# analysis {'expense_amount': 142.02, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 20, 17, 7, 49)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2eb'), 'message': {'text': 'Paid Rs. 95 to UBER on Jan 20, 2020 21:59:17 with Ref: 28491035459. For more details, visit https://p-y.tm/Mini-RV', 'date': 601230559437172992, 'guid': '255744E1-67A0-B743-2F33-57CC4398A896'}}
# analysis {'expense_amount': 95.0, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 20, 21, 59, 17)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2ec'), 'message': {'text': 'Paid Rs. 236.12 to UBER on Jan 25, 2020 05:47:35 with Ref: 28557038876. For more details, visit https://p-y.tm/JDi-KVH', 'date': 601604256728261888, 'guid': '0538BE94-FB8B-7C62-D80E-B30511E3EDDF'}}
# analysis {'expense_amount': 236.12, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 25, 5, 47, 35)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2ed'), 'message': {'text': 'Paid Rs. 214.05 to UBER on Jan 26, 2020 17:00:35 with Ref: 28580943427. For more details, visit https://p-y.tm/L5Hz-a9', 'date': 601731037494887040, 'guid': '2E992029-4CB3-0A4B-C882-FB96E422B335'}}
# analysis {'expense_amount': 214.05, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 26, 17, 0, 35)}
#
#
# message {'_id': ObjectId('5e46a93c3fdf437c9b43e2ee'), 'message': {'text': 'Paid Rs. 258.92 to UBER on Jan 26, 2020 23:13:00 with Ref: 28586371747. For more details, visit https://p-y.tm/j-9DSxk', 'date': 601753382097478016, 'guid': 'AD287587-2FF0-AF5C-2CC0-05EE99680B33'}}
# analysis {'expense_amount': 258.92, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 26, 23, 13)}
#
#
# message {'_id': ObjectId('5e46a93d3fdf437c9b43e2ef'), 'message': {'text': 'Paid Rs. 50 to UBER on Jan 26, 2020 23:24:56 with Ref: 28586453224. For more details, visit https://p-y.tm/Y-WeO9W', 'date': 601754098241417984, 'guid': '911A7029-C9F3-C5D3-59F3-C9D534377C9B'}}
# analysis {'expense_amount': 50.0, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 26, 23, 24, 56)}
#
#
# message {'_id': ObjectId('5e46a93d3fdf437c9b43e2f0'), 'message': {'text': 'Paid Rs. 112.08 to UBER on Jan 28, 2020 12:02:32 with Ref: 28607168107. For more details, visit https://p-y.tm/zdKm-gW', 'date': 601885953920616960, 'guid': '3DB8E3D0-3D40-A3F0-AC36-18D0D48D0236'}}
# analysis {'expense_amount': 112.08, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 28, 12, 2, 32)}
#
#
# message {'_id': ObjectId('5e46a93d3fdf437c9b43e2f1'), 'message': {'text': 'Paid Rs. 100.78 to UBER on Jan 28, 2020 14:46:46 with Ref: 28610413427. For more details, visit https://p-y.tm/EuC-siL', 'date': 601895807690929024, 'guid': '014519FB-EB7F-B0BF-5280-DA0F6B7E646B'}}
# analysis {'expense_amount': 100.78, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 1, 28, 14, 46, 46)}
#
#
# message {'_id': ObjectId('5e46a93d3fdf437c9b43e2f3'), 'message': {'text': 'Paid Rs. 65 to Paratha Corner on Feb 1, 2020 20:32:01 with Ref: 28677871441. For more details, visit https://p-y.tm/J-Kt6Et', 'date': 602262122936665088, 'guid': 'F82AFDCF-B13A-500C-E1F8-59B0C284C715'}}
# analysis {'expense_amount': 65.0, 'payment_mode': 'PAYTM', 'merchant': 'Paratha Corner', 'datetime': datetime.datetime(2020, 2, 1, 20, 32, 1)}
#
#
# message {'_id': ObjectId('5e46a93d3fdf437c9b43e2f4'), 'message': {'text': 'Paid Rs. 90.6 to UBER on Feb 1, 2020 22:57:31 with Ref: 28679799481. For more details, visit https://p-y.tm/L-tZtK0', 'date': 602270853092929024, 'guid': 'C4678B4B-7B65-DFDF-0B0F-738627FC1204'}}
# analysis {'expense_amount': 90.6, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 2, 1, 22, 57, 31)}
#
#
# message {'_id': ObjectId('5e46a93d3fdf437c9b43e2f5'), 'message': {'text': 'Paid Rs. 102.96 to UBER on Feb 3, 2020 15:53:25 with Ref: 28702938530. For more details, visit https://p-y.tm/X-jdRck', 'date': 602418217548739968, 'guid': 'A914BEEA-FF0D-BB70-3EBF-AE3731999B0F'}}
# analysis {'expense_amount': 102.96, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 2, 3, 15, 53, 25)}
#
#
# message {'_id': ObjectId('5e46a93d3fdf437c9b43e2f6'), 'message': {'text': 'Paid Rs. 115.93 to UBER on Feb 6, 2020 11:15:06 with Ref: 28745350784. For more details, visit https://p-y.tm/wf-nOYF', 'date': 602660708125923968, 'guid': 'E531C793-5F03-ED37-3F5D-683657F07552'}}
# analysis {'expense_amount': 115.93, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 2, 6, 11, 15, 6)}
#
#
# message {'_id': ObjectId('5e46a93d3fdf437c9b43e2f7'), 'message': {'text': 'Paid Rs. 80 to Solanki medicals on Feb 6, 2020 22:56:34 with Ref: 28758462081. For more details, visit https://p-y.tm/TnH-ihS', 'date': 602702797129587968, 'guid': 'DBFFF144-7061-7C96-014E-45CE0888EDAC'}}
# analysis {'expense_amount': 80.0, 'payment_mode': 'PAYTM', 'merchant': 'Solanki medicals', 'datetime': datetime.datetime(2020, 2, 6, 22, 56, 34)}
#
#
# message {'_id': ObjectId('5e46a93d3fdf437c9b43e2fa'), 'message': {'text': 'Paid Rs. 106.76 to UBER on Feb 10, 2020 11:33:28 with Ref: 28811759158. For more details, visit https://p-y.tm/1Q-bnfM', 'date': 603007409841016064, 'guid': '59847A8C-AC3E-2F9C-12DD-474ACAC92EDF'}}
# analysis {'expense_amount': 106.76, 'payment_mode': 'PAYTM', 'merchant': 'UBER', 'datetime': datetime.datetime(2020, 2, 10, 11, 33, 28)}
#
#
# message {'_id': ObjectId('5e46a93e3fdf437c9b43e2fd'), 'message': {'text': 'Paid Rs. 79 to Bharti Airtel Limited on Feb 13, 2020 18:55:27 with Ref: 28870749380. For more details, visit https://p-y.tm/5Gxy-gl', 'date': 603293129365107072, 'guid': 'D703750E-BF7E-2EDB-84D7-E757F0E2A097'}}
# analysis {'expense_amount': 79.0, 'payment_mode': 'PAYTM', 'merchant': 'Bharti Airtel Limited', 'datetime': datetime.datetime(2020, 2, 13, 18, 55, 27)}
#
#
# message {'_id': ObjectId('5e4c15874d76059dbcf77831'), 'message': {'text': 'Paid Rs. 200 to The lassi club on Feb 17, 2020 21:11:53 with Ref: 28937786627. For more details, visit https://p-y.tm/ub-3i8m', 'date': 603646914532008064, 'guid': '47561EF1-1C18-ABCF-3D21-F9532B540727'}}
# analysis {'expense_amount': 200.0, 'payment_mode': 'PAYTM', 'merchant': 'The lassi club', 'datetime': datetime.datetime(2020, 2, 17, 21, 11, 53)}
#
#
# message {'_id': ObjectId('5e535c43cd4ca37f9ee811b8'), 'message': {'text': 'Paid Rs. 111 to Eat Fit on Feb 24, 2020 08:55:37 with Ref: 29033103360. For more details, visit https://p-y.tm/ie8c-ZY', 'date': 604207539197252992, 'guid': 'A2B2224F-4BB1-F72C-5A5A-B31BD20C2357'}}
# analysis {'expense_amount': 111.0, 'payment_mode': 'PAYTM', 'merchant': 'Eat Fit', 'datetime': datetime.datetime(2020, 2, 24, 8, 55, 37)}
#
#
# message {'_id': ObjectId('5e58bc830f2926acec7e6574'), 'message': {'text': 'Paid Rs. 136 to Eat Fit on Feb 24, 2020 17:45:46 with Ref: 29041216488. For more details, visit https://p-y.tm/F-XKqny', 'date': 604239350202790016, 'guid': 'DC625446-B994-77A8-DBB4-0CD249D7DF8F'}}
# analysis {'expense_amount': 136.0, 'payment_mode': 'PAYTM', 'merchant': 'Eat Fit', 'datetime': datetime.datetime(2020, 2, 24, 17, 45, 46)}
#
#
# message {'_id': ObjectId('5e58bc830f2926acec7e6575'), 'message': {'text': 'Paid Rs. 187 to Eat Fit on Feb 24, 2020 17:50:47 with Ref: 29041291092. For more details, visit https://p-y.tm/CKI-JSw', 'date': 604239650564893952, 'guid': 'E71351A6-C9AE-6953-D0E8-FC6215803497'}}
# analysis {'expense_amount': 187.0, 'payment_mode': 'PAYTM', 'merchant': 'Eat Fit', 'datetime': datetime.datetime(2020, 2, 24, 17, 50, 47)}
#
#
# message {'_id': ObjectId('5e58bc840f2926acec7e6579'), 'message': {'text': 'Paid Rs. 118 to Eat Fit on Feb 25, 2020 18:57:27 with Ref: 29057347554. For more details, visit https://p-y.tm/xX-nuw3', 'date': 604330049927004032, 'guid': '551913C8-532F-1CC0-8C64-76ED9AA95916'}}
# analysis {'expense_amount': 118.0, 'payment_mode': 'PAYTM', 'merchant': 'Eat Fit', 'datetime': datetime.datetime(2020, 2, 25, 18, 57, 27)}
#
#
# message {'_id': ObjectId('5e58bc840f2926acec7e6580'), 'message': {'text': 'Paid Rs. 191 to Eat Fit on Feb 26, 2020 20:10:16 with Ref: 29073772317. For more details, visit https://p-y.tm/bA-UNeu', 'date': 604420818977362048, 'guid': '04823AAE-C531-3EBF-4FA2-4624F9A1363D'}}
# analysis {'expense_amount': 191.0, 'payment_mode': 'PAYTM', 'merchant': 'Eat Fit', 'datetime': datetime.datetime(2020, 2, 26, 20, 10, 16)}

# %%
# Acct ([X0-9]+) debited with INR([0-9.]+) on (\d{1,2}-([a-zA-Z]){3}-\d{2,4}) and ([a-zA-Z0-9@])+ credited.
iciciUPIInterpreterFormatStr = '%d-%b-%y'
def iciciUPIInterpreter(txn):
    x = re.search("Acct ([X0-9]+) debited with INR([0-9.]+) on (\d{1,2}-([a-zA-Z]){3}-\d{2,4}) and ([a-zA-Z0-9@]+) credited.", txn)
    return {
        'expense_amount': float(x.group(2)),
        'payment_mode': x.group(1),
        'merchant': x.group(5).strip(),
        'datetime': datetime.datetime.strptime(x.group(3), iciciUPIInterpreterFormatStr)
    } if x != None else {}
#     return x

for _item in list(
    enumerate(
        collection.find({
            "message.text": {'$regex': 'Acct ([X0-9]+) debited with INR([0-9.]+)'},
            "status.analysis_done": {'$ne': True}}
        ).sort([("message.date",1)]))):
    print("message", _item[1])
    _transaction = iciciUPIInterpreter(_item[1]['message']['text'])
    print("analysis", _transaction, "\n\n")
#     result = collection.update_one(
#         {'_id': bson.ObjectId(str(_item[1]['_id']))},
#         {'$set' : {'transaction': _transaction, 'status': {'analysis_done': True}}})
#     print('success' if result.modified_count == 1 else 'unsuccessful')
# Out:
# message {'_id': ObjectId('5e26dacad64bdc5152d0330f'), 'message': {'text': 'Acct XX1983 debited with INR120.00 on 06-Feb-19 and q66675194@ybl credited.Info:UPI-903721690874.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 571159939937314048, 'guid': '33FBC02F-A0E3-D626-1D8D-C236CDF245EC'}}
# analysis {'expense_amount': 120.0, 'payment_mode': 'XX1983', 'merchant': 'q66675194@ybl', 'datetime': datetime.datetime(2019, 2, 6, 0, 0)}
#
#
# message {'_id': ObjectId('5e26dacfd64bdc5152d03332'), 'message': {'text': 'Acct XX1983 debited with INR85.00 on 10-Feb-19 and q66675194@ybl credited.Info:UPI-904121364814.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 571508864698371072, 'guid': '2B905589-BDF5-D23C-6340-FB85F3FFC631'}}
# analysis {'expense_amount': 85.0, 'payment_mode': 'XX1983', 'merchant': 'q66675194@ybl', 'datetime': datetime.datetime(2019, 2, 10, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db1fd64bdc5152d03550'), 'message': {'text': 'Acct XXX983 debited with INR291.50 on 01-Aug-19 and steevraj11@okaxis credited.Info:UPI-921319307907.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 586361266060232064, 'guid': '51D38D79-183F-1DFC-4682-CB3E2D0157DD'}}
# analysis {'expense_amount': 291.5, 'payment_mode': 'XXX983', 'merchant': 'steevraj11@okaxis', 'datetime': datetime.datetime(2019, 8, 1, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db24d64bdc5152d03573'), 'message': {'text': 'Acct XXX983 debited with INR35.00 on 09-Aug-19 and airtelin@hdfcbank credited.Info:UPI-922118728639.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 587048442531720960, 'guid': '9ED2B4A2-42FA-32EC-15CA-06F54B5925AE'}}
# analysis {'expense_amount': 35.0, 'payment_mode': 'XXX983', 'merchant': 'airtelin@hdfcbank', 'datetime': datetime.datetime(2019, 8, 9, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db26d64bdc5152d03587'), 'message': {'text': 'Acct XXX983 debited with INR600.00 on 11-Aug-19 and nsantoshkumar@okicici credited.Info:UPI-922319481316.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 587224894017384064, 'guid': 'DFDEB81A-FADB-9602-6974-CA85AE160237'}}
# analysis {'expense_amount': 600.0, 'payment_mode': 'XXX983', 'merchant': 'nsantoshkumar@okicici', 'datetime': datetime.datetime(2019, 8, 11, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db27d64bdc5152d03588'), 'message': {'text': 'Acct XXX983 debited with INR185.00 on 11-Aug-19 and bharatpe90200257812@yesbankltd credited.Info:UPI-922322688913.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 587234397125993984, 'guid': '0044A7DD-98EB-C82D-6CEB-FE7A878F4E7A'}}
# analysis {'expense_amount': 185.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200257812@yesbankltd', 'datetime': datetime.datetime(2019, 8, 11, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db28d64bdc5152d0358f'), 'message': {'text': 'Acct XXX983 debited with INR543.00 on 14-Aug-19 and dunzo.payu@hdfcbank credited.Info:UPI-922616356291.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 587473546533161984, 'guid': '05A50B96-91E3-EC90-FC2A-8AD97187F9C0'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db28d64bdc5152d03597'), 'message': {'text': 'Acct XXX983 debited with INR324.00 on 16-Aug-19 and dunzo.payu@hdfcbank credited.Info:UPI-922818166911.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 587652508751885952, 'guid': 'BEBDD2C9-EB6F-6F0C-D3C9-CDEB9A58C076'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db2ad64bdc5152d035a2'), 'message': {'text': 'Acct XXX983 debited with INR15.00 on 18-Aug-19 and bharatpe90200249292@yesbankltd credited.Info:UPI-923019819148.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 587829281116413952, 'guid': '8EEC1212-B48E-7E2C-8115-3AA621D9506B'}}
# analysis {'expense_amount': 15.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200249292@yesbankltd', 'datetime': datetime.datetime(2019, 8, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db35d64bdc5152d035f7'), 'message': {'text': 'Acct XXX983 debited with INR1000.00 on 01-Oct-19 and add-money@paytm credited.Info:UPI-927434835215.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 591598512176493056, 'guid': '85ADF252-3B37-BFC4-423A-02901D529630'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db3bd64bdc5152d03625'), 'message': {'text': 'Acct XXX983 debited with INR1000.00 on 08-Oct-19 and add-money@paytm credited.Info:UPI-928133446645.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 592201428498420992, 'guid': '805C76A5-D116-2B5A-EE09-6AF1277620E8'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db3bd64bdc5152d03626'), 'message': {'text': 'Acct XXX983 debited with INR300.00 on 08-Oct-19 and paytm-8740374@paytm credited.Info:UPI-928136746847.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 592210927677929088, 'guid': '0A718F99-BCFC-7C29-1F0C-39E026B7963A'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db40d64bdc5152d03657'), 'message': {'text': 'Acct XXX983 debited with INR130.00 on 19-Oct-19 and q66675194@ybl credited.Info:UPI-929222440917.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 593197142188006016, 'guid': '608371B8-FE45-F989-0E6A-74F2DC88E305'}}
# analysis {'expense_amount': 130.0, 'payment_mode': 'XXX983', 'merchant': 'q66675194@ybl', 'datetime': datetime.datetime(2019, 10, 19, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db42d64bdc5152d03667'), 'message': {'text': 'Acct XXX983 debited with INR74.00 on 23-Oct-19 and paytm-33090441@paytm credited.Info:UPI-929645191382.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 593541134431272064, 'guid': '0FA726A0-FF59-6E6F-8DFB-07B7D9A9F588'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db46d64bdc5152d03687'), 'message': {'text': 'Acct XXX983 debited with INR130.00 on 30-Oct-19 and q66675194@ybl credited.Info:UPI-930319317540.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594137345093610112, 'guid': '68264833-D85A-94D4-4645-38227C23E00C'}}
# analysis {'expense_amount': 130.0, 'payment_mode': 'XXX983', 'merchant': 'q66675194@ybl', 'datetime': datetime.datetime(2019, 10, 30, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db47d64bdc5152d03692'), 'message': {'text': 'Acct XXX983 debited with INR100.00 on 31-Oct-19 and paytm-37625485@paytm credited.Info:UPI-930438608667.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594206394749456000, 'guid': '311922B7-BD19-2184-AFD5-A7998263CB63'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db48d64bdc5152d0369b'), 'message': {'text': 'Acct XXX983 debited with INR1625.00 on 02-Nov-19 and bharatpe.9100491829@icici credited.Info:UPI-930618202284.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594393628712228992, 'guid': '0FDD3D2C-C05B-E288-48C0-93124B13BF5B'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db4ad64bdc5152d036a5'), 'message': {'text': 'Acct XXX983 debited with INR55.00 on 04-Nov-19 and bharatpe90200249292@yesbankltd credited.Info:UPI-930819333375.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594568614260059008, 'guid': '206E6ED2-8406-F361-48D0-4289C5EFA6AB'}}
# analysis {'expense_amount': 55.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200249292@yesbankltd', 'datetime': datetime.datetime(2019, 11, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db4ad64bdc5152d036a6'), 'message': {'text': 'Acct XXX983 debited with INR23.00 on 04-Nov-19 and paytm-34417709@paytm credited.Info:UPI-930843196754.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594568844518702080, 'guid': '0D80094C-86D9-FF99-4D2B-55399ECC881F'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db4bd64bdc5152d036b1'), 'message': {'text': 'Acct XXX983 debited with INR100.00 on 05-Nov-19 and zerodhabroking@hdfcbank credited.Info:UPI-930917002098.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594649650685480960, 'guid': '45047077-C639-77D5-A3F4-05A68A6028EB'}}
# analysis {'expense_amount': 100.0, 'payment_mode': 'XXX983', 'merchant': 'zerodhabroking@hdfcbank', 'datetime': datetime.datetime(2019, 11, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db4cd64bdc5152d036b9'), 'message': {'text': 'Acct XXX983 debited with INR1000.00 on 05-Nov-19 and add-money@paytm credited.Info:UPI-930945629877.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594663262702523904, 'guid': '7273564F-1749-D5D9-1C73-CC077DD7E0BA'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db4cd64bdc5152d036ba'), 'message': {'text': 'Acct XXX983 debited with INR40.00 on 05-Nov-19 and bharatpe90200249292@yesbankltd credited.Info:UPI-930921285925.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594663879926841984, 'guid': '20493546-514D-C265-948C-500BAF9B10F2'}}
# analysis {'expense_amount': 40.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200249292@yesbankltd', 'datetime': datetime.datetime(2019, 11, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db50d64bdc5152d036e1'), 'message': {'text': 'Acct XXX983 debited with INR60.00 on 12-Nov-19 and bharatpe90200570491@yesbankltd credited.Info:UPI-931617014485.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 595252631580716928, 'guid': '7F5B5392-EE25-B544-5D54-C4DC06B09425'}}
# analysis {'expense_amount': 60.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200570491@yesbankltd', 'datetime': datetime.datetime(2019, 11, 12, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db51d64bdc5152d036e6'), 'message': {'text': 'Acct XXX983 debited with INR12.00 on 12-Nov-19 and sumitasok@okhdfcbank credited.Info:UPI-931622328163.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 595270702340430976, 'guid': 'FD0B81CE-7888-8E01-72B2-006EE19A9BD6'}}
# analysis {'expense_amount': 12.0, 'payment_mode': 'XXX983', 'merchant': 'sumitasok@okhdfcbank', 'datetime': datetime.datetime(2019, 11, 12, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db51d64bdc5152d036e8'), 'message': {'text': 'Acct XXX983 debited with INR1000.00 on 13-Nov-19 and zerodhabroking@hdfcbank credited.Info:UPI-931701045188.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 595281038652113024, 'guid': '84E88C26-C2F4-4DED-A391-389535927753'}}
# analysis {'expense_amount': 1000.0, 'payment_mode': 'XXX983', 'merchant': 'zerodhabroking@hdfcbank', 'datetime': datetime.datetime(2019, 11, 13, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db56d64bdc5152d03713'), 'message': {'text': 'Acct XXX983 debited with INR18.00 on 21-Nov-19 and billdesk.bsnl-prepaid@icici credited.Info:UPI-932510285452.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596004679343335040, 'guid': '370600BB-04BE-497D-9513-3D157F28F3C2'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e46a93a3fdf437c9b43e2c6'), 'message': {'text': 'Acct XXX983 debited with INR18.00 on 21-Nov-19 and billdesk.bsnl-prepaid@icici credited.Info:UPI-932510285452.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596004679343335040, 'guid': '370600BB-04BE-497D-9513-3D157F28F3C2'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db56d64bdc5152d03715'), 'message': {'text': 'Acct XXX983 debited with INR44.00 on 21-Nov-19 and bsnlupi1@fbl credited.Info:UPI-932510293355.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596005200593992960, 'guid': 'E61053C7-6138-A4A3-8595-7555B61EFE46'}}
# analysis {'expense_amount': 44.0, 'payment_mode': 'XXX983', 'merchant': 'bsnlupi1@fbl', 'datetime': datetime.datetime(2019, 11, 21, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db59d64bdc5152d03726'), 'message': {'text': 'Acct XXX983 debited with INR405.00 on 22-Nov-19 and q07991171@ybl credited.Info:UPI-932611026815.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596093467026407040, 'guid': '2C793F13-6433-D7DF-6019-56A61B5C34D4'}}
# analysis {'expense_amount': 405.0, 'payment_mode': 'XXX983', 'merchant': 'q07991171@ybl', 'datetime': datetime.datetime(2019, 11, 22, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db5bd64bdc5152d03739'), 'message': {'text': 'Acct XXX983 debited with INR5833.00 on 25-Nov-19 and sumitasok@hdfcbank credited.Info:UPI-932909057656.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596348108770611072, 'guid': 'BC384E7E-CAC3-0970-7E2D-8D8BD96C3D2D'}}
# analysis {'expense_amount': 5833.0, 'payment_mode': 'XXX983', 'merchant': 'sumitasok@hdfcbank', 'datetime': datetime.datetime(2019, 11, 25, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db5ed64bdc5152d03755'), 'message': {'text': 'Acct XXX983 debited with INR12.00 on 28-Nov-19 and sumitasok@hdfcbank credited.Info:UPI-933222199545.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596653526037372928, 'guid': '42858240-970D-3F36-7475-B521D2143342'}}
# analysis {'expense_amount': 12.0, 'payment_mode': 'XXX983', 'merchant': 'sumitasok@hdfcbank', 'datetime': datetime.datetime(2019, 11, 28, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db63d64bdc5152d03781'), 'message': {'text': 'Acct XXX983 debited with INR22.00 on 03-Dec-19 and sumitasok@hdfcbank credited.Info:UPI-933721017842.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597083246661630080, 'guid': 'DD068A27-296E-0207-3FE5-8A17DFE95BE4'}}
# analysis {'expense_amount': 22.0, 'payment_mode': 'XXX983', 'merchant': 'sumitasok@hdfcbank', 'datetime': datetime.datetime(2019, 12, 3, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db65d64bdc5152d03790'), 'message': {'text': 'Acct XXX983 debited with INR50.00 on 06-Dec-19 and bharatpe90200570491@yesbankltd credited.Info:UPI-934016164251.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597324064627881088, 'guid': 'EB3DC43C-0873-0BE2-0AA7-BD081517A102'}}
# analysis {'expense_amount': 50.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200570491@yesbankltd', 'datetime': datetime.datetime(2019, 12, 6, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db66d64bdc5152d03794'), 'message': {'text': 'Acct XXX983 debited with INR329.00 on 08-Dec-19 and reliancejio@hdfcbank credited.Info:UPI-934217347908.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597500013432171008, 'guid': '6C652F91-9B67-5B03-65A1-44C97650F1D4'}}
# analysis {'expense_amount': 329.0, 'payment_mode': 'XXX983', 'merchant': 'reliancejio@hdfcbank', 'datetime': datetime.datetime(2019, 12, 8, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db66d64bdc5152d03797'), 'message': {'text': 'Acct XXX983 debited with INR45.26 on 08-Dec-19 and zomato@hdfcbank credited.Info:UPI-934221376360.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597513056611577088, 'guid': 'AC20E90A-3B7F-79ED-6BBD-FB53CA7259E5'}}
# analysis {'expense_amount': 45.26, 'payment_mode': 'XXX983', 'merchant': 'zomato@hdfcbank', 'datetime': datetime.datetime(2019, 12, 8, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db66d64bdc5152d0379c'), 'message': {'text': 'Acct XXX983 debited with INR90.00 on 09-Dec-19 and q71845857@ybl credited.Info:UPI-934318087552.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597590168408044032, 'guid': 'CC4A57E1-8E02-6338-FF23-4307976395A3'}}
# analysis {'expense_amount': 90.0, 'payment_mode': 'XXX983', 'merchant': 'q71845857@ybl', 'datetime': datetime.datetime(2019, 12, 9, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db67d64bdc5152d037a3'), 'message': {'text': 'Acct XXX983 debited with INR100.00 on 10-Dec-19 and add-money@paytm credited.Info:UPI-934433454175.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597644784967293952, 'guid': 'CBAA5257-3817-8696-F0CA-44448CAEB947'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db68d64bdc5152d037a8'), 'message': {'text': 'Acct XXX983 debited with INR50.00 on 11-Dec-19 and BHARATPE90200570491@yesbankltd credited.Info:UPI-934540227115.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597754875421702016, 'guid': 'B95EEC7B-821B-8A04-FA02-E4D4E357EBE7'}}
# analysis {'expense_amount': 50.0, 'payment_mode': 'XXX983', 'merchant': 'BHARATPE90200570491@yesbankltd', 'datetime': datetime.datetime(2019, 12, 11, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db69d64bdc5152d037b3'), 'message': {'text': 'Acct XXX983 debited with INR50.00 on 13-Dec-19 and bharatpe90200570491@yesbankltd credited.Info:UPI-934715041259.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597923435852444032, 'guid': '6C827D82-A6A2-5285-26C0-F44A0DB417B5'}}
# analysis {'expense_amount': 50.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200570491@yesbankltd', 'datetime': datetime.datetime(2019, 12, 13, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db69d64bdc5152d037b4'), 'message': {'text': 'Acct XXX983 debited with INR60.00 on 13-Dec-19 and bharatpe90200249292@yesbankltd credited.Info:UPI-934717260554.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597932665644472960, 'guid': '0144255B-18B7-9EFB-40CC-2F76F9ED1E8A'}}
# analysis {'expense_amount': 60.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200249292@yesbankltd', 'datetime': datetime.datetime(2019, 12, 13, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db69d64bdc5152d037b5'), 'message': {'text': 'Acct XXX983 debited with INR40.00 on 13-Dec-19 and q28746679@ybl credited.Info:UPI-934717282336.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597932918085254016, 'guid': 'A729012A-9006-30DB-4936-E98D02F10BF3'}}
# analysis {'expense_amount': 40.0, 'payment_mode': 'XXX983', 'merchant': 'q28746679@ybl', 'datetime': datetime.datetime(2019, 12, 13, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db69d64bdc5152d037b6'), 'message': {'text': 'Acct XXX983 debited with INR136.00 on 13-Dec-19 and zomato@hdfcbank credited.Info:UPI-934718462897.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597934830042426880, 'guid': '30D73275-093B-F7B6-608F-34A6A459370D'}}
# analysis {'expense_amount': 136.0, 'payment_mode': 'XXX983', 'merchant': 'zomato@hdfcbank', 'datetime': datetime.datetime(2019, 12, 13, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db6ad64bdc5152d037bb'), 'message': {'text': 'Acct XXX983 debited with INR931.00 on 14-Dec-19 and paytmqr281005050101vw0veuje5ppb@paytm credited.Info:UPI-934808140026.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597985075245532032, 'guid': '341A2BFE-8F8B-03F9-B0F4-BCFE69926F40'}}
# analysis {'expense_amount': 931.0, 'payment_mode': 'XXX983', 'merchant': 'paytmqr281005050101vw0veuje5ppb@paytm', 'datetime': datetime.datetime(2019, 12, 14, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db6bd64bdc5152d037be'), 'message': {'text': 'Acct XXX983 debited with INR219.00 on 14-Dec-19 and zomato-order@paytm credited.Info:UPI-934822372696.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598034977218830976, 'guid': '62895F39-017C-10E8-A69E-05A86F7049A0'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db6cd64bdc5152d037c7'), 'message': {'text': 'Acct XXX983 debited with INR40.00 on 18-Dec-19 and bharatpe90200570491@yesbankltd credited.Info:UPI-935216209540.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598357999798145024, 'guid': 'BD730D18-4071-4F10-7BDA-CD90B06C7D93'}}
# analysis {'expense_amount': 40.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200570491@yesbankltd', 'datetime': datetime.datetime(2019, 12, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db6cd64bdc5152d037c9'), 'message': {'text': 'Acct XXX983 debited with INR738.00 on 18-Dec-19 and amazon@apl credited.Info:UPI-935223841908.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598385579145298944, 'guid': 'E79D5C52-E853-49B3-8511-1B17F222DD75'}}
# analysis {'expense_amount': 738.0, 'payment_mode': 'XXX983', 'merchant': 'amazon@apl', 'datetime': datetime.datetime(2019, 12, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db6ed64bdc5152d037d8'), 'message': {'text': 'Acct XXX983 debited with INR250.00 on 20-Dec-19 and vijualoor@okhdfcbank credited.Info:UPI-935410461711.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598512034617570048, 'guid': 'E179752F-EC3B-C475-2089-69BDBA098CFD'}}
# analysis {'expense_amount': 250.0, 'payment_mode': 'XXX983', 'merchant': 'vijualoor@okhdfcbank', 'datetime': datetime.datetime(2019, 12, 20, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db6ed64bdc5152d037d9'), 'message': {'text': 'Acct XXX983 debited with INR310.76 on 20-Dec-19 and zomato-order@paytm credited.Info:UPI-935421196685.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598550402042536064, 'guid': '71DE2055-8430-88A4-A3EE-21C8CF69A7FB'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db71d64bdc5152d037f3'), 'message': {'text': 'Acct XXX983 debited with INR70.00 on 23-Dec-19 and wiresandsparesmixies.98665416@hdfcbank credited.Info:UPI-935718358319.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598797299569468928, 'guid': '6E6E5908-1AF2-1F74-D2D5-26A0DC1ECA87'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db71d64bdc5152d037f4'), 'message': {'text': 'Acct XXX983 debited with INR1300.00 on 26-Dec-19 and wiresandsparesmixies.98665416@hdfcbank credited.Info:UPI-936015423282.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599047986244081024, 'guid': 'C41D8135-5FF1-13D2-114E-473916219251'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db73d64bdc5152d03803'), 'message': {'text': 'Acct XXX983 debited with INR1755.40 on 28-Dec-19 and googtravel@axisbank credited.Info:UPI-936216204083.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599225105204764928, 'guid': '17D94A6F-E130-D60B-C633-7A98084A5736'}}
# analysis {'expense_amount': 1755.4, 'payment_mode': 'XXX983', 'merchant': 'googtravel@axisbank', 'datetime': datetime.datetime(2019, 12, 28, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db73d64bdc5152d03804'), 'message': {'text': 'Acct XXX983 debited with INR1545.40 on 28-Dec-19 and googtravel@axisbank credited.Info:UPI-936217237032.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599225441834825088, 'guid': '27A4EA9C-BF9F-539C-7367-FFAFD672F4AD'}}
# analysis {'expense_amount': 1545.4, 'payment_mode': 'XXX983', 'merchant': 'googtravel@axisbank', 'datetime': datetime.datetime(2019, 12, 28, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db73d64bdc5152d03809'), 'message': {'text': 'Acct XXX983 debited with INR200.00 on 28-Dec-19 and q44979700@ybl credited.Info:UPI-936218344412.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599231537250332032, 'guid': '49ABF2A2-389F-79C8-B8D2-67983F3985FA'}}
# analysis {'expense_amount': 200.0, 'payment_mode': 'XXX983', 'merchant': 'q44979700@ybl', 'datetime': datetime.datetime(2019, 12, 28, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db74d64bdc5152d0380b'), 'message': {'text': 'Acct XXX983 debited with INR1600.00 on 29-Dec-19 and wiresandsparesmixies.98665416@hdfcbank credited.Info:UPI-936310020730.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599287708549520000, 'guid': 'C0ECD975-D88F-512B-C175-BFF5A252C7DC'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db77d64bdc5152d03827'), 'message': {'text': 'Acct XXX983 debited with INR700.00 on 03-Jan-20 and add-money@paytm credited.Info:UPI-000313468012.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599729431036901888, 'guid': '3F629A20-1E4A-EE41-93FB-4C93F9E57FC4'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db77d64bdc5152d0382a'), 'message': {'text': 'Acct XXX983 debited with INR12.00 on 03-Jan-20 and chinjuprakasan90@okhdfcbank credited.Info:UPI-000316444192.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599742304999963008, 'guid': '2EFB65DE-6ACC-8751-2CC2-B5FF57F35C73'}}
# analysis {'expense_amount': 12.0, 'payment_mode': 'XXX983', 'merchant': 'chinjuprakasan90@okhdfcbank', 'datetime': datetime.datetime(2020, 1, 3, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db78d64bdc5152d0382b'), 'message': {'text': 'Acct XXX983 debited with INR850.00 on 03-Jan-20 and greenzie.98836485@hdfcbank credited.Info:UPI-000319492650.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599753114260136064, 'guid': 'D1AC5DB3-1A63-1738-6A28-5E3BBE5E2F67'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db7bd64bdc5152d03849'), 'message': {'text': 'Acct XXX983 debited with INR327.50 on 05-Jan-20 and zomato-order@paytm credited.Info:UPI-000514196164.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599907361630696064, 'guid': 'A19BB34C-8F0E-4021-19DD-229329888E67'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db7dd64bdc5152d0385b'), 'message': {'text': 'Acct XXX983 debited with INR28.00 on 07-Jan-20 and paytmqr2810050501011f9xdbj3suxl@paytm credited.Info:UPI-000718423610.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600093955553542912, 'guid': 'AF18E7A0-155E-23C5-EAA6-635DE99B36B4'}}
# analysis {'expense_amount': 28.0, 'payment_mode': 'XXX983', 'merchant': 'paytmqr2810050501011f9xdbj3suxl@paytm', 'datetime': datetime.datetime(2020, 1, 7, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db7ed64bdc5152d03863'), 'message': {'text': 'Acct XXX983 debited with INR85.00 on 08-Jan-20 and paytmqr2810050501011f9xdbj3suxl@paytm credited.Info:UPI-000814479998.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600167002562502016, 'guid': 'BA040BA3-5B6B-DF4E-C3AA-D6F1486517DE'}}
# analysis {'expense_amount': 85.0, 'payment_mode': 'XXX983', 'merchant': 'paytmqr2810050501011f9xdbj3suxl@paytm', 'datetime': datetime.datetime(2020, 1, 8, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db7fd64bdc5152d0386a'), 'message': {'text': 'Acct XXX983 debited with INR1000.00 on 09-Jan-20 and add-money@paytm credited.Info:UPI-000912864724.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600245276467442048, 'guid': '1B431C48-70F3-E666-2196-4E5E7A739A9E'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db83d64bdc5152d0388f'), 'message': {'text': 'Acct XXX983 debited with INR28.00 on 14-Jan-20 and BHARATPE90200257812@yesbankltd credited.Info:UPI-001419780819.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600703171334236928, 'guid': '9CD90CAC-3062-41EC-B9BC-48E8D9548C7E'}}
# analysis {'expense_amount': 28.0, 'payment_mode': 'XXX983', 'merchant': 'BHARATPE90200257812@yesbankltd', 'datetime': datetime.datetime(2020, 1, 14, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db88d64bdc5152d038bb'), 'message': {'text': 'Acct XXX983 debited with INR1905.40 on 19-Jan-20 and googtravel@axisbank credited.Info:UPI-001914365285.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601120486202475008, 'guid': 'CF987140-AFD5-1A4B-8AD1-D794FCCFA281'}}
# analysis {'expense_amount': 1905.4, 'payment_mode': 'XXX983', 'merchant': 'googtravel@axisbank', 'datetime': datetime.datetime(2020, 1, 19, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db8ad64bdc5152d038cd'), 'message': {'text': 'Acct XXX983 debited with INR1000.00 on 20-Jan-20 and add-money@paytm credited.Info:UPI-002019024282.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601221753087609984, 'guid': '58E2101B-C6D1-4C8B-8879-1F7A5B7E89D6'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e288929546d0b8e7aa1eba1'), 'message': {'text': 'Acct XXX983 debited with INR130.00 on 21-Jan-20 and paytmqr281005050101i59jhuhgndi1@paytm credited.Info:UPI-002119181841.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601313706551071104, 'guid': 'DEDC90E9-A990-3944-0179-A15D3CC2ACF3'}}
# analysis {'expense_amount': 130.0, 'payment_mode': 'XXX983', 'merchant': 'paytmqr281005050101i59jhuhgndi1@paytm', 'datetime': datetime.datetime(2020, 1, 21, 0, 0)}
#
#
# message {'_id': ObjectId('5e288929546d0b8e7aa1eba2'), 'message': {'text': 'Acct XXX983 debited with INR220.00 on 21-Jan-20 and kgyqde2861@paytm credited.Info:UPI-002121079903.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601317408468883968, 'guid': '50ED988D-39BD-8E4A-0346-5CBD3675104E'}}
# analysis {'expense_amount': 220.0, 'payment_mode': 'XXX983', 'merchant': 'kgyqde2861@paytm', 'datetime': datetime.datetime(2020, 1, 21, 0, 0)}
#
#
# message {'_id': ObjectId('5e2ea50e7d9a1886601c0bba'), 'message': {'text': 'Acct XXX983 debited with INR214.00 on 24-Jan-20 and dunzo.payu@hdfcbank credited.Info:UPI-002423248246.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601580517089737088, 'guid': '36B5DC5F-08D2-0744-C7DE-79174E79D9D0'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e3a782c85ce1ed04ce1b69a'), 'message': {'text': 'Acct XXX983 debited with INR200.00 on 28-Jan-20 and paytmqr2810050501011f9xdbj3suxl@paytm credited.Info:UPI-002820292488.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601915141695790976, 'guid': '988468AF-B987-510F-E315-294F3B5270FB'}}
# analysis {'expense_amount': 200.0, 'payment_mode': 'XXX983', 'merchant': 'paytmqr2810050501011f9xdbj3suxl@paytm', 'datetime': datetime.datetime(2020, 1, 28, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a783385ce1ed04ce1b6cc'), 'message': {'text': 'Acct XXX983 debited with INR60.00 on 04-Feb-20 and bharatpe90200570491@yesbankltd credited.Info:UPI-003516231101.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602507332447206016, 'guid': '1F400656-7661-EF41-C171-4920FBD3CF97'}}
# analysis {'expense_amount': 60.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200570491@yesbankltd', 'datetime': datetime.datetime(2020, 2, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a783485ce1ed04ce1b6ce'), 'message': {'text': 'Acct XXX983 debited with INR168.00 on 04-Feb-20 and bharatpe.9040576993@icici credited.Info:UPI-003522386132.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602529171835697024, 'guid': '15C1DE5F-0B0E-3434-7A79-A8AC5ABA7BA5'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e3e5b35dd2322b0ad5cccf7'), 'message': {'text': 'Acct XXX983 debited with INR60.00 on 06-Feb-20 and bharatpe90200570491@yesbankltd credited.Info:UPI-003717485126.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602682752318349952, 'guid': '07991290-E405-492C-4717-7D1EC7622275'}}
# analysis {'expense_amount': 60.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200570491@yesbankltd', 'datetime': datetime.datetime(2020, 2, 6, 0, 0)}
#
#
# message {'_id': ObjectId('5e40f96a637cbe765df7dd7c'), 'message': {'text': 'Acct XXX983 debited with INR136.00 on 08-Feb-20 and zomato@hdfcbank credited.Info:UPI-003921079421.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602870700584781056, 'guid': '0284708D-459B-9328-BC23-5DECC5A2D7FD'}}
# analysis {'expense_amount': 136.0, 'payment_mode': 'XXX983', 'merchant': 'zomato@hdfcbank', 'datetime': datetime.datetime(2020, 2, 8, 0, 0)}
#
#
# message {'_id': ObjectId('5e46a6ab435652b77cb5c01e'), 'message': {'text': 'Acct XXX983 debited with INR280.00 on 11-Feb-20 and vijualoor@okhdfcbank credited.Info:UPI-004220148926.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 603125261218690048, 'guid': '3C9BC9BE-D221-D430-60B6-A026DFB201E7'}}
# analysis {'expense_amount': 280.0, 'payment_mode': 'XXX983', 'merchant': 'vijualoor@okhdfcbank', 'datetime': datetime.datetime(2020, 2, 11, 0, 0)}
#
#
# message {'_id': ObjectId('5e46a6ab435652b77cb5c023'), 'message': {'text': 'Acct XXX983 debited with INR80.00 on 13-Feb-20 and bharatpe90200570491@yesbankltd credited.Info:UPI-004414126838.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 603277083227789952, 'guid': '9FE7FE7D-1295-975F-8464-10819A7BA094'}}
# analysis {'expense_amount': 80.0, 'payment_mode': 'XXX983', 'merchant': 'bharatpe90200570491@yesbankltd', 'datetime': datetime.datetime(2020, 2, 13, 0, 0)}
#
#
# message {'_id': ObjectId('5e46a6ab435652b77cb5c026'), 'message': {'text': 'Acct XXX983 debited with INR1709.10 on 13-Feb-20 and amazonsellerservices.98397377@hdfcbank credited.Info:UPI-004420017660.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 603297578671529984, 'guid': '897336CF-D029-EAEE-9525-12C43E1E4E3C'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e4c15874d76059dbcf77834'), 'message': {'text': 'Acct XXX983 debited with INR210.00 on 18-Feb-20 and bharatpe09600003315¡yesbankltd credited.Info:UPI-004919457521.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 603726939660899072, 'guid': '8F90E582-F997-6F60-74C0-449443F4C9F6'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e50de58a8ef7cb503f2d331'), 'message': {'text': 'Acct XXX983 debited with INR70.00 on 19-Feb-20 and bharatpe90200570491¡yesbankltd credited.Info:UPI-005015401728.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 603801312442396032, 'guid': 'DABF120B-BF00-60E0-36EB-197768A7C4CA'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e58bc840f2926acec7e6577'), 'message': {'text': 'Acct XXX983 debited with INR70.00 on 25-Feb-20 and cru5ty.d3m0nx-2@okhdfcbank credited.Info:UPI-005616427398.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 604320004521337088, 'guid': 'FB693769-4700-2FEA-3EA6-A55591F019FA'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e58bc840f2926acec7e657d'), 'message': {'text': 'Acct XXX983 debited with INR10.00 on 26-Feb-20 and q22904860@ybl credited.Info:UPI-005715374127.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 604404422681974016, 'guid': 'BD4BADAC-0596-5836-5E83-DAD40EF81808'}}
# analysis {'expense_amount': 10.0, 'payment_mode': 'XXX983', 'merchant': 'q22904860@ybl', 'datetime': datetime.datetime(2020, 2, 26, 0, 0)}

# %%
for _item in list(
    enumerate(
        collection.find({
            "message.text": {'$regex': 'ALERT: You\'ve spent Rs.([0-9.]+)'},
            "status.analysis_done": {'$ne': True}}
        ).sort([("message.date",1)]))):
    print("message", _item[1])
    _transaction = hdfcCreditCardInterpreter(_item[1]['message']['text'])
    print("analysis", _transaction, "\n\n")
    result = collection.update_one(
        {'_id': bson.ObjectId(str(_item[1]['_id']))},
        {'$set' : {'transaction': _transaction, 'status': {'analysis_done': True}}})
    print('success' if result.modified_count == 1 else 'unsuccessful')
    
for _item in list(
    enumerate(
        collection.find({
            "message.text": {'$regex': 'ALERT:You\'ve spent Rs.([0-9.]+) on'},
            "status.analysis_done": {'$ne': True}} #             
        ).sort([("message.date",1)]))):
    print("message", _item[1])
    _transaction = hdfcCreditCardInterpreter2(_item[1]['message']['text'])
    print("analysis", _transaction, "\n\n")
    if _transaction != {}:
        result = collection.update_one(
            {'_id': bson.ObjectId(str(_item[1]['_id']))},
            {'$set' : {'transaction': _transaction, 'status': {'analysis_done': True}}})
        print('success' if result.modified_count == 1 else 'unsuccessful')
        
for _item in list(
    enumerate(
        collection.find({
            "message.text": {'$regex': 'ALERT:You\'ve spent Rs.([0-9.]+) via'},
} #             "status.analysis_done": {'$ne': True}
        ).sort([("message.date",1)]))):
    print("message", _item[1])
    _transaction = hdfcCreditCardInterpreterVia(_item[1]['message']['text'])
    print("analysis", _transaction, "\n\n")
    if _transaction != {}:
        result = collection.update_one(
            {'_id': bson.ObjectId(str(_item[1]['_id']))},
            {'$set' : {'transaction': _transaction, 'status': {'analysis_done': True}}})
        print('success' if result.modified_count == 1 else 'unsuccessful')
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-4-66439441e052> in <module>
#       4             "message.text": {'$regex': 'ALERT: You\'ve spent Rs.([0-9.]+)'},
#       5             "status.analysis_done": {'$ne': True}}
# ----> 6         ).sort([("message.date",1)]))):
#       7     print("message", _item[1])
#       8     _transaction = hdfcCreditCardInterpreter(_item[1]['message']['text'])
#
# /opt/conda/lib/python3.7/site-packages/pymongo/cursor.py in next(self)
#    1154         if self.__empty:
#    1155             raise StopIteration
# -> 1156         if len(self.__data) or self._refresh():
#    1157             if self.__manipulate:
#    1158                 _db = self.__collection.database
#
# /opt/conda/lib/python3.7/site-packages/pymongo/cursor.py in _refresh(self)
#    1048
#    1049         if not self.__session:
# -> 1050             self.__session = self.__collection.database.client._ensure_session()
#    1051
#    1052         if self.__id is None:  # Query
#
# /opt/conda/lib/python3.7/site-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1808             # Don't make implicit sessions causally consistent. Applications
#    1809             # should always opt-in.
# -> 1810             return self.__start_session(True, causal_consistency=False)
#    1811         except (ConfigurationError, InvalidOperation):
#    1812             # Sessions not supported, or multiple users authenticated.
#
# /opt/conda/lib/python3.7/site-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1761
#    1762         # Raises ConfigurationError if sessions are not supported.
# -> 1763         server_session = self._get_server_session()
#    1764         opts = client_session.SessionOptions(**kwargs)
#    1765         return client_session.ClientSession(
#
# /opt/conda/lib/python3.7/site-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1794     def _get_server_session(self):
#    1795         """Internal: start or resume a _ServerSession."""
# -> 1796         return self._topology.get_server_session()
#    1797
#    1798     def _return_server_session(self, server_session, lock):
#
# /opt/conda/lib/python3.7/site-packages/pymongo/topology.py in get_server_session(self)
#     483                             any_server_selector,
#     484                             self._settings.server_selection_timeout,
# --> 485                             None)
#     486                 elif not self._description.readable_servers:
#     487                     self._select_servers_loop(
#
# /opt/conda/lib/python3.7/site-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     207             if timeout == 0 or now > end_time:
#     208                 raise ServerSelectionTimeoutError(
# --> 209                     self._error_message(selector))
#     210
#     211             self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused

# %%
year = 2020
month = 2

next_month = 1 if month == 12 else month + 1
next_year = year + 1 if month == 12 else year

monthly = list(enumerate(collection.find({'status': {'analysis_done': True},
                 'transaction.datetime' : {
                     '$gte': datetime.datetime(year,month,1), '$lt': datetime.datetime(next_year,next_month,1)}
                  }, {'transaction': 1})))

monthly_transactions = list(map(extract_transactions, monthly))

# %%
display(HTML(tabulate.tabulate(monthly_transactions, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td style="text-align: right;">  500   </td><td>CREDIT Card xx3690</td><td>PAYTM                                 </td><td>2020-02-02 20:44:58</td><td>272486.89               </td><td style="text-align: right;">27513.1</td><td>5e3a783285ce1ed04ce1b6c3</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  465.5 </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510                       </td><td>2020-02-02 20:42:47</td><td>272986.5                </td><td style="text-align: right;">27013.5</td><td>5e3a783285ce1ed04ce1b6c4</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  465.5 </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510 in BANGALORE          </td><td>2020-02-02 20:42:48</td><td>5e3a783285ce1ed04ce1b6c5</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  400   </td><td>CREDIT Card xx3690</td><td>PAYTM3852398                          </td><td>2020-02-02 20:49:59</td><td>272086.89               </td><td style="text-align: right;">27913.1</td><td>5e3a783285ce1ed04ce1b6c6</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  199   </td><td>Debit Card xx1827 </td><td>NETFLIX ENTERTAINMENT                 </td><td>2020-02-03 19:28:14</td><td>5e3a783385ce1ed04ce1b6ca</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  500   </td><td>CREDIT Card xx3690</td><td>PAYTM3852398                          </td><td>2020-02-03 23:14:18</td><td>271586.0                </td><td style="text-align: right;">28414  </td><td>5e3a783385ce1ed04ce1b6cb</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">   60   </td><td>XXX983            </td><td>bharatpe90200570491@yesbankltd        </td><td>2020-02-04 00:00:00</td><td>5e3a783385ce1ed04ce1b6cc</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">   60   </td><td>XXX983            </td><td>bharatpe90200570491@yesbankltd        </td><td>2020-02-06 00:00:00</td><td>5e3e5b35dd2322b0ad5cccf7</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;"> 1514.37</td><td>CREDIT Card xx3690</td><td>www.bigbasket.                        </td><td>2020-02-06 22:08:21</td><td>270071.63               </td><td style="text-align: right;">29928.4</td><td>5e3e5b35dd2322b0ad5cccfa</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  588   </td><td>CREDIT Card xx3690</td><td>MYNTRA72883                           </td><td>2020-02-06 22:50:28</td><td>269484.52               </td><td style="text-align: right;">30515.5</td><td>5e3e5b35dd2322b0ad5cccfc</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  606   </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510                       </td><td>2020-02-07 10:39:43</td><td>268878.0                </td><td style="text-align: right;">31122  </td><td>5e3e5b35dd2322b0ad5cccff</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  606   </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510 in BANGALORE          </td><td>2020-02-07 10:39:44</td><td>5e3e5b35dd2322b0ad5ccd00</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;"> 1204.35</td><td>CREDIT Card xx3690</td><td>AJIO                                  </td><td>2020-02-07 11:22:23</td><td>267674.17               </td><td style="text-align: right;">32325.8</td><td>5e3e5b36dd2322b0ad5ccd02</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  136   </td><td>XXX983            </td><td>zomato@hdfcbank                       </td><td>2020-02-08 00:00:00</td><td>5e40f96a637cbe765df7dd7c</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  212   </td><td>CREDIT Card xx3690</td><td>SWIGGY                                </td><td>2020-02-10 10:09:35</td><td>267462.0                </td><td style="text-align: right;">32538  </td><td>5e4255e6112fba20f1b03b67</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  200   </td><td>CREDIT Card xx3690</td><td>SWIGGY                                </td><td>2020-02-10 20:54:05</td><td>267262.17               </td><td style="text-align: right;">32737.8</td><td>5e4255e6112fba20f1b03b6a</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  404   </td><td>CREDIT Card xx3690</td><td>SWIGGY                                </td><td>2020-02-10 22:37:50</td><td>266858.17               </td><td style="text-align: right;">33141.8</td><td>5e4255e7112fba20f1b03b6c</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  610   </td><td>CREDIT Card xx3690</td><td>..MATTO COFFEA_                       </td><td>2020-02-11 16:54:42</td><td>266248.0                </td><td style="text-align: right;">33752  </td><td>5e46a6ab435652b77cb5c01d</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  280   </td><td>XXX983            </td><td>vijualoor@okhdfcbank                  </td><td>2020-02-11 00:00:00</td><td>5e46a6ab435652b77cb5c01e</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">   80   </td><td>XXX983            </td><td>bharatpe90200570491@yesbankltd        </td><td>2020-02-13 00:00:00</td><td>5e46a6ab435652b77cb5c023</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  757   </td><td>CREDIT Card xx3690</td><td>NEW FRUIT LAND                        </td><td>2020-02-13 17:53:10</td><td>265491.0                </td><td style="text-align: right;">34509  </td><td>5e46a6ab435652b77cb5c024</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;"> 1700   </td><td>CREDIT Card xx3690</td><td>HINDUSTAN PETROLEUM CO                </td><td>2020-02-13 18:08:16</td><td>263791.17               </td><td style="text-align: right;">36208.8</td><td>5e46a6ab435652b77cb5c025</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">   65   </td><td>PAYTM             </td><td>Paratha Corner                        </td><td>2020-02-01 20:32:01</td><td>5e46a93d3fdf437c9b43e2f3</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">   90.6 </td><td>PAYTM             </td><td>UBER                                  </td><td>2020-02-01 22:57:31</td><td>5e46a93d3fdf437c9b43e2f4</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  102.96</td><td>PAYTM             </td><td>UBER                                  </td><td>2020-02-03 15:53:25</td><td>5e46a93d3fdf437c9b43e2f5</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  115.93</td><td>PAYTM             </td><td>UBER

# %%
# add_category_info(collection, '5e497fb75bc90c80c1c82a81', category='purchase', sub_category='toys')
# Out:
# success

# %%
# Txn of INR 970.00 done on Acct XX983 on 01-Feb-20.Info: VPS*PAY Sreen.Avbl Bal:INR 13,481.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766
# Txn of INR ([0-9.]+) done on Acct ([X0-9]+) on (\d{1,2}-([a-zA-Z]){3}-\d{2,4}).Info: ([a-zA-Z0-9\s._//*]+)?Avbl Bal:INR ([\d,]+.[\d]{2})?.

iciciUPIInterpreterFormatStr2 = '%d-%b-%y'
def iciciUPIInterpreter2(txn):
    x = re.search("Txn of INR ([0-9.]+) done on Acct ([X0-9]+) on (\d{1,2}-([a-zA-Z]){3}-\d{2,4}).Info: ([a-zA-Z0-9\s._//*]+)?Avbl Bal:INR ([\d,]+.[\d]{2})?.", txn)
    return {
        'expense_amount': float(x.group(1)),
        'payment_mode': x.group(2),
        'merchant': x.group(5).strip(),
        'datetime': datetime.datetime.strptime(x.group(3), iciciUPIInterpreterFormatStr)
    } if x != None else {}
#     return x

for _item in list(
    enumerate(
        collection.find({
            "message.text": {'$regex': 'Txn of INR ([0-9.]+) done on Acct ([X0-9]+) on'},
            "status.analysis_done": {'$ne': True}}
        ).sort([("message.date",1)]))):
    print("message", _item[1])
    _transaction = iciciUPIInterpreter2(_item[1]['message']['text'])
    print("analysis", _transaction, "\n\n")
    result = collection.update_one(
        {'_id': bson.ObjectId(str(_item[1]['_id']))},
        {'$set' : {'transaction': _transaction, 'status': {'analysis_done': True}}})
    print('success' if result.modified_count == 1 else 'unsuccessful')
# Out:
# message {'_id': ObjectId('5e26dad5d64bdc5152d03355'), 'message': {'text': 'Txn of INR 199.00 done on Acct XX1983 on 20-Feb-19.Info: VIN*ITUNES CO.Avbl Bal:INR 12,112.07.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 572324444443048960, 'guid': 'BF8E98A6-07B9-2C3C-BF33-33710568A78B'}}
# analysis {'expense_amount': 199.0, 'payment_mode': 'XX1983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 2, 20, 0, 0)}
#
#
# message {'_id': ObjectId('5e26dadfd64bdc5152d03399'), 'message': {'text': 'Txn of INR 79.00 done on Acct XX1983 on 05-Mar-19.Info: VIN*ITUNES CO.Avbl Bal:INR 12,033.07.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 573473703451655040, 'guid': 'F9659202-15E3-8160-7305-A1BF4C8ED47D'}}
# analysis {'expense_amount': 79.0, 'payment_mode': 'XX1983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 3, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26dae0d64bdc5152d0339c'), 'message': {'text': 'Txn of INR 75.00 done on Acct XX1983 on 07-Mar-19.Info: VIN*ITUNES CO.Avbl Bal:INR 11,958.07.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 573613577369200000, 'guid': '3457AB2E-6677-1F43-3870-031362FCD6DA'}}
# analysis {'expense_amount': 75.0, 'payment_mode': 'XX1983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 3, 7, 0, 0)}
#
#
# message {'_id': ObjectId('5e26dae2d64bdc5152d033a9'), 'message': {'text': 'Txn of INR 120.00 done on Acct XX1983 on 10-MAR-19.Info: VIN*ITUNES CO.Avbl Bal:INR 11,324.07.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 573918162680660032, 'guid': '62BDDA70-DD35-1109-F68D-FD17A52E7F1F'}}
# analysis {'expense_amount': 120.0, 'payment_mode': 'XX1983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 3, 10, 0, 0)}
#
#
# message {'_id': ObjectId('5e26dae4d64bdc5152d033b8'), 'message': {'text': 'Txn of INR 945.61 done on Acct XX1983 on 17-MAR-19.Info: VIN*PAYPAL  N.Avbl Bal:INR 10,892.46.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 574498959332028032, 'guid': '0D8DFE86-2E4F-5159-402D-F11E9C038BDC'}}
# analysis {'expense_amount': 945.61, 'payment_mode': 'XX1983', 'merchant': 'VIN*PAYPAL  N.', 'datetime': datetime.datetime(2019, 3, 17, 0, 0)}
#
#
# message {'_id': ObjectId('5e26daedd64bdc5152d033f2'), 'message': {'text': 'Txn of INR 75.00 done on Acct XX1983 on 07-APR-19.Info: VIN*ITUNES CO.Avbl Bal:INR 10,905.76.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 576288336890462976, 'guid': '8426321C-50B7-BAA7-CB04-D0CD49DF421F'}}
# analysis {'expense_amount': 75.0, 'payment_mode': 'XX1983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 4, 7, 0, 0)}
#
#
# message {'_id': ObjectId('5e26daeed64bdc5152d033f6'), 'message': {'text': 'Txn of INR 100.00 done on Acct XX1983 on 07-APR-19.Info: VIN*SBIETC   .Avbl Bal:INR 10,805.76.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 576310078799255040, 'guid': 'B74A5E24-2B43-041C-09AA-4D9408BC9DF5'}}
# analysis {'expense_amount': 100.0, 'payment_mode': 'XX1983', 'merchant': 'VIN*SBIETC   .', 'datetime': datetime.datetime(2019, 4, 7, 0, 0)}
#
#
# message {'_id': ObjectId('5e26daefd64bdc5152d033fb'), 'message': {'text': 'Txn of INR 470.00 done on Acct XX1983 on 09-Apr-19.Info: VIN*SBIETC   .Avbl Bal:INR 10,335.76.Call 18601207777 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 576499961099449984, 'guid': '2081ACA4-4503-4954-50DB-87451C2297EF'}}
# analysis {'expense_amount': 470.0, 'payment_mode': 'XX1983', 'merchant': 'VIN*SBIETC   .', 'datetime': datetime.datetime(2019, 4, 9, 0, 0)}
#
#
# message {'_id': ObjectId('5e26daf1d64bdc5152d03407'), 'message': {'text': 'Txn of INR 99.00 done on Acct XX1983 on 10-Apr-19.Info: VIN*ITUNES CO.Avbl Bal:INR 10,236.76.Call 18002662 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 576596560729655936, 'guid': 'E7EF9521-A098-7BE8-579B-F08BED612DA6'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'XX1983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 4, 10, 0, 0)}
#
#
# message {'_id': ObjectId('5e26daf3d64bdc5152d03417'), 'message': {'text': 'Txn of INR 699.00 done on Acct XX1983 on 14-APR-19.Info: VPS*SCUBER FO.Avbl Bal:INR 3,361.76.Call 18002662 for dispute or SMS BLOCK 1983 to 9215676766', 'date': 576939599512311040, 'guid': '8E679A5A-8CFA-58F0-B89F-8D0668DC6BDE'}}
# analysis {'expense_amount': 699.0, 'payment_mode': 'XX1983', 'merchant': 'VPS*SCUBER FO.', 'datetime': datetime.datetime(2019, 4, 14, 0, 0)}
#
#
# message {'_id': ObjectId('5e26dafad64bdc5152d0344b'), 'message': {'text': 'Txn of INR 380.00 done on Acct XX983 on 03-Jun-19.Info: IPS*M K RETAI.Avbl Bal:INR 14,576.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 581255866397539072, 'guid': 'E1DCD889-82DD-4FF8-D6FB-94E4DB1BA276'}}
# analysis {'expense_amount': 380.0, 'payment_mode': 'XX983', 'merchant': 'IPS*M K RETAI.', 'datetime': datetime.datetime(2019, 6, 3, 0, 0)}
#
#
# message {'_id': ObjectId('5e26dafbd64bdc5152d0344e'), 'message': {'text': 'Txn of INR 337.61 done on Acct XX983 on 04-Jun-19.Info: IPS*M K RETAI.Avbl Bal:INR 14,239.15.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 581351397147096960, 'guid': '56AC7B3C-C5BC-2CB2-5BC2-0F4C6F607214'}}
# analysis {'expense_amount': 337.61, 'payment_mode': 'XX983', 'merchant': 'IPS*M K RETAI.', 'datetime': datetime.datetime(2019, 6, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e26dafbd64bdc5152d03454'), 'message': {'text': 'Txn of INR 660.00 done on Acct XX983 on 04-Jun-19.Info: IPS*M K RETAI.Avbl Bal:INR 13,579.15.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 581352565490679936, 'guid': 'AA408631-8BDE-55D2-BC61-89BB3328F110'}}
# analysis {'expense_amount': 660.0, 'payment_mode': 'XX983', 'merchant': 'IPS*M K RETAI.', 'datetime': datetime.datetime(2019, 6, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e26dafcd64bdc5152d03456'), 'message': {'text': 'Txn of INR 79.00 done on Acct XX983 on 05-JUN-19.Info: VIN*ITUNES CO.Avbl Bal:INR 13,500.15.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 581443125768974976, 'guid': '081654C0-08CA-E436-20ED-B47E5AC1D3C6'}}
# analysis {'expense_amount': 79.0, 'payment_mode': 'XX983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 6, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db01d64bdc5152d03479'), 'message': {'text': 'Txn of INR 99.00 done on Acct XX983 on 10-Jun-19.Info: VIN*ITUNES CO.Avbl Bal:INR 13,169.29.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 581859754653248000, 'guid': '6A89F002-A161-9F01-9C7E-C27EC04DCA90'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'XX983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 6, 10, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db04d64bdc5152d0348f'), 'message': {'text': 'Txn of INR 101.00 done on Acct XX983 on 13-Jun-19.Info: VIN*WWW BIGBA.Avbl Bal:INR 11,413.29.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 582134690501392000, 'guid': '17F817D5-1F8C-9DF4-8AB4-D8E167C2FE7A'}}
# analysis {'expense_amount': 101.0, 'payment_mode': 'XX983', 'merchant': 'VIN*WWW BIGBA.', 'datetime': datetime.datetime(2019, 6, 13, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db11d64bdc5152d034e6'), 'message': {'text': 'Txn of INR 690.00 done on Acct XX983 on 04-Jul-19.Info: IPS*CENTRALAB.Avbl Bal:INR 13,696.29.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 583916123070966016, 'guid': 'F0E48408-E8E0-A73C-AF71-5FB93329F899'}}
# analysis {'expense_amount': 690.0, 'payment_mode': 'XX983', 'merchant': 'IPS*CENTRALAB.', 'datetime': datetime.datetime(2019, 7, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db11d64bdc5152d034e8'), 'message': {'text': 'Txn of INR 219.00 done on Acct XX983 on 05-Jul-19.Info: VIN*ITUNES CO.Avbl Bal:INR 13,477.29.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 584006492767584000, 'guid': 'A468CC72-36F8-0C4B-735E-041D4B253AD2'}}
# analysis {'expense_amount': 219.0, 'payment_mode': 'XX983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 7, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db12d64bdc5152d034ec'), 'message': {'text': 'Txn of INR 645.75 done on Acct XX983 on 06-Jul-19.Info: VIN*PAYPAL  U.Avbl Bal:INR 12,831.54.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 584101606689228032, 'guid': '0291C668-2AA3-C930-6C16-B8D58E8AC68A'}}
# analysis {'expense_amount': 645.75, 'payment_mode': 'XX983', 'merchant': 'VIN*PAYPAL  U.', 'datetime': datetime.datetime(2019, 7, 6, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db13d64bdc5152d034f6'), 'message': {'text': 'Txn of INR 99.00 done on Acct XX983 on 10-Jul-19.Info: VIN*ITUNES CO.Avbl Bal:INR 12,732.54.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 584451757261051008, 'guid': '20C6043F-BA7A-0984-A50C-BC485BFEF9FE'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'XX983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 7, 10, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db14d64bdc5152d034f9'), 'message': {'text': 'Txn of INR 223.00 done on Acct XX983 on 10-Jul-19.Info: VIN*WWW BIGBA.Avbl Bal:INR 12,509.54.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 584459889294710016, 'guid': '61AB9432-F18E-2DD4-139D-5789C46E3E21'}}
# analysis {'expense_amount': 223.0, 'payment_mode': 'XX983', 'merchant': 'VIN*WWW BIGBA.', 'datetime': datetime.datetime(2019, 7, 10, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db20d64bdc5152d03555'), 'message': {'text': 'Txn of INR 150.00 done on Acct XX983 on 02-Aug-19.Info: VIN*ITUNES CO.Avbl Bal:INR 12,147.13.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 586431779041484928, 'guid': '573BF9F2-F1F3-7340-74FC-2067ACDDD6C3'}}
# analysis {'expense_amount': 150.0, 'payment_mode': 'XX983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 8, 2, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db21d64bdc5152d03562'), 'message': {'text': 'Txn of INR 699.50 done on Acct XX983 on 04-AUG-19.Info: VPS*ONE FRIDA.Avbl Bal:INR 11,447.63.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 586618994333600000, 'guid': '80180061-3134-C4A6-E34D-9E03F5D08A3C'}}
# analysis {'expense_amount': 699.5, 'payment_mode': 'XX983', 'merchant': 'VPS*ONE FRIDA.', 'datetime': datetime.datetime(2019, 8, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db22d64bdc5152d03567'), 'message': {'text': 'Txn of INR 219.00 done on Acct XX983 on 05-Aug-19.Info: VIN*ITUNES CO.Avbl Bal:INR 11,228.63.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 586684855411265024, 'guid': '5B36F206-38B5-FC0D-E670-65B819DA7F70'}}
# analysis {'expense_amount': 219.0, 'payment_mode': 'XX983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 8, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db25d64bdc5152d0357d'), 'message': {'text': 'Txn of INR 99.00 done on Acct XX983 on 10-AUG-19.Info: VIN*ITUNES CO.Avbl Bal:INR 11,094.63.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 587130214902899968, 'guid': 'CADBDA30-8DEC-913B-9D7D-453B7B9F4A51'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'XX983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 8, 10, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db2fd64bdc5152d035ca'), 'message': {'text': 'Txn of INR 2.00 done on Acct XX983 on 26-Aug-19.Info: VIN*AMAZON PA.Avbl Bal:INR 9,454.63.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 588524138535822080, 'guid': '24EE07CE-32E0-78DA-8D86-F9A2769FD23C'}}
# analysis {'expense_amount': 2.0, 'payment_mode': 'XX983', 'merchant': 'VIN*AMAZON PA.', 'datetime': datetime.datetime(2019, 8, 26, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db32d64bdc5152d035e1'), 'message': {'text': 'Txn of INR 247.00 done on Acct XX983 on 24-Sep-19.Info: IIN*I-Debit*A.Avbl Bal:INR 7,465.21.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 591016255931239936, 'guid': '668DEA09-A8E7-4DD6-F345-12DB40C8887C'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db33d64bdc5152d035e3'), 'message': {'text': 'Txn of INR 249.00 done on Acct XX983 on 24-Sep-19.Info: VIN*ITUNES CO.Avbl Bal:INR 7,216.21.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 591028991136704000, 'guid': '1EC88122-20F1-0B48-A1DE-1609804DA579'}}
# analysis {'expense_amount': 249.0, 'payment_mode': 'XX983', 'merchant': 'VIN*ITUNES CO.', 'datetime': datetime.datetime(2019, 9, 24, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db35d64bdc5152d035f3'), 'message': {'text': 'Txn of INR 890.00 done on Acct XX983 on 30-Sep-19.Info: IIN*I-Debit*A.Avbl Bal:INR 13,385.71.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 591546840993512960, 'guid': '14C1875B-09A8-5D55-D9C6-F0CAF0353546'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db37d64bdc5152d03605'), 'message': {'text': 'Txn of INR 765.00 done on Acct XX983 on 04-Oct-19.Info: VIN*KERALA ST.Avbl Bal:INR 11,620.71.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 591903727352560000, 'guid': '36CF014F-087D-8C65-E3C0-46E4D30B7133'}}
# analysis {'expense_amount': 765.0, 'payment_mode': 'XX983', 'merchant': 'VIN*KERALA ST.', 'datetime': datetime.datetime(2019, 10, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db37d64bdc5152d03607'), 'message': {'text': 'Txn of INR 603.50 done on Acct XX983 on 05-Oct-19.Info: IIN*Bharat Pe.Avbl Bal:INR 11,017.21.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 591947515186077952, 'guid': '5CCC5602-CDC6-BFA1-23FC-3731077E93B2'}}
# analysis {'expense_amount': 603.5, 'payment_mode': 'XX983', 'merchant': 'IIN*Bharat Pe.', 'datetime': datetime.datetime(2019, 10, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db37d64bdc5152d03609'), 'message': {'text': 'Txn of INR 219.00 done on Acct XX983 on 05-Oct-19.Info: VSI*ITUNES CO.Avbl Bal:INR 10,798.21.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 591955143613844992, 'guid': '8E2316CE-46E7-6C33-A6C4-2A8A2B720520'}}
# analysis {'expense_amount': 219.0, 'payment_mode': 'XX983', 'merchant': 'VSI*ITUNES CO.', 'datetime': datetime.datetime(2019, 10, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db39d64bdc5152d03616'), 'message': {'text': 'Txn of INR 470.00 done on Acct XX983 on 06-OCT-19.Info: VIN*SBIETC   .Avbl Bal:INR 10,328.21.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 592073734269608960, 'guid': '0AEDFCA2-2A67-0A74-4205-D1690A6F50DA'}}
# analysis {'expense_amount': 470.0, 'payment_mode': 'XX983', 'merchant': 'VIN*SBIETC   .', 'datetime': datetime.datetime(2019, 10, 6, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db41d64bdc5152d0365e'), 'message': {'text': 'Txn of INR 371.22 done on Acct XX983 on 22-Oct-19.Info: VSI*MEDIUM MO.Avbl Bal:INR 20,662.49.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 593444514284329088, 'guid': '000D970C-A857-0B41-B97E-936E88B61CDA'}}
# analysis {'expense_amount': 371.22, 'payment_mode': 'XX983', 'merchant': 'VSI*MEDIUM MO.', 'datetime': datetime.datetime(2019, 10, 22, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db42d64bdc5152d03663'), 'message': {'text': 'Txn of INR 876.10 done on Acct XX983 on 23-Oct-19.Info: VIN*Innovativ.Avbl Bal:INR 19,694.39.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 593533587260738944, 'guid': 'FD48E040-2B40-545A-556B-58826AF8AA91'}}
# analysis {'expense_amount': 876.1, 'payment_mode': 'XX983', 'merchant': 'VIN*Innovativ.', 'datetime': datetime.datetime(2019, 10, 23, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db49d64bdc5152d036a0'), 'message': {'text': 'Txn of INR 450.00 done on Acct XX983 on 03-NOV-19.Info: VPS*WOW MOMO .Avbl Bal:INR 16,256.63.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594467796339603968, 'guid': '4F7C3529-BCE3-800F-F7AB-758C0078A9F2'}}
# analysis {'expense_amount': 450.0, 'payment_mode': 'XX983', 'merchant': 'VPS*WOW MOMO .', 'datetime': datetime.datetime(2019, 11, 3, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db49d64bdc5152d036a4'), 'message': {'text': 'Txn of INR 57.00 done on Acct XX983 on 04-Nov-19.Info: IIN*Amazon   .Avbl Bal:INR 14,449.63.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594533337605553024, 'guid': 'A2478129-01E8-7095-8CF5-491F7177960F'}}
# analysis {'expense_amount': 57.0, 'payment_mode': 'XX983', 'merchant': 'IIN*Amazon   .', 'datetime': datetime.datetime(2019, 11, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db4bd64bdc5152d036ae'), 'message': {'text': 'Txn of INR 219.00 done on Acct XX983 on 05-Nov-19.Info: VSI*APPLE COM.Avbl Bal:INR 14,152.63.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 594637162435538048, 'guid': '917693CD-EA9E-CA68-FB14-1A926F5D1092'}}
# analysis {'expense_amount': 219.0, 'payment_mode': 'XX983', 'merchant': 'VSI*APPLE COM.', 'datetime': datetime.datetime(2019, 11, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db50d64bdc5152d036db'), 'message': {'text': 'Txn of INR 99.00 done on Acct XX983 on 10-NOV-19.Info: VSI*APPLE COM.Avbl Bal:INR 13,013.63.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 595082562615411968, 'guid': '1E72F7BD-1111-3A44-ABBF-ECDC6A4ADE45'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'XX983', 'merchant': 'VSI*APPLE COM.', 'datetime': datetime.datetime(2019, 11, 10, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db53d64bdc5152d036f3'), 'message': {'text': 'Txn of INR 249.00 done on Acct XX983 on 14-Nov-19.Info: VIN*APPLE COM.Avbl Bal:INR 12,692.63.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 595408643820812032, 'guid': 'DEABA8FE-EB5F-0BA2-2EA6-7410A0821708'}}
# analysis {'expense_amount': 249.0, 'payment_mode': 'XX983', 'merchant': 'VIN*APPLE COM.', 'datetime': datetime.datetime(2019, 11, 14, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db54d64bdc5152d03700'), 'message': {'text': 'Txn of INR 374.19 done on Acct XX983 on 17-NOV-19.Info: VSI*MEDIUM MO.Avbl Bal:INR 10,950.82.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 595669313318385920, 'guid': 'C4A408D9-7132-50E3-9357-FB170B343DF2'}}
# analysis {'expense_amount': 374.19, 'payment_mode': 'XX983', 'merchant': 'VSI*MEDIUM MO.', 'datetime': datetime.datetime(2019, 11, 17, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db56d64bdc5152d03710'), 'message': {'text': 'Txn of INR 188.00 done on Acct XX983 on 20-Nov-19.Info: VIN*WWW BIGBA.Avbl Bal:INR 9,059.06.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 595960364975625984, 'guid': '21184CB8-953B-71F6-A860-0277AF9BF295'}}
# analysis {'expense_amount': 188.0, 'payment_mode': 'XX983', 'merchant': 'VIN*WWW BIGBA.', 'datetime': datetime.datetime(2019, 11, 20, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db57d64bdc5152d03719'), 'message': {'text': 'Txn of INR 2.00 done on Acct XX983 on 21-Nov-19.Info: IIN*LinkedIn .Avbl Bal:INR 8,313.06.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596023598159383040, 'guid': 'BE10BEFB-7868-51DD-AC97-82590CB28E83'}}
# analysis {'expense_amount': 2.0, 'payment_mode': 'XX983', 'merchant': 'IIN*LinkedIn .', 'datetime': datetime.datetime(2019, 11, 21, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db58d64bdc5152d03724'), 'message': {'text': 'Txn of INR 500.00 done on Acct XX983 on 22-Nov-19.Info: VIN*PAYTM    .Avbl Bal:INR 7,194.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596064942122030080, 'guid': '4BC3F9FC-76D2-02AE-4743-597F433BA3EC'}}
# analysis {'expense_amount': 500.0, 'payment_mode': 'XX983', 'merchant': 'VIN*PAYTM    .', 'datetime': datetime.datetime(2019, 11, 22, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db58d64bdc5152d03725'), 'message': {'text': 'Txn of INR 198.30 done on Acct XX983 on 22-Nov-19.Info: IIN*Amazon   .Avbl Bal:INR 7,694.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596064942654044928, 'guid': '7557CB6B-CD76-C6A3-0100-2B637900B000'}}
# analysis {'expense_amount': 198.3, 'payment_mode': 'XX983', 'merchant': 'IIN*Amazon   .', 'datetime': datetime.datetime(2019, 11, 22, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db59d64bdc5152d0372d'), 'message': {'text': 'Txn of INR 149.00 done on Acct XX983 on 23-NOV-19.Info: IIN*Amazon   .Avbl Bal:INR 6,640.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596184743685179008, 'guid': 'C7006DEE-80E3-BE0D-FF29-B55A8512FC1A'}}
# analysis {'expense_amount': 149.0, 'payment_mode': 'XX983', 'merchant': 'IIN*Amazon   .', 'datetime': datetime.datetime(2019, 11, 23, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db5ad64bdc5152d03733'), 'message': {'text': 'Txn of INR 199.00 done on Acct XX983 on 24-NOV-19.Info: VSI*AMAZON ST.Avbl Bal:INR 6,119.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 596301268551921920, 'guid': '6C6BF131-71FA-3C4B-0656-5D6D7E2D59D3'}}
# analysis {'expense_amount': 199.0, 'payment_mode': 'XX983', 'merchant': 'VSI*AMAZON ST.', 'datetime': datetime.datetime(2019, 11, 24, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db63d64bdc5152d03782'), 'message': {'text': 'Txn of INR 550.00 done on Acct XX983 on 04-Dec-19.Info: VPS*TRUFFLES .Avbl Bal:INR 19,776.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597153091571240960, 'guid': '0F559B6B-C91C-DE60-A67A-71063DB88FD6'}}
# analysis {'expense_amount': 550.0, 'payment_mode': 'XX983', 'merchant': 'VPS*TRUFFLES .', 'datetime': datetime.datetime(2019, 12, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db64d64bdc5152d03784'), 'message': {'text': 'Txn of INR 330.00 done on Acct XX983 on 04-Dec-19.Info: IPS*M K RETAI.Avbl Bal:INR 17,384.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597161343790663040, 'guid': '7711587B-BA70-ECA1-1206-138AE93B10EB'}}
# analysis {'expense_amount': 330.0, 'payment_mode': 'XX983', 'merchant': 'IPS*M K RETAI.', 'datetime': datetime.datetime(2019, 12, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db64d64bdc5152d03787'), 'message': {'text': 'Txn of INR 99.00 done on Acct XX983 on 05-Dec-19.Info: VIN*APPLE COM.Avbl Bal:INR 17,285.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597249059831787008, 'guid': 'F885AFAE-AB72-2373-4219-FD661C75CD6D'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'XX983', 'merchant': 'VIN*APPLE COM.', 'datetime': datetime.datetime(2019, 12, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db64d64bdc5152d03789'), 'message': {'text': 'Txn of INR 100.00 done on Acct XX983 on 05-Dec-19.Info: IPS*M K RETAI.Avbl Bal:INR 17,185.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597252682723361920, 'guid': '293AB3DA-541A-DF15-740C-B81D2EF653FF'}}
# analysis {'expense_amount': 100.0, 'payment_mode': 'XX983', 'merchant': 'IPS*M K RETAI.', 'datetime': datetime.datetime(2019, 12, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db65d64bdc5152d0378c'), 'message': {'text': 'Txn of INR 219.00 done on Acct XX983 on 06-Dec-19.Info: VSI*APPLE COM.Avbl Bal:INR 16,761.76.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597271310058336000, 'guid': 'DEF0CF79-CEC3-2B2C-58A9-3B4B2B140383'}}
# analysis {'expense_amount': 219.0, 'payment_mode': 'XX983', 'merchant': 'VSI*APPLE COM.', 'datetime': datetime.datetime(2019, 12, 6, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db66d64bdc5152d0379b'), 'message': {'text': 'Txn of INR 154.00 done on Acct XX983 on 09-Dec-19.Info: IPS*NEW FRUIT.Avbl Bal:INR 15,074.50.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597586876094408960, 'guid': '7E92C5CC-230A-78A6-753E-32837DA6ABC8'}}
# analysis {'expense_amount': 154.0, 'payment_mode': 'XX983', 'merchant': 'IPS*NEW FRUIT.', 'datetime': datetime.datetime(2019, 12, 9, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db67d64bdc5152d0379d'), 'message': {'text': 'Txn of INR 205.00 done on Acct XX983 on 09-Dec-19.Info: VPS*HUNAN EXP.Avbl Bal:INR 14,595.50.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597595920660612992, 'guid': '0D577554-0B34-560E-808D-8FF76EA13693'}}
# analysis {'expense_amount': 205.0, 'payment_mode': 'XX983', 'merchant': 'VPS*HUNAN EXP.', 'datetime': datetime.datetime(2019, 12, 9, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db67d64bdc5152d0379e'), 'message': {'text': 'Txn of INR 167.00 done on Acct XX983 on 09-Dec-19.Info: VPS*THETHICK .Avbl Bal:INR 14,428.50.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597596260170766976, 'guid': '83E441C8-32E4-3870-4174-EFE1EEE7F604'}}
# analysis {'expense_amount': 167.0, 'payment_mode': 'XX983', 'merchant': 'VPS*THETHICK .', 'datetime': datetime.datetime(2019, 12, 9, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db67d64bdc5152d0379f'), 'message': {'text': 'Txn of INR 60.00 done on Acct XX983 on 09-Dec-19.Info: VPS*PHOENIX M.Avbl Bal:INR 14,368.50.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597599160955965056, 'guid': '7EAC48C0-63A1-05E8-93FF-C58716B42826'}}
# analysis {'expense_amount': 60.0, 'payment_mode': 'XX983', 'merchant': 'VPS*PHOENIX M.', 'datetime': datetime.datetime(2019, 12, 9, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db67d64bdc5152d037a5'), 'message': {'text': 'Txn of INR 500.00 done on Acct XX983 on 10-Dec-19.Info: IIN*I-Debit*P.Avbl Bal:INR 13,768.50.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597644983043652096, 'guid': '7B7C8566-7EC2-0290-672D-6CF7B436C8F4'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db68d64bdc5152d037a9'), 'message': {'text': 'Txn of INR 100.00 done on Acct XX983 on 11-Dec-19.Info: VPS*FOOT WEAR.Avbl Bal:INR 13,718.50.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597757127773623040, 'guid': '04DCB77A-28F7-A477-3976-1A3659511EE5'}}
# analysis {'expense_amount': 100.0, 'payment_mode': 'XX983', 'merchant': 'VPS*FOOT WEAR.', 'datetime': datetime.datetime(2019, 12, 11, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db68d64bdc5152d037aa'), 'message': {'text': 'Txn of INR 224.00 done on Acct XX983 on 11-Dec-19.Info: IPS*NEW FRUIT.Avbl Bal:INR 13,494.50.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597759210353037952, 'guid': '911505C3-A666-B5B1-88F7-2FF9F15D91D9'}}
# analysis {'expense_amount': 224.0, 'payment_mode': 'XX983', 'merchant': 'IPS*NEW FRUIT.', 'datetime': datetime.datetime(2019, 12, 11, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db69d64bdc5152d037b1'), 'message': {'text': 'Txn of INR 126.00 done on Acct XX983 on 12-Dec-19.Info: VPS*LEON GRIL.Avbl Bal:INR 12,000.87.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597834053283232000, 'guid': '7E0F4AFE-585D-4DA8-9581-AC263F2C300B'}}
# analysis {'expense_amount': 126.0, 'payment_mode': 'XX983', 'merchant': 'VPS*LEON GRIL.', 'datetime': datetime.datetime(2019, 12, 12, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db69d64bdc5152d037b2'), 'message': {'text': 'Txn of INR 800.00 done on Acct XX983 on 12-Dec-19.Info: VPS*DR KRISHN.Avbl Bal:INR 11,200.87.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 597838462924242944, 'guid': '74E28E14-1F0A-E70F-2E10-88313208602F'}}
# analysis {'expense_amount': 800.0, 'payment_mode': 'XX983', 'merchant': 'VPS*DR KRISHN.', 'datetime': datetime.datetime(2019, 12, 12, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db6bd64bdc5152d037c0'), 'message': {'text': 'Txn of INR 906.00 done on Acct XX983 on 15-DEC-19.Info: IPS*NEW FRUIT.Avbl Bal:INR 8,868.87.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598115608415070080, 'guid': '9B54A53B-8743-4730-C9DA-297971DD4B3E'}}
# analysis {'expense_amount': 906.0, 'payment_mode': 'XX983', 'merchant': 'IPS*NEW FRUIT.', 'datetime': datetime.datetime(2019, 12, 15, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db6bd64bdc5152d037c1'), 'message': {'text': 'Txn of INR 710.00 done on Acct XX983 on 15-DEC-19.Info: VPS*AJFAN DAT.Avbl Bal:INR 8,158.87.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598116148550663040, 'guid': '238875B7-CDE0-195C-2FDE-4C34DE0AB036'}}
# analysis {'expense_amount': 710.0, 'payment_mode': 'XX983', 'merchant': 'VPS*AJFAN DAT.', 'datetime': datetime.datetime(2019, 12, 15, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db6bd64bdc5152d037c4'), 'message': {'text': 'Txn of INR 299.00 done on Acct XX983 on 16-Dec-19.Info: VIN*APPLE COM.Avbl Bal:INR 6,813.87.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598186339853222016, 'guid': '98C28EE3-18A9-19DF-AE72-5CCCE6395E00'}}
# analysis {'expense_amount': 299.0, 'payment_mode': 'XX983', 'merchant': 'VIN*APPLE COM.', 'datetime': datetime.datetime(2019, 12, 16, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db6fd64bdc5152d037e4'), 'message': {'text': 'Txn of INR 189.00 done on Acct XX983 on 21-Dec-19.Info: VPS*HOTEL SHR.Avbl Bal:INR 14,423.61.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 598591138604866944, 'guid': 'CD87F18F-1D8C-AB37-E03D-81F8E991A28E'}}
# analysis {'expense_amount': 189.0, 'payment_mode': 'XX983', 'merchant': 'VPS*HOTEL SHR.', 'datetime': datetime.datetime(2019, 12, 21, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db72d64bdc5152d037fb'), 'message': {'text': 'Txn of INR 935.00 done on Acct XX983 on 27-Dec-19.Info: VPS*IRINJALAK.Avbl Bal:INR 13,185.01.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599116618365862912, 'guid': '39836494-EA1F-249B-78FF-61E80EDE46DB'}}
# analysis {'expense_amount': 935.0, 'payment_mode': 'XX983', 'merchant': 'VPS*IRINJALAK.', 'datetime': datetime.datetime(2019, 12, 27, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db75d64bdc5152d03816'), 'message': {'text': 'Txn of INR 699.00 done on Acct XX983 on 01-Jan-20.Info: VPS*MSP RETAI.Avbl Bal:INR 17,912.96.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599576252912121088, 'guid': 'BBCD1D5B-881E-D1DD-0467-BC31B9D507A4'}}
# analysis {'expense_amount': 699.0, 'payment_mode': 'XX983', 'merchant': 'VPS*MSP RETAI.', 'datetime': datetime.datetime(2020, 1, 1, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db75d64bdc5152d03817'), 'message': {'text': 'Txn of INR 169.00 done on Acct XX983 on 01-Jan-20.Info: VPS*MSP RETAI.Avbl Bal:INR 17,743.96.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599576297564136064, 'guid': '87FCF953-E0A2-14BE-606C-C2BFAA673474'}}
# analysis {'expense_amount': 169.0, 'payment_mode': 'XX983', 'merchant': 'VPS*MSP RETAI.', 'datetime': datetime.datetime(2020, 1, 1, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db75d64bdc5152d03819'), 'message': {'text': 'Txn of INR 640.00 done on Acct XX983 on 01-Jan-20.Info: VPS*NAS ESTAB.Avbl Bal:INR 15,977.96.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599576912062522112, 'guid': 'C5120E03-B37A-9AAF-6182-9A982CE81B19'}}
# analysis {'expense_amount': 640.0, 'payment_mode': 'XX983', 'merchant': 'VPS*NAS ESTAB.', 'datetime': datetime.datetime(2020, 1, 1, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db75d64bdc5152d0381a'), 'message': {'text': 'Txn of INR 447.16 done on Acct XX983 on 01-Jan-20.Info: VPS*RELIANCE .Avbl Bal:INR 15,530.80.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599578008811889024, 'guid': '3AAB5A35-AC3E-9AD3-2C09-FC0FB8944AEF'}}
# analysis {'expense_amount': 447.16, 'payment_mode': 'XX983', 'merchant': 'VPS*RELIANCE .', 'datetime': datetime.datetime(2020, 1, 1, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db76d64bdc5152d0381f'), 'message': {'text': 'Txn of INR 717.00 done on Acct XX983 on 02-Jan-20.Info: IIN*Bharat Pe.Avbl Bal:INR 14,813.80.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599641967310315904, 'guid': 'BF61C06B-B2F0-69CC-C7A8-EFED52F9598A'}}
# analysis {'expense_amount': 717.0, 'payment_mode': 'XX983', 'merchant': 'IIN*Bharat Pe.', 'datetime': datetime.datetime(2020, 1, 2, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db77d64bdc5152d03822'), 'message': {'text': 'Txn of INR 693.13 done on Acct XX983 on 02-Jan-20.Info: VPS*KFC      .Avbl Bal:INR 14,120.67.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599664887748489984, 'guid': '0F340FCC-6AC3-1204-0A7E-21DBEF3FAC8A'}}
# analysis {'expense_amount': 693.13, 'payment_mode': 'XX983', 'merchant': 'VPS*KFC      .', 'datetime': datetime.datetime(2020, 1, 2, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db77d64bdc5152d03823'), 'message': {'text': 'Txn of INR 221.00 done on Acct XX983 on 02-Jan-20.Info: VPS*SUPREME B.Avbl Bal:INR 13,899.67.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599667201951145088, 'guid': '199F59D1-C4BD-505B-E4C0-51CDD9275FD8'}}
# analysis {'expense_amount': 221.0, 'payment_mode': 'XX983', 'merchant': 'VPS*SUPREME B.', 'datetime': datetime.datetime(2020, 1, 2, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db78d64bdc5152d0382c'), 'message': {'text': 'Txn of INR 221.00 done on Acct XX983 on 03-Jan-20.Info: VPS*ASWATHY H.Avbl Bal:INR 12,128.67.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599755008061691008, 'guid': '6759FD9E-693C-1C5B-C035-452DBBC7619D'}}
# analysis {'expense_amount': 221.0, 'payment_mode': 'XX983', 'merchant': 'VPS*ASWATHY H.', 'datetime': datetime.datetime(2020, 1, 3, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db79d64bdc5152d0383a'), 'message': {'text': 'Txn of INR 320.00 done on Acct XX983 on 05-JAN-20.Info: VPS*HOTEL ARY.Avbl Bal:INR 11,808.67.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599883009332535040, 'guid': '5B8E2B85-32E7-FEF5-F2A8-9F0CB0516B52'}}
# analysis {'expense_amount': 320.0, 'payment_mode': 'XX983', 'merchant': 'VPS*HOTEL ARY.', 'datetime': datetime.datetime(2020, 1, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db7ad64bdc5152d03843'), 'message': {'text': 'Txn of INR 99.00 done on Acct XX983 on 05-JAN-20.Info: VSI*APPLE COM.Avbl Bal:INR 9,709.67.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599898716201190016, 'guid': '0CCEDC03-40B3-20D9-D81B-D9E12DA4C6B9'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'XX983', 'merchant': 'VSI*APPLE COM.', 'datetime': datetime.datetime(2020, 1, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db7ad64bdc5152d03844'), 'message': {'text': 'Txn of INR 99.00 done on Acct XX983 on 05-JAN-20.Info: VSI*APPLE COM.Avbl Bal:INR 9,709.67.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599898801906752896, 'guid': '1A39FFD1-0E02-4A10-466A-BE030862A921'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'XX983', 'merchant': 'VSI*APPLE COM.', 'datetime': datetime.datetime(2020, 1, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db7bd64bdc5152d0384a'), 'message': {'text': 'Txn of INR 219.00 done on Acct XX983 on 05-JAN-20.Info: VSI*APPLE COM.Avbl Bal:INR 9,163.17.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 599907534398644992, 'guid': '3BC6ABB3-6304-799A-64D6-A5C089C9F5D2'}}
# analysis {'expense_amount': 219.0, 'payment_mode': 'XX983', 'merchant': 'VSI*APPLE COM.', 'datetime': datetime.datetime(2020, 1, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db7dd64bdc5152d03859'), 'message': {'text': 'Txn of INR 299.00 done on Acct XX983 on 07-Jan-20.Info: VIN*APPLE COM.Avbl Bal:INR 4,926.17.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600087924441171072, 'guid': '2DC4A5F8-6711-26FF-B0ED-DFB0C9CC895A'}}
# analysis {'expense_amount': 299.0, 'payment_mode': 'XX983', 'merchant': 'VIN*APPLE COM.', 'datetime': datetime.datetime(2020, 1, 7, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db7fd64bdc5152d03868'), 'message': {'text': 'Txn of INR 369.00 done on Acct XX983 on 09-Jan-20.Info: IPS*M K RETAI.Avbl Bal:INR 17,086.17.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600238045755218048, 'guid': '8FFCE6A9-6354-E668-1686-A728B313B677'}}
# analysis {'expense_amount': 369.0, 'payment_mode': 'XX983', 'merchant': 'IPS*M K RETAI.', 'datetime': datetime.datetime(2020, 1, 9, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db80d64bdc5152d03875'), 'message': {'text': 'Txn of INR 1.00 done on Acct XX983 on 11-JAN-20.Info: VIN*UBER     .Avbl Bal:INR 17,396.17.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600435543928668032, 'guid': 'DE0453E3-E9D2-5D25-DB5F-3ECC98B8939A'}}
# analysis {'expense_amount': 1.0, 'payment_mode': 'XX983', 'merchant': 'VIN*UBER     .', 'datetime': datetime.datetime(2020, 1, 11, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db80d64bdc5152d03877'), 'message': {'text': 'Txn of INR 49.00 done on Acct XX983 on 11-JAN-20.Info: VIN*APPLE COM.Avbl Bal:INR 16,995.17.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600444546567113088, 'guid': '89A4211D-E8B7-4E94-F86B-F449040DC86B'}}
# analysis {'expense_amount': 49.0, 'payment_mode': 'XX983', 'merchant': 'VIN*APPLE COM.', 'datetime': datetime.datetime(2020, 1, 11, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db80d64bdc5152d0387a'), 'message': {'text': 'Txn of INR 850.00 done on Acct XX983 on 12-JAN-20.Info: VPS*ABHAYAHAS.Avbl Bal:INR 14,439.17.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600511225639665024, 'guid': 'C39EEE7D-8C42-EB1C-C554-DA0DAE478967'}}
# analysis {'expense_amount': 850.0, 'payment_mode': 'XX983', 'merchant': 'VPS*ABHAYAHAS.', 'datetime': datetime.datetime(2020, 1, 12, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db81d64bdc5152d0387c'), 'message': {'text': 'Txn of INR 231.00 done on Acct XX983 on 12-JAN-20.Info: VIN*Dunzo Dig.Avbl Bal:INR 13,590.17.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600531047645220992, 'guid': '780DAE59-57A8-F1DC-59B9-4DF9CA05280C'}}
# analysis {'expense_amount': 231.0, 'payment_mode': 'XX983', 'merchant': 'VIN*Dunzo Dig.', 'datetime': datetime.datetime(2020, 1, 12, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db85d64bdc5152d038a3'), 'message': {'text': 'Txn of INR 500.00 done on Acct XX983 on 18-Jan-20.Info: IIN*PAYTM    .Avbl Bal:INR 11,420.17.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 600991522965906048, 'guid': 'EEDB36FD-51F3-569D-DA28-8FA220BAC825'}}
# analysis {'expense_amount': 500.0, 'payment_mode': 'XX983', 'merchant': 'IIN*PAYTM    .', 'datetime': datetime.datetime(2020, 1, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db86d64bdc5152d038ac'), 'message': {'text': 'Txn of INR 166.00 done on Acct XX983 on 18-Jan-20.Info: VPS*BON APPET.Avbl Bal:INR 10,583.93.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601049442876103040, 'guid': '5FA8C3DF-DEB4-4448-A2FA-429F440E7B21'}}
# analysis {'expense_amount': 166.0, 'payment_mode': 'XX983', 'merchant': 'VPS*BON APPET.', 'datetime': datetime.datetime(2020, 1, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db86d64bdc5152d038ad'), 'message': {'text': 'Txn of INR 201.00 done on Acct XX983 on 18-Jan-20.Info: VPS*GELATO   .Avbl Bal:INR 10,382.93.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601050268362760960, 'guid': '1ABD30AE-9D96-F78A-A721-3C081AC3DC1D'}}
# analysis {'expense_amount': 201.0, 'payment_mode': 'XX983', 'merchant': 'VPS*GELATO   .', 'datetime': datetime.datetime(2020, 1, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db87d64bdc5152d038b1'), 'message': {'text': 'Txn of INR 235.00 done on Acct XX983 on 18-Jan-20.Info: VIN*WWW BIGBA.Avbl Bal:INR 8,572.93.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601051604829673088, 'guid': '7A40D43E-E1CE-714F-7D95-046DA27AE3E0'}}
# analysis {'expense_amount': 235.0, 'payment_mode': 'XX983', 'merchant': 'VIN*WWW BIGBA.', 'datetime': datetime.datetime(2020, 1, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db87d64bdc5152d038b3'), 'message': {'text': 'Txn of INR 140.00 done on Acct XX983 on 18-Jan-20.Info: VPS*PHOENIX M.Avbl Bal:INR 8,432.93.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601057745985661952, 'guid': '691305D0-C5A0-4CB5-DDF8-3987A2AF5D40'}}
# analysis {'expense_amount': 140.0, 'payment_mode': 'XX983', 'merchant': 'VPS*PHOENIX M.', 'datetime': datetime.datetime(2020, 1, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db87d64bdc5152d038b7'), 'message': {'text': 'Txn of INR 1.00 done on Acct XX983 on 18-Jan-20.Info: VIN*GOOGLE  T.Avbl Bal:INR 20,431.93.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601066101185091968, 'guid': 'AF7E4278-B13C-A3F2-9547-BC0F1D801FB2'}}
# analysis {'expense_amount': 1.0, 'payment_mode': 'XX983', 'merchant': 'VIN*GOOGLE  T.', 'datetime': datetime.datetime(2020, 1, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db87d64bdc5152d038b8'), 'message': {'text': 'Txn of INR 80.00 done on Acct XX983 on 18-Jan-20.Info: VIN*GOOGLE  G.Avbl Bal:INR 20,352.93.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601066101282243968, 'guid': '670F51C5-6E03-700E-A1E9-3F4DA0769CFF'}}
# analysis {'expense_amount': 80.0, 'payment_mode': 'XX983', 'merchant': 'VIN*GOOGLE  G.', 'datetime': datetime.datetime(2020, 1, 18, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db88d64bdc5152d038bd'), 'message': {'text': 'Txn of INR 579.19 done on Acct XX983 on 19-JAN-20.Info: IIN*I-Debit*A.Avbl Bal:INR 15,534.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601124345298679936, 'guid': '3CF3038D-501D-5FB5-9FC3-A828490DF807'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db88d64bdc5152d038c1'), 'message': {'text': 'Txn of INR 379.00 done on Acct XX983 on 19-JAN-20.Info: IIN*Amazon   .Avbl Bal:INR 15,155.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601144994526685056, 'guid': '05E58F78-5FEF-1E2A-324A-8AED998B7BE7'}}
# analysis {'expense_amount': 379.0, 'payment_mode': 'XX983', 'merchant': 'IIN*Amazon   .', 'datetime': datetime.datetime(2020, 1, 19, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db89d64bdc5152d038c7'), 'message': {'text': 'Txn of INR 558.00 done on Acct XX983 on 20-Jan-20.Info: IIN*I-Debit*A.Avbl Bal:INR 14,597.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601170796729539968, 'guid': '5FD6D02B-6B93-A67B-A47F-243BD01EDDC8'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db8ad64bdc5152d038cc'), 'message': {'text': 'Txn of INR 870.00 done on Acct XX983 on 20-Jan-20.Info: VPS*AJFAN DAT.Avbl Bal:INR 12,447.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601221633443824000, 'guid': '34BBAA7E-0627-F164-B5FE-010797E3C732'}}
# analysis {'expense_amount': 870.0, 'payment_mode': 'XX983', 'merchant': 'VPS*AJFAN DAT.', 'datetime': datetime.datetime(2020, 1, 20, 0, 0)}
#
#
# message {'_id': ObjectId('5e26db8ad64bdc5152d038cf'), 'message': {'text': 'Txn of INR 359.00 done on Acct XX983 on 21-Jan-20.Info: IIN*Amazon   .Avbl Bal:INR 11,088.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601277876831464064, 'guid': 'F00B553E-CD96-1C60-E7A0-1A8EA5EDF788'}}
# analysis {'expense_amount': 359.0, 'payment_mode': 'XX983', 'merchant': 'IIN*Amazon   .', 'datetime': datetime.datetime(2020, 1, 21, 0, 0)}
#
#
# message {'_id': ObjectId('5e288929546d0b8e7aa1eba4'), 'message': {'text': 'Txn of INR 128.00 done on Acct XX983 on 22-Jan-20.Info: IIN*I-Debit*A.Avbl Bal:INR 10,341.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601333960316915072, 'guid': '36EF2C9A-718D-A173-347B-BCD366EAB0D3'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e3a782b85ce1ed04ce1b697'), 'message': {'text': 'Txn of INR 650.00 done on Acct XX983 on 28-Jan-20.Info: VPS*CMH-GPRS .Avbl Bal:INR 17,812.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601889623795245952, 'guid': '62583E2B-73D6-F2D1-7466-B16035F88025'}}
# analysis {}
#
#
# message {'_id': ObjectId('5e3a782c85ce1ed04ce1b699'), 'message': {'text': 'Txn of INR 204.00 done on Acct XX983 on 28-Jan-20.Info: VIN*Dunzo Dig.Avbl Bal:INR 17,608.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601910142665131008, 'guid': 'D71EA3F9-7BDE-F07A-A02D-BF742B3E83B7'}}
# analysis {'expense_amount': 204.0, 'payment_mode': 'XX983', 'merchant': 'VIN*Dunzo Dig.', 'datetime': datetime.datetime(2020, 1, 28, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a782c85ce1ed04ce1b69c'), 'message': {'text': 'Txn of INR 371.00 done on Acct XX983 on 28-Jan-20.Info: VPS*MSW AMRUT.Avbl Bal:INR 17,037.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 601916508528131968, 'guid': 'BCCD28BE-FE77-44F0-1A1F-F08B318C86BA'}}
# analysis {'expense_amount': 371.0, 'payment_mode': 'XX983', 'merchant': 'VPS*MSW AMRUT.', 'datetime': datetime.datetime(2020, 1, 28, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a782e85ce1ed04ce1b6a5'), 'message': {'text': 'Txn of INR 442.00 done on Acct XX983 on 29-Jan-20.Info: IPS*NEW FRUIT.Avbl Bal:INR 16,332.52.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602000117859470976, 'guid': 'C95EF4BA-FB65-0555-952E-A21D18A32A0A'}}
# analysis {'expense_amount': 442.0, 'payment_mode': 'XX983', 'merchant': 'IPS*NEW FRUIT.', 'datetime': datetime.datetime(2020, 1, 29, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a782f85ce1ed04ce1b6ab'), 'message': {'text': 'Txn of INR 200.00 done on Acct XX983 on 30-Jan-20.Info: IIN*Amazon   .Avbl Bal:INR 15,219.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602091927141672960, 'guid': '73266E58-A716-3359-30C4-1B7F215032F3'}}
# analysis {'expense_amount': 200.0, 'payment_mode': 'XX983', 'merchant': 'IIN*Amazon   .', 'datetime': datetime.datetime(2020, 1, 30, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a783085ce1ed04ce1b6b5'), 'message': {'text': 'Txn of INR 146.00 done on Acct XX983 on 31-Jan-20.Info: VIN*DUNZO DIG.Avbl Bal:INR 14,803.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602175317734680960, 'guid': '010F36C3-78A3-49E3-CF40-149BEEC0BA3A'}}
# analysis {'expense_amount': 146.0, 'payment_mode': 'XX983', 'merchant': 'VIN*DUNZO DIG.', 'datetime': datetime.datetime(2020, 1, 31, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a783185ce1ed04ce1b6b9'), 'message': {'text': 'Txn of INR 970.00 done on Acct XX983 on 01-Feb-20.Info: VPS*PAY Sreen.Avbl Bal:INR 13,481.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602261371010292096, 'guid': '960D1016-121D-CA71-A3C9-264C43663256'}}
# analysis {'expense_amount': 970.0, 'payment_mode': 'XX983', 'merchant': 'VPS*PAY Sreen.', 'datetime': datetime.datetime(2020, 2, 1, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a783185ce1ed04ce1b6bd'), 'message': {'text': 'Txn of INR 120.00 done on Acct XX983 on 02-FEB-20.Info: VPS*DROMI    .Avbl Bal:INR 11,833.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602304940784756992, 'guid': '66E959AE-1847-F6F0-CC7D-531BA3254559'}}
# analysis {'expense_amount': 120.0, 'payment_mode': 'XX983', 'merchant': 'VPS*DROMI    .', 'datetime': datetime.datetime(2020, 2, 2, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a783385ce1ed04ce1b6c7'), 'message': {'text': 'Txn of INR 268.00 done on Acct XX983 on 03-Feb-20.Info: VPS*HORTICULT.Avbl Bal:INR 11,480.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602426433163383936, 'guid': '83108E38-FF1D-4254-CD20-8EFB101F8ED8'}}
# analysis {'expense_amount': 268.0, 'payment_mode': 'XX983', 'merchant': 'VPS*HORTICULT.', 'datetime': datetime.datetime(2020, 2, 3, 0, 0)}
#
#
# message {'_id': ObjectId('5e3a783385ce1ed04ce1b6cd'), 'message': {'text': 'Txn of INR 299.00 done on Acct XX983 on 04-Feb-20.Info: VIN*APPLE COM.Avbl Bal:INR 11,121.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602519685105257984, 'guid': '4FB2F6B1-93F6-DD05-E1A5-CBB7436A3DBB'}}
# analysis {'expense_amount': 299.0, 'payment_mode': 'XX983', 'merchant': 'VIN*APPLE COM.', 'datetime': datetime.datetime(2020, 2, 4, 0, 0)}
#
#
# message {'_id': ObjectId('5e3e5b34dd2322b0ad5cccf4'), 'message': {'text': 'Txn of INR 99.00 done on Acct XX983 on 05-Feb-20.Info: VSI*APPLE COM.Avbl Bal:INR 10,854.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602585943022873984, 'guid': 'B439E447-4E30-5E2A-E29D-C0DC89AF149B'}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'XX983', 'merchant': 'VSI*APPLE COM.', 'datetime': datetime.datetime(2020, 2, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e3e5b34dd2322b0ad5cccf5'), 'message': {'text': 'Txn of INR 219.00 done on Acct XX983 on 05-Feb-20.Info: VSI*APPLE COM.Avbl Bal:INR 10,635.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602585945620988032, 'guid': '6CF2097C-8427-1AA8-CFF2-801AD5942A65'}}
# analysis {'expense_amount': 219.0, 'payment_mode': 'XX983', 'merchant': 'VSI*APPLE COM.', 'datetime': datetime.datetime(2020, 2, 5, 0, 0)}
#
#
# message {'_id': ObjectId('5e3e5b36dd2322b0ad5ccd05'), 'message': {'text': 'Txn of INR 249.00 done on Acct XX983 on 07-Feb-20.Info: IIN*Amazon   .Avbl Bal:INR 9,032.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602756630500877056, 'guid': 'DCCBE6A8-A96A-76DC-C067-71025DC72974'}}
# analysis {'expense_amount': 249.0, 'payment_mode': 'XX983', 'merchant': 'IIN*Amazon   .', 'datetime': datetime.datetime(2020, 2, 7, 0, 0)}
#
#
# message {'_id': ObjectId('5e40f96a637cbe765df7dd7e'), 'message': {'text': 'Txn of INR 999.00 done on Acct XX983 on 09-FEB-20.Info: VIN*APPLE COM.Avbl Bal:INR 7,613.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602937452780382080, 'guid': '1BDBCA74-7C72-7356-656C-4DC4C29000E4'}}
# analysis {'expense_amount': 999.0, 'payment_mode': 'XX983', 'merchant': 'VIN*APPLE COM.', 'datetime': datetime.datetime(2020, 2, 9, 0, 0)}
#
#
# message {'_id': ObjectId('5e40f96b637cbe765df7dd82'), 'message': {'text': 'Txn of INR 195.00 done on Acct XX983 on 09-FEB-20.Info: IIN*I-Debit*D.Avbl Bal:INR 7,418.75.Call 18002662 for dispute or SMS BLOCK 983 to 9215676766', 'date': 602958137578338944, 'guid': '359DDF7B-4839-C32D-0A0C-BD9C9E3E824F'}}
# analysis {}
