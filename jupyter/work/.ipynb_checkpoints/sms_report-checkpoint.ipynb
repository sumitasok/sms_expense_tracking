# %%
from pymongo import MongoClient
import os
import bson

def mongoCollection(connstr, db, collection):
    client = MongoClient(connstr)
    db = client[db]
    return db[collection]

import re
import datetime

hdfcCreditCardInterpreterFormatStr = '%Y-%m-%d:%H:%M:%S'

# ALERT: You've spent Rs.5605.00  on CREDIT Card xx3690 at AARKITHA on 2020-02-22:12:09:36.Avl bal - Rs.286107.00, curr o/s - Rs.13893.00.Not you? Call 18002586161.
def hdfcCreditCardInterpreter(txn):
    x = re.search("ALERT: You\'ve spent Rs.([0-9.]+)\s+on\s+([a-zA-Z0-9\s._]+)? on (\d{4}-\d{2}-\d{2}:\d{2}:\d{2}:\d{2}).Avl bal - Rs.([0-9.]+), curr o\/s - Rs.([0-9]+.[0-9]+).", txn)
    return {
        'expense_amount': float(x.group(1)),
        'payment_mode': x.group(2).split('at', 1)[0].strip(),
        'merchant': x.group(2).split('at', 1)[1].strip(),
        'datetime': datetime.datetime.strptime(x.group(3), hdfcCreditCardInterpreterFormatStr),
        'available_balance': float(x.group(4)),
        'outstanding_amount': float(x.group(5))
    } if x != None else {}

# ALERT:You've spent Rs.428.00 on CREDIT Card xx3690 at FRESHTOH3631510 in BANGALORE on 2020-02-15:16:46:51.Not you?Call 18002586161.
def hdfcCreditCardInterpreter2(txn):
    x = re.search("ALERT:You\'ve spent Rs.([0-9.]+)\s+on\s+([a-zA-Z0-9\s._//]+)? on (\d{4}-\d{2}-\d{2}:\d{2}:\d{2}:\d{2}).", txn)
    return {
        'expense_amount': float(x.group(1)),
        'payment_mode': x.group(2).split('at', 1)[0].strip(),
        'merchant': x.group(2).split('at', 1)[1].strip(),
        'datetime': datetime.datetime.strptime(x.group(3), hdfcCreditCardInterpreterFormatStr)
    } if x != None else {}

# ALERT:You've spent Rs.3638.00 via Debit Card xx6504 at www.lenskart.c on 2019-01-14:20:29:59.Avl Bal Rs.264666.51.Not you?Call 18002586161.
def hdfcCreditCardInterpreterVia(txn):
    x = re.search("ALERT:You\'ve spent Rs.([0-9.]+)\s+via\s+([a-zA-Z0-9\s._//]+)? on (\d{4}-\d{2}-\d{2}:\d{2}:\d{2}:\d{2}).", txn)
    return {
        'expense_amount': float(x.group(1)),
        'payment_mode': x.group(2).split('at', 1)[0].strip(),
        'merchant': x.group(2).split('at', 1)[1].strip(),
        'datetime': datetime.datetime.strptime(x.group(3), hdfcCreditCardInterpreterFormatStr)
    } if x != None else {}

from IPython.display import HTML, display
import tabulate

def extract_transactions(i):
    return list(i[1]['transaction'].values()) + [str(i[1]['_id'])]

def mark_duplicate(collection, _id):
    result = collection.update_one({'_id': bson.ObjectId(_id)}, {'$set' : {'status': {'duplicate': True}}})
    print('success' if result.modified_count == 1 else 'failed')
    return result

def add_category_info(collection, _id, category='', sub_category=''):
    result = collection.update_one(
        {'_id': bson.ObjectId(_id)}, 
        {'$set' : {'transaction.category': category, 'transaction.sub_category': sub_category}})
    print('success' if result.modified_count == 1 else 'failed')
    return result

# %%
collection = mongoCollection(os.environ.get('MONGODB_CONN_STR'), 'smsinfo', 'transactions')

# %%
for _item in list(
    enumerate(
        collection.find({
            "message.text": {'$regex': 'ALERT: You\'ve spent Rs.([0-9.]+)'},
            "status.analysis_done": {'$ne': True}}
        ).sort([("message.date",1)]))):
    print("message", _item[1])
    _transaction = hdfcCreditCardInterpreter(_item[1]['message']['text'])
    print("analysis", _transaction, "\n\n")
    result = collection.update_one(
        {'_id': bson.ObjectId(str(_item[1]['_id']))},
        {'$set' : {'transaction': _transaction, 'status': {'analysis_done': True}}})
    print('success' if result.modified_count == 1 else 'unsuccessful')
    
for _item in list(
    enumerate(
        collection.find({
            "message.text": {'$regex': 'ALERT:You\'ve spent Rs.([0-9.]+) on'},
            "status.analysis_done": {'$ne': True}} #             
        ).sort([("message.date",1)]))):
    print("message", _item[1])
    _transaction = hdfcCreditCardInterpreter2(_item[1]['message']['text'])
    print("analysis", _transaction, "\n\n")
    if _transaction != {}:
        result = collection.update_one(
            {'_id': bson.ObjectId(str(_item[1]['_id']))},
            {'$set' : {'transaction': _transaction, 'status': {'analysis_done': True}}})
        print('success' if result.modified_count == 1 else 'unsuccessful')
        
for _item in list(
    enumerate(
        collection.find({
            "message.text": {'$regex': 'ALERT:You\'ve spent Rs.([0-9.]+) via'},
} #             "status.analysis_done": {'$ne': True}
        ).sort([("message.date",1)]))):
    print("message", _item[1])
    _transaction = hdfcCreditCardInterpreterVia(_item[1]['message']['text'])
    print("analysis", _transaction, "\n\n")
    if _transaction != {}:
        result = collection.update_one(
            {'_id': bson.ObjectId(str(_item[1]['_id']))},
            {'$set' : {'transaction': _transaction, 'status': {'analysis_done': True}}})
        print('success' if result.modified_count == 1 else 'unsuccessful')
# Out:
# message {'_id': ObjectId('5e26daadd64bdc5152d03248'), 'message': {'text': "ALERT:You've spent Rs.3638.00 via Debit Card xx6504 at www.lenskart.c on 2019-01-14:20:29:59.Avl Bal Rs.264666.51.Not you?Call 18002586161.", 'date': 569170804628270016, 'guid': 'E444A878-FC20-6B86-E7FC-6806D93E74E6'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 3638.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.lenskart.c', 'datetime': datetime.datetime(2019, 1, 14, 20, 29, 59)}
#
#
# success
# message {'_id': ObjectId('5e26daadd64bdc5152d03249'), 'message': {'text': "ALERT:You've spent Rs.102.00 via Debit Card xx6504 at M.K.RETAIL COMPANY on 2019-01-15:20:46:22.Avl Bal Rs.264564.51.Not you?Call 18002586161.", 'date': 569258193092419008, 'guid': 'D47AF885-55D6-9F7F-B00D-169BC5EC835D'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 102.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'M.K.RETAIL COMPANY', 'datetime': datetime.datetime(2019, 1, 15, 20, 46, 22)}
#
#
# success
# message {'_id': ObjectId('5e26daadd64bdc5152d0324c'), 'message': {'text': "ALERT:You've spent Rs.685.00 via Debit Card xx6504 at BPCL on 2019-01-15:21:35:11.Avl Bal Rs.263879.51.Not you?Call 18002586161.", 'date': 569261124629058944, 'guid': 'FFDAD4F2-11AF-B280-188F-22E84C2CB143'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 685.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'BPCL', 'datetime': datetime.datetime(2019, 1, 15, 21, 35, 11)}
#
#
# success
# message {'_id': ObjectId('5e26daaed64bdc5152d03250'), 'message': {'text': "ALERT:You've spent Rs.1028.00 via Debit Card xx6504 at GLENS BAKE HOUSE on 2019-01-16:15:40:50.Avl Bal Rs.262851.51.Not you?Call 18002586161.", 'date': 569326260224279040, 'guid': 'AC102505-54F7-77E0-B000-434F17643158'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1028.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'GLENS BAKE HOUSE', 'datetime': datetime.datetime(2019, 1, 16, 15, 40, 50)}
#
#
# success
# message {'_id': ObjectId('5e26daaed64bdc5152d03251'), 'message': {'text': "ALERT:You've spent Rs.229.00 via Debit Card xx6504 at GLENS BAKE HOUSE on 2019-01-16:15:45:53.Avl Bal Rs.262622.51.Not you?Call 18002586161.", 'date': 569326561620079040, 'guid': '39E9E3D5-AEA8-FCBF-CCCF-75E71DD1A94D'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 229.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'GLENS BAKE HOUSE', 'datetime': datetime.datetime(2019, 1, 16, 15, 45, 53)}
#
#
# success
# message {'_id': ObjectId('5e26daaed64bdc5152d03254'), 'message': {'text': "ALERT:You've spent Rs.1899.00 via Debit Card xx6504 at AMAZON on 2019-01-16:21:45:34.Avl Bal Rs.261347.21.Not you?Call 18002586161.", 'date': 569348147626955008, 'guid': '0B9667EA-0EFD-DACE-134B-57B8C9F2DD88'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1899.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'AMAZON', 'datetime': datetime.datetime(2019, 1, 16, 21, 45, 34)}
#
#
# success
# message {'_id': ObjectId('5e26daafd64bdc5152d03258'), 'message': {'text': "ALERT:You've spent Rs.238.00 via Debit Card xx6504 at www.swiggy.in on 2019-01-17:07:52:12.Avl Bal Rs.261109.21.Not you?Call 18002586161.", 'date': 569384537501243008, 'guid': 'F79E01A1-611D-7DA7-ECD7-30878E431DC8'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 238.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 1, 17, 7, 52, 12)}
#
#
# success
# message {'_id': ObjectId('5e26daafd64bdc5152d0325a'), 'message': {'text': "ALERT:You've spent Rs.165.00 via Debit Card xx6504 at PAYTM on 2019-01-17:14:58:00.Avl Bal Rs.260944.21.Not you?Call 18002586161.", 'date': 569410084855393024, 'guid': '4F1B58C7-819C-A58D-4125-F658F14D0257'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 165.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 1, 17, 14, 58)}
#
#
# success
# message {'_id': ObjectId('5e26dab0d64bdc5152d0325f'), 'message': {'text': "ALERT:You've spent Rs.280.00 via Debit Card xx6504 at SWIGGY on 2019-01-18:09:00:37.Avl Bal Rs.260654.21.Not you?Call 18002586161.", 'date': 569475050240898944, 'guid': '7A6356DD-4F37-57B3-4762-D3257F0B1B53'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 280.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 1, 18, 9, 0, 37)}
#
#
# success
# message {'_id': ObjectId('5e26dab0d64bdc5152d03262'), 'message': {'text': "ALERT:You've spent Rs.160.00 via Debit Card xx6504 at PAYTMWAL1210203 on 2019-01-18:15:27:48.Avl Bal Rs.260494.21.Not you?Call 18002586161.", 'date': 569498281705317952, 'guid': '30E568E1-A5B6-11C1-81D5-6E41DEC3430A'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 160.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTMWAL1210203', 'datetime': datetime.datetime(2019, 1, 18, 15, 27, 48)}
#
#
# success
# message {'_id': ObjectId('5e26dab0d64bdc5152d03265'), 'message': {'text': "ALERT:You've spent Rs.18.00 via Debit Card xx6504 at PAYTMWAL1210203 on 2019-01-18:18:46:21.Avl Bal Rs.260476.21.Not you?Call 18002586161.", 'date': 569510190084401984, 'guid': '52D224D2-4052-0D2C-3E42-D8ED01C33271'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 18.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTMWAL1210203', 'datetime': datetime.datetime(2019, 1, 18, 18, 46, 21)}
#
#
# success
# message {'_id': ObjectId('5e26dab1d64bdc5152d0326b'), 'message': {'text': "ALERT:You've spent Rs.159.00 via Debit Card xx6504 at PAYTMWAL1210203 on 2019-01-18:20:58:44.Avl Bal Rs.261997.21.Not you?Call 18002586161.", 'date': 569518134613024960, 'guid': '92FD9F3C-16C2-98BA-110D-B4D0F54EE098'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 159.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTMWAL1210203', 'datetime': datetime.datetime(2019, 1, 18, 20, 58, 44)}
#
#
# success
# message {'_id': ObjectId('5e26dab1d64bdc5152d0326d'), 'message': {'text': "ALERT:You've spent Rs.478.00 via Debit Card xx6504 at www.swiggy.in on 2019-01-18:22:07:37.Avl Bal Rs.261519.21.Not you?Call 18002586161.", 'date': 569522268786236032, 'guid': '1EECCB75-47A7-8E84-BDB9-D8A05DB3EB05'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 478.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 1, 18, 22, 7, 37)}
#
#
# success
# message {'_id': ObjectId('5e26dab2d64bdc5152d03270'), 'message': {'text': "ALERT:You've spent Rs.631.00 via Debit Card xx6504 at PAYTM on 2019-01-19:09:52:31.Avl Bal Rs.260888.21.Not you?Call 18002586161.", 'date': 569564556829673024, 'guid': 'ED715C6A-3B59-251F-0E63-53DDC5151194'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 631.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 1, 19, 9, 52, 31)}
#
#
# success
# message {'_id': ObjectId('5e26dab2d64bdc5152d03272'), 'message': {'text': "ALERT:You've spent Rs.1162.00 via Debit Card xx6504 at FURLENCO1203619 on 2019-01-19:16:16:47.Avl Bal Rs.259726.21.Not you?Call 18002586161.", 'date': 569587613424146048, 'guid': 'A13B045F-72D0-BA45-64BB-887A546BE1AA'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1162.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'FURLENCO1203619', 'datetime': datetime.datetime(2019, 1, 19, 16, 16, 47)}
#
#
# success
# message {'_id': ObjectId('5e26dab3d64bdc5152d03279'), 'message': {'text': "ALERT:You've spent Rs.182.00 via Debit Card xx6504 at www.swiggy.in on 2019-01-20:10:58:20.Avl Bal Rs.259499.21.Not you?Call 18002586161.", 'date': 569654915815408000, 'guid': '243B6FA1-1B59-CF6E-7B74-5FA396566787'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 182.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 1, 20, 10, 58, 20)}
#
#
# success
# message {'_id': ObjectId('5e26dab3d64bdc5152d0327b'), 'message': {'text': "ALERT:You've spent Rs.246.00 via Debit Card xx6504 at SWIGGY on 2019-01-20:11:23:16.Avl Bal Rs.259253.21.Not you?Call 18002586161.", 'date': 569656410855739008, 'guid': 'D04761B3-884F-5136-32A8-A45FC84A684B'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 246.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 1, 20, 11, 23, 16)}
#
#
# success
# message {'_id': ObjectId('5e26dab3d64bdc5152d0327e'), 'message': {'text': "ALERT:You've spent Rs.394.00 via Debit Card xx6504 at SWIGGY on 2019-01-20:14:44:43.Avl Bal Rs.258859.21.Not you?Call 18002586161.", 'date': 569668496779535040, 'guid': '0F0832A8-E94A-CFA1-1CCD-0D038708C876'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 394.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 1, 20, 14, 44, 43)}
#
#
# success
# message {'_id': ObjectId('5e26dab3d64bdc5152d0327f'), 'message': {'text': "ALERT:You've spent Rs.517.58 via Debit Card xx6504 at M K RETAIL on 2019-01-20:19:26:22.Avl Bal Rs.258341.63.Not you?Call 18002586161.", 'date': 569685387916612032, 'guid': '5AB1F44B-2DD3-B628-148F-3A1A712C8A87'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 517.58, 'payment_mode': 'Debit Card xx6504', 'merchant': 'M K RETAIL', 'datetime': datetime.datetime(2019, 1, 20, 19, 26, 22)}
#
#
# success
# message {'_id': ObjectId('5e26dab4d64bdc5152d03280'), 'message': {'text': "ALERT:You've spent Rs.290.00 via Debit Card xx6504 at M K RETAIL on 2019-01-20:19:44:01.Avl Bal Rs.258051.63.Not you?Call 18002586161.", 'date': 569686449633919936, 'guid': '074CE8D2-219E-206A-9BCA-2B0E4E60D088'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 290.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'M K RETAIL', 'datetime': datetime.datetime(2019, 1, 20, 19, 44, 1)}
# success
# message {'_id': ObjectId('5e26dab4d64bdc5152d03282'), 'message': {'text': "ALERT:You've spent Rs.79.00 via Debit Card xx6504 at www.swiggy.in on 2019-01-21:09:44:03.Avl Bal Rs.257972.63.Not you?Call 18002586161.", 'date': 569736856353041024, 'guid': 'AE9550E1-3A72-FC8D-5F45-EE90657E10A3'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 79.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 1, 21, 9, 44, 3)}
#
#
# success
# message {'_id': ObjectId('5e26dab4d64bdc5152d03285'), 'message': {'text': "ALERT:You've spent Rs.110.00 via Debit Card xx6504 at SWIGGY1368042 on 2019-01-21:10:40:15.Avl Bal Rs.257862.63.Not you?Call 18002586161.", 'date': 569740224422060032, 'guid': '1AEC17BE-8564-F0B9-51CE-27EF6BE34FDF'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 110.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY1368042', 'datetime': datetime.datetime(2019, 1, 21, 10, 40, 15)}
#
#
# success
# message {'_id': ObjectId('5e26dab5d64bdc5152d03288'), 'message': {'text': "ALERT:You've spent Rs.112.12 via Debit Card xx6504 at UBER61701 on 2019-01-21:16:31:22.Avl Bal Rs.257750.51.Not you?Call 18002586161.", 'date': 569761296563395008, 'guid': 'B7BFA6DB-4972-1AA4-3D04-C0F91687935E'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 112.12, 'payment_mode': 'Debit Card xx6504', 'merchant': 'UBER61701', 'datetime': datetime.datetime(2019, 1, 21, 16, 31, 22)}
#
#
# success
# message {'_id': ObjectId('5e26dab5d64bdc5152d03289'), 'message': {'text': "ALERT:You've spent Rs.65.00 via Debit Card xx6504 at MEDPLUS NO 188 on 2019-01-21:19:38:08.Avl Bal Rs.257685.51.Not you?Call 18002586161.", 'date': 569772500848940032, 'guid': 'B0A49854-9609-D3C2-CDF9-7D08431AA467'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 65.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'MEDPLUS NO 188', 'datetime': datetime.datetime(2019, 1, 21, 19, 38, 8)}
#
#
# success
# message {'_id': ObjectId('5e26dab5d64bdc5152d0328c'), 'message': {'text': "ALERT:You've spent Rs.125.00 via Debit Card xx6504 at SWIGGY on 2019-01-22:09:00:51.Avl Bal Rs.257560.51.Not you?Call 18002586161.", 'date': 569820661755408064, 'guid': '780958C4-BD65-C0D6-8AA6-56842AA2844C'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 125.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 1, 22, 9, 0, 51)}
#
#
# success
# message {'_id': ObjectId('5e26dab6d64bdc5152d0328f'), 'message': {'text': "ALERT:You've spent Rs.284.00 via Debit Card xx6504 at SWIGGY1368042 on 2019-01-22:13:06:29.Avl Bal Rs.257276.51.Not you?Call 18002586161.", 'date': 569835401694111936, 'guid': 'B34FF22B-802C-E39B-7040-3F2D4D5300E8'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 284.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY1368042', 'datetime': datetime.datetime(2019, 1, 22, 13, 6, 29)}
#
#
# success
# message {'_id': ObjectId('5e26dab6d64bdc5152d03293'), 'message': {'text': "ALERT:You've spent Rs.1.00 via Debit Card xx6504 at GOOGLE *SERVICES on 2019-01-22:18:52:23.Avl Bal Rs.257085.51.Not you?Call 18002586161.", 'date': 569856149597075008, 'guid': '4FF452C6-6B48-FACD-2D51-6BAD3191754B'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26dab6d64bdc5152d03295'), 'message': {'text': "ALERT:You've spent Rs.200.03 via Debit Card xx6504 at PACKT PUBLISHING L on 2019-01-22:18:53:38.Avl Bal Rs.256885.48.Not you?Call 18002586161.", 'date': 569856223498873024, 'guid': '3320A9B6-ECB7-2313-81B4-F0273FCBB67D'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 200.03, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PACKT PUBLISHING L', 'datetime': datetime.datetime(2019, 1, 22, 18, 53, 38)}
#
#
# success
# message {'_id': ObjectId('5e26dab7d64bdc5152d03298'), 'message': {'text': "ALERT:You've spent Rs.650.00 via Debit Card xx6504 at VISTAPRINT60645 on 2019-01-22:21:32:25.Avl Bal Rs.256236.48.Not you?Call 18002586161.", 'date': 569865746414664960, 'guid': 'C3895E4F-7ACF-62B9-A833-ED6E0EE96733'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 650.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'VISTAPRINT60645', 'datetime': datetime.datetime(2019, 1, 22, 21, 32, 25)}
#
#
# success
# message {'_id': ObjectId('5e26dab7d64bdc5152d0329a'), 'message': {'text': "ALERT:You've spent Rs.397.64 via Debit Card xx6504 at PACKT PUBLISHING L on 2019-01-22:22:00:58.Avl Bal Rs.255838.84.Not you?Call 18002586161.", 'date': 569867462048316032, 'guid': 'F96A22D0-8529-27E8-D651-9313F11AC226'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 397.64, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PACKT PUBLISHING L', 'datetime': datetime.datetime(2019, 1, 22, 22, 0, 58)}
#
#
# success
# message {'_id': ObjectId('5e26dab8d64bdc5152d0329c'), 'message': {'text': "ALERT:You've spent Rs.125.00 via Debit Card xx6504 at SWIGGY on 2019-01-23:09:08:41.Avl Bal Rs.255713.84.Not you?Call 18002586161.", 'date': 569907536647483008, 'guid': '4577D451-4CC2-E357-0838-346E9515DAB5'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 125.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 1, 23, 9, 8, 41)}
#
#
# success
# message {'_id': ObjectId('5e26dab8d64bdc5152d0329e'), 'message': {'text': "ALERT:You've spent Rs.160.00 via Debit Card xx6504 at SWIGGY1368042 on 2019-01-23:10:09:49.Avl Bal Rs.255553.84.Not you?Call 18002586161.", 'date': 569911195200739968, 'guid': '9306FF0C-40B7-F01C-C20C-D03531A0299D'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 160.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY1368042', 'datetime': datetime.datetime(2019, 1, 23, 10, 9, 49)}
#
#
# success
# message {'_id': ObjectId('5e26dab9d64bdc5152d032a5'), 'message': {'text': "ALERT:You've spent Rs.125.00 via Debit Card xx6504 at SWIGGY on 2019-01-24:09:11:15.Avl Bal Rs.255383.84.Not you?Call 18002586161.", 'date': 569994228583260032, 'guid': '6851C98B-B458-BB00-3D0B-E1D97F3B3C63'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 125.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 1, 24, 9, 11, 15)}
#
#
# success
# message {'_id': ObjectId('5e26dab9d64bdc5152d032a8'), 'message': {'text': "ALERT:You've spent Rs.160.00 via Debit Card xx6504 at www.swiggy.in on 2019-01-24:10:11:14.Avl Bal Rs.255223.84.Not you?Call 18002586161.", 'date': 569997680725196928, 'guid': 'E4155C36-9AFC-C2FC-4279-166BDAED1E89'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 160.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 1, 24, 10, 11, 14)}
#
#
# success
# message {'_id': ObjectId('5e26dabad64bdc5152d032ac'), 'message': {'text': "ALERT:You've spent Rs.173.00 via Debit Card xx6504 at SWIGGY1368042 on 2019-01-24:15:38:28.Avl Bal Rs.255241.99.Not you?Call 18002586161.", 'date': 570017320976202944, 'guid': '84827DED-ED79-D80A-6F03-E6D8CE62CC56'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 173.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY1368042', 'datetime': datetime.datetime(2019, 1, 24, 15, 38, 28)}
#
#
# success
# message {'_id': ObjectId('5e26dabad64bdc5152d032ae'), 'message': {'text': "ALERT:You've spent Rs.366.00 via Debit Card xx6504 at PHD.,. on 2019-01-24:20:23:21.Avl Bal Rs.254872.25.Not you?Call 18002586161.", 'date': 570034413884677056, 'guid': 'DFE764E6-93F0-8608-1F76-2098A60540F0'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26dabbd64bdc5152d032af'), 'message': {'text': "ALERT:You've spent Rs.109.72 via Debit Card xx6504 at M K RETAIL on 2019-01-24:20:26:39.Avl Bal Rs.254762.53.Not you?Call 18002586161.", 'date': 570034613395179008, 'guid': 'CA74075D-8CC4-F2E8-FFDA-D37E00971B77'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 109.72, 'payment_mode': 'Debit Card xx6504', 'merchant': 'M K RETAIL', 'datetime': datetime.datetime(2019, 1, 24, 20, 26, 39)}
#
#
# success
# message {'_id': ObjectId('5e26dabbd64bdc5152d032b2'), 'message': {'text': "ALERT:You've spent Rs.818.00 via Debit Card xx6504 at PAYTM on 2019-01-25:19:57:04.Avl Bal Rs.253944.53.Not you?Call 18002586161.", 'date': 570119233931748992, 'guid': '461C4F66-6D28-45AB-4A1E-AE4DF285A9BE'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 818.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 1, 25, 19, 57, 4)}
# success
# message {'_id': ObjectId('5e26dabcd64bdc5152d032b7'), 'message': {'text': "ALERT:You've spent Rs.93.31 via Debit Card xx6504 at Zaak Epayment Services on 2019-01-26:16:10:30.Avl Bal Rs.253851.22.Not you?Call 18002586161.", 'date': 570192042286133056, 'guid': '4BE9A31A-1CE2-2308-320C-8B7ED6A0DE18'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 93.31, 'payment_mode': 'Debit Card xx6504', 'merchant': 'Zaak Epayment Services', 'datetime': datetime.datetime(2019, 1, 26, 16, 10, 30)}
#
#
# success
# message {'_id': ObjectId('5e26dabcd64bdc5152d032b9'), 'message': {'text': "ALERT:You've spent Rs.105.90 via Debit Card xx6504 at Zaak Epayment Services on 2019-01-26:17:47:30.Avl Bal Rs.253745.32.Not you?Call 18002586161.", 'date': 570197864650207040, 'guid': '57BDA2BD-A52B-6FB2-C192-DA6F454CD1B2'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 105.9, 'payment_mode': 'Debit Card xx6504', 'merchant': 'Zaak Epayment Services', 'datetime': datetime.datetime(2019, 1, 26, 17, 47, 30)}
#
#
# success
# message {'_id': ObjectId('5e26dabcd64bdc5152d032ba'), 'message': {'text': "ALERT:You've spent Rs.375.00 via Debit Card xx6504 at MAC FAST FOODS on 2019-01-26:18:06:56.Avl Bal Rs.253370.32.Not you?Call 18002586161.", 'date': 570199019586822976, 'guid': '7FF8922A-89AD-3F00-A605-7C97559BA803'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 375.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'MAC FAST FOODS', 'datetime': datetime.datetime(2019, 1, 26, 18, 6, 56)}
#
#
# success
# message {'_id': ObjectId('5e26dabdd64bdc5152d032bc'), 'message': {'text': "ALERT:You've spent Rs.868.00 via Debit Card xx6504 at M K RETAIL on 2019-01-27:20:07:53.Avl Bal Rs.252452.32.Not you?Call 18002586161.", 'date': 570292687728979008, 'guid': '607360B7-0CC1-7532-14D3-6920A7F1A65F'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 868.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'M K RETAIL', 'datetime': datetime.datetime(2019, 1, 27, 20, 7, 53)}
#
#
# success
# message {'_id': ObjectId('5e26dabdd64bdc5152d032be'), 'message': {'text': "ALERT:You've spent Rs.124.17 via Debit Card xx6504 at Zaak Epayment Services on 2019-01-28:09:16:49.Avl Bal Rs.252328.15.Not you?Call 18002586161.", 'date': 570340026893394944, 'guid': '461E8391-E177-4174-92E8-A59D0589B1DD'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 124.17, 'payment_mode': 'Debit Card xx6504', 'merchant': 'Zaak Epayment Services', 'datetime': datetime.datetime(2019, 1, 28, 9, 16, 49)}
#
#
# success
# message {'_id': ObjectId('5e26dabdd64bdc5152d032c0'), 'message': {'text': "ALERT:You've spent Rs.453.10 via Debit Card xx6504 at AMAZON on 2019-01-28:23:07:52.Avl Bal Rs.422806.22.Not you?Call 18002586161.", 'date': 570389883664041024, 'guid': '8CBDD48F-9E4D-A145-6F55-49AD527DFF3D'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 453.1, 'payment_mode': 'Debit Card xx6504', 'merchant': 'AMAZON', 'datetime': datetime.datetime(2019, 1, 28, 23, 7, 52)}
#
#
# success
# message {'_id': ObjectId('5e26dabed64bdc5152d032c4'), 'message': {'text': "ALERT:You've spent Rs.372.00 via Debit Card xx6504 at PAYTM on 2019-01-29:11:05:43.Avl Bal Rs.422434.22.Not you?Call 18002586161.", 'date': 570432957857424000, 'guid': '6C5F220A-B1E9-E9F5-C3F2-C4E9A23414C8'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 372.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 1, 29, 11, 5, 43)}
#
#
# success
# message {'_id': ObjectId('5e26dabed64bdc5152d032c5'), 'message': {'text': "ALERT:You've spent Rs.180.00 via Debit Card xx6504 at SOLANKI MEDICALS on 2019-01-29:20:35:30.Avl Bal Rs.422254.22.Not you?Call 18002586161.", 'date': 570467140546507008, 'guid': 'CD20531D-7A40-6EA6-7047-08EEA29BD4AB'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 180.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SOLANKI MEDICALS', 'datetime': datetime.datetime(2019, 1, 29, 20, 35, 30)}
#
#
# success
# message {'_id': ObjectId('5e26dabed64bdc5152d032c6'), 'message': {'text': "ALERT:You've spent Rs.530.00 via Debit Card xx6504 at KAAYAL on 2019-01-30:15:18:42.Avl Bal Rs.420839.22.Not you?Call 18002586161.", 'date': 570534533503229952, 'guid': '30C80168-8B09-FA84-D1D3-2A92089A9727'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 530.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'KAAYAL', 'datetime': datetime.datetime(2019, 1, 30, 15, 18, 42)}
#
#
# success
# message {'_id': ObjectId('5e26dabed64bdc5152d032c8'), 'message': {'text': "ALERT:You've spent Rs.10.00 via Debit Card xx6504 at PAYTM on 2019-01-30:18:58:31.Avl Bal Rs.420829.22.Not you?Call 18002586161.", 'date': 570547723231219072, 'guid': '8C4C9B29-6EC0-6B5C-1D98-76BF928F3DD2'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 10.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 1, 30, 18, 58, 31)}
#
#
# success
# message {'_id': ObjectId('5e26dabfd64bdc5152d032cc'), 'message': {'text': "ALERT:You've spent Rs.99.00 via Debit Card xx6504 at Zaak Epayment Services on 2019-01-31:17:43:35.Avl Bal Rs.420678.22.Not you?Call 18002586161.", 'date': 570629620470243008, 'guid': '5FC8DC28-6EC0-AEF4-AA71-597C0083457C'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'Zaak Epayment Services', 'datetime': datetime.datetime(2019, 1, 31, 17, 43, 35)}
#
#
# success
# message {'_id': ObjectId('5e26dac0d64bdc5152d032cf'), 'message': {'text': "ALERT:You've spent Rs.111.18 via Debit Card xx6504 at Zaak Epayment Services on 2019-01-31:18:07:51.Avl Bal Rs.420567.04.Not you?Call 18002586161.", 'date': 570631081337096000, 'guid': 'C01CC0B2-E3AB-1645-86C9-464FDEE3C6BD'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 111.18, 'payment_mode': 'Debit Card xx6504', 'merchant': 'Zaak Epayment Services', 'datetime': datetime.datetime(2019, 1, 31, 18, 7, 51)}
#
#
# success
# message {'_id': ObjectId('5e26dac0d64bdc5152d032d1'), 'message': {'text': "ALERT:You've spent Rs.20.00 via Debit Card xx6504 at PAYTM on 2019-01-31:19:49:23.Avl Bal Rs.420547.04.Not you?Call 18002586161.", 'date': 570637175542826048, 'guid': '69D6DF79-D0F6-B6C4-E37E-BAD1C87EA561'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 20.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 1, 31, 19, 49, 23)}
#
#
# success
# message {'_id': ObjectId('5e26dac0d64bdc5152d032d3'), 'message': {'text': "ALERT:You've spent Rs.213.00 via Debit Card xx6504 at PAYTM on 2019-01-31:19:54:04.Avl Bal Rs.420334.04.Not you?Call 18002586161.", 'date': 570637451837591040, 'guid': '2045A00D-E859-2F90-25B2-F95F5FFD0D9E'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 213.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 1, 31, 19, 54, 4)}
#
#
# success
# message {'_id': ObjectId('5e26dac1d64bdc5152d032d7'), 'message': {'text': "ALERT:You've spent Rs.150.00 via Debit Card xx6504 at www.swiggy.in on 2019-02-01:08:11:09.Avl Bal Rs.420099.04.Not you?Call 18002586161.", 'date': 570681696037179008, 'guid': 'B336B171-D782-3543-95FC-B6C2EFA206BD'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 150.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 2, 1, 8, 11, 9)}
#
#
# success
# message {'_id': ObjectId('5e26dac1d64bdc5152d032db'), 'message': {'text': "ALERT:You've spent Rs.120.00 via Debit Card xx6504 at www.swiggy.in on 2019-02-01:14:12:51.Avl Bal Rs.419830.04.Not you?Call 18002586161.", 'date': 570703381617691968, 'guid': 'DB0AE38E-D09C-524B-C48B-B1858306DA1E'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 120.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 2, 1, 14, 12, 51)}
# success
# message {'_id': ObjectId('5e26dac2d64bdc5152d032dd'), 'message': {'text': "ALERT:You've spent Rs.120.00 via Debit Card xx6504 at www.swiggy.in on 2019-02-01:14:15:05.Avl Bal Rs.419710.04.Not you?Call 18002586161.", 'date': 570703513183253056, 'guid': 'E99F7F31-54C3-0394-F298-25C98FD6DCD1'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 120.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 2, 1, 14, 15, 5)}
#
#
# success
# message {'_id': ObjectId('5e26dac2d64bdc5152d032df'), 'message': {'text': "ALERT:You've spent Rs.499.00 via Debit Card xx6504 at PAYTM1293914 on 2019-02-01:19:15:33.Avl Bal Rs.421110.04.Not you?Call 18002586161.", 'date': 570721550539266944, 'guid': '2044C2EE-20A7-02F3-6AD3-E4A023620B8B'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 499.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM1293914', 'datetime': datetime.datetime(2019, 2, 1, 19, 15, 33)}
#
#
# success
# message {'_id': ObjectId('5e26dac3d64bdc5152d032e3'), 'message': {'text': "ALERT:You've spent Rs.25.05 via Debit Card xx6504 at PAYTM on 2019-02-01:21:58:38.Avl Bal Rs.420864.99.Not you?Call 18002586161.", 'date': 570731328044186944, 'guid': 'CE433300-577A-6A1A-28A5-0A5A2A968F26'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 25.05, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 2, 1, 21, 58, 38)}
#
#
# success
# message {'_id': ObjectId('5e26dac3d64bdc5152d032e6'), 'message': {'text': "ALERT:You've spent Rs.12.00 via Debit Card xx6504 at PAYTM on 2019-02-01:22:17:18.Avl Bal Rs.420852.99.Not you?Call 18002586161.", 'date': 570732445816809984, 'guid': 'C4EC6CD6-F65F-60D2-8D02-69E35B57E1B2'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 12.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 2, 1, 22, 17, 18)}
#
#
# success
# message {'_id': ObjectId('5e26dac4d64bdc5152d032e9'), 'message': {'text': "ALERT:You've spent Rs.110.00 via Debit Card xx6504 at www.swiggy.in on 2019-02-02:09:58:59.Avl Bal Rs.398742.99.Not you?Call 18002586161.", 'date': 570774552274526976, 'guid': '16826D2A-8EB9-4B74-65B6-FB026AAE168C'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 110.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 2, 2, 9, 58, 59)}
#
#
# success
# message {'_id': ObjectId('5e26dac4d64bdc5152d032eb'), 'message': {'text': "ALERT:You've spent Rs.110.00 via Debit Card xx6504 at www.swiggy.in on 2019-02-02:09:59:48.Avl Bal Rs.398632.99.Not you?Call 18002586161.", 'date': 570774654095523008, 'guid': '1EFE066C-B99D-0DCD-FE33-A30CEA95D0C5'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 110.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 2, 2, 9, 59, 48)}
#
#
# success
# message {'_id': ObjectId('5e26dac4d64bdc5152d032ed'), 'message': {'text': "ALERT:You've spent Rs.353.00 via Debit Card xx6504 at www.swiggy.in on 2019-02-02:17:02:26.Avl Bal Rs.398279.99.Not you?Call 18002586161.", 'date': 570799955207097984, 'guid': '8FBD2799-008C-EC00-6C32-E712B370105D'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 353.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 2, 2, 17, 2, 26)}
#
#
# success
# message {'_id': ObjectId('5e26dac4d64bdc5152d032ee'), 'message': {'text': "ALERT:You've spent Rs.500.00 via Debit Card xx6504 at MADHULOKA THE on 2019-02-02:19:58:03.Avl Bal Rs.397779.99.Not you?Call 18002586161.", 'date': 570810506314952000, 'guid': 'F5D0F3C9-2F92-ADE5-DAB5-4E2CA4DD0376'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 500.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'MADHULOKA THE', 'datetime': datetime.datetime(2019, 2, 2, 19, 58, 3)}
#
#
# success
# message {'_id': ObjectId('5e26dac5d64bdc5152d032f0'), 'message': {'text': "ALERT:You've spent Rs.307.00 via Debit Card xx6504 at SWIGGY on 2019-02-03:02:34:16.Avl Bal Rs.397472.99.Not you?Call 18002586161.", 'date': 570834265971312064, 'guid': 'F7653156-A7D3-983E-2CB4-F88BA539E321'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 307.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 2, 3, 2, 34, 16)}
#
#
# success
# message {'_id': ObjectId('5e26dac5d64bdc5152d032f3'), 'message': {'text': "ALERT:You've spent Rs.1180.00 via Debit Card xx6504 at MARKET CITY on 2019-02-03:14:09:08.Avl Bal Rs.396192.99.Not you?Call 18002586161.", 'date': 570875956992568960, 'guid': '7C992A43-85BA-EDAB-EDCC-2843DC126FD1'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1180.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'MARKET CITY', 'datetime': datetime.datetime(2019, 2, 3, 14, 9, 8)}
#
#
# success
# message {'_id': ObjectId('5e26dac6d64bdc5152d032f5'), 'message': {'text': "ALERT:You've spent Rs.20.00 via Debit Card xx6504 at PAYTM on 2019-02-03:19:31:52.Avl Bal Rs.396172.99.Not you?Call 18002586161.", 'date': 570895328851917056, 'guid': 'BC09035C-9B83-AD88-55EC-6B5DFAFAB9D2'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 20.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 2, 3, 19, 31, 52)}
#
#
# success
# message {'_id': ObjectId('5e26dac6d64bdc5152d032f9'), 'message': {'text': "ALERT:You've spent Rs.12.00 via Debit Card xx6504 at PAYTM on 2019-02-03:21:05:11.Avl Bal Rs.394793.37.Not you?Call 18002586161.", 'date': 570900921732146048, 'guid': '99339833-9CB5-5FC7-0662-026E9A973FA5'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 12.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 2, 3, 21, 5, 11)}
#
#
# success
# message {'_id': ObjectId('5e26dac6d64bdc5152d032fb'), 'message': {'text': "ALERT:You've spent Rs.133.00 via Debit Card xx6504 at Swiggy on 2019-02-04:09:48:43.Avl Bal Rs.394660.37.Not you?Call 18002586161.", 'date': 570946731428936000, 'guid': '714F9B11-0A92-C961-4414-0654D0374D7A'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 133.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'Swiggy', 'datetime': datetime.datetime(2019, 2, 4, 9, 48, 43)}
#
#
# success
# message {'_id': ObjectId('5e26dac7d64bdc5152d032fd'), 'message': {'text': "ALERT:You've spent Rs.83.00 via Debit Card xx6504 at www.swiggy.in on 2019-02-04:13:48:32.Avl Bal Rs.394577.37.Not you?Call 18002586161.", 'date': 570961124528267008, 'guid': 'BC742DCD-942F-D1C5-E210-CC1284EC2677'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 83.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 2, 4, 13, 48, 32)}
#
#
# success
# message {'_id': ObjectId('5e26dac7d64bdc5152d032fe'), 'message': {'text': "ALERT:You've spent Rs.2100.00 via Debit Card xx6504 at HINDUSTAN PETROLEUM CO on 2019-02-04:16:24:08.Avl Bal Rs.392477.37.Not you?Call 18002586161.", 'date': 570970463456712960, 'guid': '4E7CE9B6-4BF4-2992-37E6-CA98E636F6D7'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 2100.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'HINDUSTAN PETROLEUM CO', 'datetime': datetime.datetime(2019, 2, 4, 16, 24, 8)}
#
#
# success
# message {'_id': ObjectId('5e26dac7d64bdc5152d03300'), 'message': {'text': "ALERT:You've spent Rs.1199.00 via Debit Card xx6504 at MYNTRA90914 on 2019-02-04:17:47:09.Avl Bal Rs.391278.37.Not you?Call 18002586161.", 'date': 570975440016239040, 'guid': 'F5684450-3846-ED3F-8D02-49C0A885E05B'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1199.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'MYNTRA90914', 'datetime': datetime.datetime(2019, 2, 4, 17, 47, 9)}
#
#
# success
# message {'_id': ObjectId('5e26dac7d64bdc5152d03301'), 'message': {'text': "ALERT:You've spent Rs.236.00 via Debit Card xx6504 at GREEN TRENDS LIMELITE on 2019-02-04:18:55:20.Avl Bal Rs.391042.37.Not you?Call 18002586161.", 'date': 570979532862710976, 'guid': 'E0978DB2-C9EB-19EF-74E2-CD7CBE894014'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 236.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'GREEN TRENDS LIMELITE', 'datetime': datetime.datetime(2019, 2, 4, 18, 55, 20)}
#
#
# success
# message {'_id': ObjectId('5e26dac8d64bdc5152d03303'), 'message': {'text': "ALERT:You've spent Rs.567.00 via Debit Card xx6504 at SWIGGY on 2019-02-05:20:00:29.Avl Bal Rs.390475.37.Not you?Call 18002586161.", 'date': 571069836872472064, 'guid': '0F7383A0-0204-3BD3-4171-ACE0F3A9E57B'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 567.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 2, 5, 20, 0, 29)}
#
#
# success
# message {'_id': ObjectId('5e26dac8d64bdc5152d03305'), 'message': {'text': "ALERT:You've spent Rs.125.00 via Debit Card xx6504 at SWIGGY on 2019-02-06:09:29:55.Avl Bal Rs.390350.37.Not you?Call 18002586161.", 'date': 571118401285144000, 'guid': 'F8ABF204-F033-F3FC-E0DE-5DCEE99756AA'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 125.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 2, 6, 9, 29, 55)}
# success
# message {'_id': ObjectId('5e26dac8d64bdc5152d03308'), 'message': {'text': "ALERT:You've spent Rs.133.00 via Debit Card xx6504 at www.swiggy.in on 2019-02-06:09:32:17.Avl Bal Rs.390217.37.Not you?Call 18002586161.", 'date': 571118548730422976, 'guid': 'DB0D51D7-F660-CC07-F2A7-6F7364627824'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 133.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 2, 6, 9, 32, 17)}
#
#
# success
# message {'_id': ObjectId('5e26dac9d64bdc5152d0330a'), 'message': {'text': "ALERT:You've spent Rs.83.00 via Debit Card xx6504 at SWIGGY on 2019-02-06:12:34:52.Avl Bal Rs.390134.37.Not you?Call 18002586161.", 'date': 571129499284508928, 'guid': '0B205454-53D4-BFEA-50E4-09C230362679'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 83.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 2, 6, 12, 34, 52)}
#
#
# success
# message {'_id': ObjectId('5e26dac9d64bdc5152d0330c'), 'message': {'text': "ALERT:You've spent Rs.284.00 via Debit Card xx6504 at SWIGGY1368042 on 2019-02-06:13:24:56.Avl Bal Rs.389850.37.Not you?Call 18002586161.", 'date': 571132507253034944, 'guid': 'D9706BB3-3C81-63F9-751C-3E417C46ED34'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 284.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY1368042', 'datetime': datetime.datetime(2019, 2, 6, 13, 24, 56)}
#
#
# success
# message {'_id': ObjectId('5e26dac9d64bdc5152d0330e'), 'message': {'text': "ALERT:You've spent Rs.300.00 via Debit Card xx6504 at PAYTM1293914 on 2019-02-06:20:51:56.Avl Bal Rs.389550.37.Not you?Call 18002586161.", 'date': 571159322622766976, 'guid': 'CEB77B06-B467-23F6-65D6-BBE492BC67EC'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 300.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM1293914', 'datetime': datetime.datetime(2019, 2, 6, 20, 51, 56)}
#
#
# success
# message {'_id': ObjectId('5e26dacad64bdc5152d03312'), 'message': {'text': "ALERT:You've spent Rs.168.00 via Debit Card xx6504 at www.swiggy.in on 2019-02-07:09:57:49.Avl Bal Rs.389382.37.Not you?Call 18002586161.", 'date': 571206488621907968, 'guid': 'E91936BD-1CAD-1ABF-489E-83AB1EC53E6C'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 168.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.swiggy.in', 'datetime': datetime.datetime(2019, 2, 7, 9, 57, 49)}
#
#
# success
# message {'_id': ObjectId('5e26dacad64bdc5152d03315'), 'message': {'text': "ALERT:You've spent Rs.400.00 via Debit Card xx6504 at PAYTM on 2019-02-07:13:31:04.Avl Bal Rs.388982.37.Not you?Call 18002586161.", 'date': 571219277507795008, 'guid': '61885ADD-DD7B-5418-8FDA-B8AF97DE7FA8'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 400.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM', 'datetime': datetime.datetime(2019, 2, 7, 13, 31, 4)}
#
#
# success
# message {'_id': ObjectId('5e26dacbd64bdc5152d03317'), 'message': {'text': "ALERT:You've spent Rs.145.00 via Debit Card xx6504 at SWIGGY on 2019-02-07:14:03:19.Avl Bal Rs.388837.37.Not you?Call 18002586161.", 'date': 571221222873912000, 'guid': '42301E67-FAFC-E5F7-1BF6-C050E4F154E5'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 145.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 2, 7, 14, 3, 19)}
#
#
# success
# message {'_id': ObjectId('5e26dacbd64bdc5152d03318'), 'message': {'text': "ALERT:You've spent Rs.100.00 via Debit Card xx6504 at PAYTM1293914 on 2019-02-07:18:42:26.Avl Bal Rs.388737.37.Not you?Call 18002586161.", 'date': 571237949384428032, 'guid': '9E631B1A-8BCD-6F90-2EA9-953EECA35212'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 100.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM1293914', 'datetime': datetime.datetime(2019, 2, 7, 18, 42, 26)}
#
#
# success
# message {'_id': ObjectId('5e26dacbd64bdc5152d0331b'), 'message': {'text': "ALERT:You've spent Rs.2494.97 via Debit Card xx6504 at MYNTRA72883 on 2019-02-07:19:12:16.Avl Bal Rs.386242.40.Not you?Call 18002586161.", 'date': 571239739868952960, 'guid': 'B8A9258E-3286-0BD7-E7C5-8C3F9F35A80A'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 2494.97, 'payment_mode': 'Debit Card xx6504', 'merchant': 'MYNTRA72883', 'datetime': datetime.datetime(2019, 2, 7, 19, 12, 16)}
#
#
# success
# message {'_id': ObjectId('5e26daccd64bdc5152d0331d'), 'message': {'text': "ALERT:You've spent Rs.412.00 via Debit Card xx6504 at PAYTM1293914 on 2019-02-08:08:02:06.Avl Bal Rs.385846.15.Not you?Call 18002586161.", 'date': 571285931440989952, 'guid': '6D551B5F-0422-087E-6FA1-2E6C2851B019'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 412.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM1293914', 'datetime': datetime.datetime(2019, 2, 8, 8, 2, 6)}
#
#
# success
# message {'_id': ObjectId('5e26daccd64bdc5152d03320'), 'message': {'text': "ALERT:You've spent Rs.267.94 via Debit Card xx6504 at Zaak Epayment Services on 2019-02-08:19:04:59.Avl Bal Rs.385578.21.Not you?Call 18002586161.", 'date': 571325704961119040, 'guid': 'D042EE1E-7FBF-CE84-E43B-7BD1415A5500'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 267.94, 'payment_mode': 'Debit Card xx6504', 'merchant': 'Zaak Epayment Services', 'datetime': datetime.datetime(2019, 2, 8, 19, 4, 59)}
#
#
# success
# message {'_id': ObjectId('5e26dacdd64bdc5152d03322'), 'message': {'text': "ALERT:You've spent Rs.180.00 via Debit Card xx6504 at SWIGGY on 2019-02-09:09:13:41.Avl Bal Rs.385398.21.Not you?Call 18002586161.", 'date': 571376633440323008, 'guid': '6F0BD5AF-65CA-A5EC-4017-2B4E7AD9DCA3'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 180.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 2, 9, 9, 13, 41)}
#
#
# success
# message {'_id': ObjectId('5e26dacdd64bdc5152d03324'), 'message': {'text': "ALERT:You've spent Rs.795.00 via Debit Card xx6504 at PAYTM1293914 on 2019-02-09:13:25:20.Avl Bal Rs.384603.21.Not you?Call 18002586161.", 'date': 571391728296113984, 'guid': '45F93992-65A8-F295-F45C-3DDD2549FA21'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 795.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'PAYTM1293914', 'datetime': datetime.datetime(2019, 2, 9, 13, 25, 20)}
#
#
# success
# message {'_id': ObjectId('5e26dacdd64bdc5152d03328'), 'message': {'text': "ALERT:You've spent Rs.173.00 via Debit Card xx6504 at SWIGGY on 2019-02-10:12:04:37.Avl Bal Rs.382075.21.Not you?Call 18002586161.", 'date': 571473285499569088, 'guid': 'DF8DC652-22E5-4DC2-77AA-C398A2425FD0'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 173.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'SWIGGY', 'datetime': datetime.datetime(2019, 2, 10, 12, 4, 37)}
#
#
# success
# message {'_id': ObjectId('5e26daced64bdc5152d0332a'), 'message': {'text': "ALERT:You've spent Rs.1.00 via Debit Card xx6504 at GOOGLE *SERVICES on 2019-02-10:12:23:43.Avl Bal Rs.382074.21.Not you?Call 18002586161.", 'date': 571474433334224000, 'guid': '9A3AE06A-872B-4C9E-4EF2-78BF2BB814F1'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26daced64bdc5152d0332d'), 'message': {'text': "ALERT:You've spent Rs.1167.00 via Debit Card xx6504 at NEW FRUITLAND on 2019-02-10:16:47:38.Avl Bal Rs.380709.75.Not you?Call 18002586161.", 'date': 571490267499518976, 'guid': 'AFA43770-E35D-61AC-AE42-B80E0516766E'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1167.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'NEW FRUITLAND', 'datetime': datetime.datetime(2019, 2, 10, 16, 47, 38)}
#
#
# success
# message {'_id': ObjectId('5e26daced64bdc5152d0332e'), 'message': {'text': "ALERT:You've spent Rs.560.00 via Debit Card xx6504 at MAC FAST FOODS on 2019-02-10:17:29:52.Avl Bal Rs.380149.75.Not you?Call 18002586161.", 'date': 571492797807104960, 'guid': '4E375FEF-00BE-F44E-B4A7-EF0D3593320B'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 560.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'MAC FAST FOODS', 'datetime': datetime.datetime(2019, 2, 10, 17, 29, 52)}
# success
# message {'_id': ObjectId('5e26dacfd64bdc5152d0332f'), 'message': {'text': "ALERT:You've spent Rs.3392.00 via Debit Card xx6504 at LIFE STYLE. on 2019-02-10:18:11:25.Avl Bal Rs.376757.75.Not you?Call 18002586161.", 'date': 571495298269471040, 'guid': '5FB13548-9D29-EA85-0FC3-6C4FDD98F743'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 3392.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'LIFE STYLE.', 'datetime': datetime.datetime(2019, 2, 10, 18, 11, 25)}
#
#
# success
# message {'_id': ObjectId('5e26dacfd64bdc5152d03330'), 'message': {'text': "ALERT:You've spent Rs.1056.00 via Debit Card xx6504 at M K RETAIL on 2019-02-10:19:15:15.Avl Bal Rs.375701.75.Not you?Call 18002586161.", 'date': 571499122961856000, 'guid': 'B727E551-4E8E-587C-3DCC-B42798F325EF'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1056.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'M K RETAIL', 'datetime': datetime.datetime(2019, 2, 10, 19, 15, 15)}
#
#
# success
# message {'_id': ObjectId('5e26dacfd64bdc5152d03333'), 'message': {'text': "ALERT:You've spent Rs.1630.55 via Debit Card xx6504 at AMAZON SELLER on 2019-02-11:07:05:42.Avl Bal Rs.374071.20.Not you?Call 18002586161.", 'date': 571541748161314944, 'guid': 'E2B66398-6674-DF63-8E1C-2743EAF5FB76'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1630.55, 'payment_mode': 'Debit Card xx6504', 'merchant': 'AMAZON SELLER', 'datetime': datetime.datetime(2019, 2, 11, 7, 5, 42)}
#
#
# success
# message {'_id': ObjectId('5e26dad0d64bdc5152d03336'), 'message': {'text': "ALERT:You've spent Rs.137.00 via Debit Card xx6504 at www.dunzo.in on 2019-02-12:20:58:30.Avl Bal Rs.373934.20.Not you?Call 18002586161.", 'date': 571678120975574016, 'guid': '08EBEFB0-DB79-2DF3-053C-AABBA421D702'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 137.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'www.dunzo.in', 'datetime': datetime.datetime(2019, 2, 12, 20, 58, 30)}
#
#
# success
# message {'_id': ObjectId('5e26dad0d64bdc5152d03339'), 'message': {'text': "ALERT:You've spent Rs.1.00 via Debit Card xx6504 at GOOGLE CLOUD INDIA PVT on 2019-02-14:10:25:14.Avl Bal Rs.373933.20.Not you?Call 18002586161.", 'date': 571812929961720960, 'guid': 'B143A05C-F9DA-7743-CA6B-AD7C61ED8058'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1.0, 'payment_mode': 'Debit Card xx6504', 'merchant': 'GOOGLE CLOUD INDIA PVT', 'datetime': datetime.datetime(2019, 2, 14, 10, 25, 14)}
#
#
# success
# ...
#
#
# success
# message {'_id': ObjectId('5e26db5ad64bdc5152d0372f'), 'message': {'text': "ALERT:You've spent Rs.1427.00 via Debit Card xx1827 at ITSY BITSY on 2019-11-24:18:43:49.Avl Bal Rs.58983.25.Not you?Call 18002586161.", 'date': 596294036949133056, 'guid': 'F99CD023-2368-CC0B-607C-6D4FF509E836'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1427.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'ITSY BITSY', 'datetime': datetime.datetime(2019, 11, 24, 18, 43, 49)}
#
#
# success
# message {'_id': ObjectId('5e26db5cd64bdc5152d03740'), 'message': {'text': "ALERT:You've spent Rs.2183.50 via Debit Card xx1827 at HPCL HINDUSTAN PETROLE on 2019-11-25:18:00:14.Avl Bal Rs.62572.75.Not you?Call 18002586161.", 'date': 596377825415153920, 'guid': '45B443AD-45CC-9C77-D422-8D0DDD214F0D'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 2183.5, 'payment_mode': 'Debit Card xx1827', 'merchant': 'HPCL HINDUSTAN PETROLE', 'datetime': datetime.datetime(2019, 11, 25, 18, 0, 14)}
#
#
# success
# message {'_id': ObjectId('5e26db5cd64bdc5152d03748'), 'message': {'text': "ALERT:You've spent Rs.1234.00 via Debit Card xx1827 at SMALL BUS HOSPITALITY on 2019-11-26:15:01:56.Avl Bal Rs.47792.50.Not you?Call 18002586161.", 'date': 596453521893641984, 'guid': '1D86FAF9-9A32-0997-088C-5A49902ECA56'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1234.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'SMALL BUS HOSPITALITY', 'datetime': datetime.datetime(2019, 11, 26, 15, 1, 56)}
#
#
# success
# message {'_id': ObjectId('5e26db5dd64bdc5152d0374b'), 'message': {'text': "ALERT:You've spent Rs.1409.00 via Debit Card xx1827 at KOBE SIZZLERS on 2019-11-27:22:23:29.Avl Bal Rs.46288.75.Not you?Call 18002586161.", 'date': 596566417961403008, 'guid': 'DF754D0B-A0C7-31C2-16CD-6EC76BFB3C29'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1409.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'KOBE SIZZLERS', 'datetime': datetime.datetime(2019, 11, 27, 22, 23, 29)}
#
#
# success
# message {'_id': ObjectId('5e26db5ed64bdc5152d03750'), 'message': {'text': "ALERT:You've spent Rs.475.00 via Debit Card xx1827 at CAKEWALK on 2019-11-28:15:32:26.Avl Bal Rs.46324.75.Not you?Call 18002586161.", 'date': 596628160980291968, 'guid': 'D0222199-7A32-45F7-C3A2-5B3EBD0BD003'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 475.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'CAKEWALK', 'datetime': datetime.datetime(2019, 11, 28, 15, 32, 26)}
#
#
# success
# message {'_id': ObjectId('5e26db5ed64bdc5152d03757'), 'message': {'text': "ALERT:You've spent Rs.500.00 via Debit Card xx1827 at DR KRISHNA MURTHY R on 2019-11-29:15:36:10.Avl Bal Rs.45780.75.Not you?Call 18002586161.", 'date': 596714777643190016, 'guid': '575D0492-2FC6-A454-2CB7-CC9BEDD5AC65'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 500.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'DR KRISHNA MURTHY R', 'datetime': datetime.datetime(2019, 11, 29, 15, 36, 10)}
#
#
# success
# message {'_id': ObjectId('5e26db5fd64bdc5152d0375c'), 'message': {'text': "ALERT:You've spent Rs.1602.50 via Debit Card xx1827 at www.bigbasket. on 2019-11-29:20:29:51.Avl Bal Rs.44178.25.Not you?Call 18002586161.", 'date': 596732401054013056, 'guid': '18D43863-1E67-E83E-7BD4-AE5623EA20D5'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1602.5, 'payment_mode': 'Debit Card xx1827', 'merchant': 'www.bigbasket.', 'datetime': datetime.datetime(2019, 11, 29, 20, 29, 51)}
#
#
# success
# message {'_id': ObjectId('5e26db60d64bdc5152d03762'), 'message': {'text': "ALERT:You've spent Rs.175.00 via Debit Card xx1827 at AMAZON on 2019-11-30:14:54:55.Avl Bal Rs.16475.25.Not you?Call 18002586161.", 'date': 596798700118155008, 'guid': 'A9CAF8CE-3902-63DE-EB4A-D629D5D7E612'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 175.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'AMAZON', 'datetime': datetime.datetime(2019, 11, 30, 14, 54, 55)}
#
#
# success
# message {'_id': ObjectId('5e26db61d64bdc5152d0376a'), 'message': {'text': "ALERT:You've spent Rs.1500.00 via Debit Card xx1827 at PAYTM3024646 on 2019-12-02:13:18:13.Avl Bal Rs.11563.57.Not you?Call 18002586161.", 'date': 596965699776225024, 'guid': 'BB048039-3167-15A9-B021-DA47EF1C67D2'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1500.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'PAYTM3024646', 'datetime': datetime.datetime(2019, 12, 2, 13, 18, 13)}
#
#
# success
# message {'_id': ObjectId('5e26db61d64bdc5152d0376e'), 'message': {'text': "ALERT:You've spent Rs.605.00 via Debit Card xx1827 at NEW FRUITLAND on 2019-12-02:18:05:52.Avl Bal Rs.10958.57.Not you?Call 18002586161.", 'date': 596982964700343936, 'guid': 'E60D9F54-A498-7763-AB9B-93BA86AA5322'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 605.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'NEW FRUITLAND', 'datetime': datetime.datetime(2019, 12, 2, 18, 5, 52)}
# success
# message {'_id': ObjectId('5e26db62d64bdc5152d03775'), 'message': {'text': "ALERT:You've spent Rs.160.00 via Debit Card xx1827 at PVR LIMITED. on 2019-12-03:14:29:06.Avl Bal Rs.10065.25.Not you?Call 18002586161.", 'date': 597056357226532992, 'guid': '5AC8F51E-A876-061E-1B3B-7899AC76DEB9'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 160.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'PVR LIMITED.', 'datetime': datetime.datetime(2019, 12, 3, 14, 29, 6)}
#
#
# success
# message {'_id': ObjectId('5e26db62d64bdc5152d03776'), 'message': {'text': "ALERT:You've spent Rs.600.00 via Debit Card xx1827 at PVR LIMITED. on 2019-12-03:14:33:28.Avl Bal Rs.9465.25.Not you?Call 18002586161.", 'date': 597056615442608000, 'guid': 'BBC9779E-44A1-3FB3-CE62-9BF73B29366D'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 600.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'PVR LIMITED.', 'datetime': datetime.datetime(2019, 12, 3, 14, 33, 28)}
#
#
# success
# message {'_id': ObjectId('5e26db62d64bdc5152d03777'), 'message': {'text': "ALERT:You've spent Rs.394.00 via Debit Card xx1827 at MARKET 99 , on 2019-12-03:17:18:30.Avl Bal Rs.9071.25.Not you?Call 18002586161.", 'date': 597066520271515008, 'guid': 'EB024C06-E43B-F657-DDBA-72E696CCD99D'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db62d64bdc5152d03778'), 'message': {'text': "ALERT:You've spent Rs.209.00 via Debit Card xx1827 at OM BOOK SHOP, on 2019-12-03:17:57:51.Avl Bal Rs.8862.25.Not you?Call 18002586161.", 'date': 597068881681692928, 'guid': '836AB29C-ABCA-C7C4-D543-878D5693633E'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db62d64bdc5152d03779'), 'message': {'text': "ALERT:You've spent Rs.2739.00 via Debit Card xx1827 at TABLEZ & TOYS PVT LTD on 2019-12-03:18:27:04.Avl Bal Rs.6123.25.Not you?Call 18002586161.", 'date': 597070628875224960, 'guid': 'B184D311-BFC8-0597-9CB2-CE990EA2B7F7'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {}
#
#
# message {'_id': ObjectId('5e26db63d64bdc5152d0377a'), 'message': {'text': "ALERT:You've spent Rs.145.00 via Debit Card xx1827 at BON APPETIT FOOD AND B on 2019-12-03:18:34:14.Avl Bal Rs.5978.25.Not you?Call 18002586161.", 'date': 597071065050153984, 'guid': 'CEA0C2E9-FCB1-67C8-D7CA-951F255D3A13'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 145.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'BON APPETIT FOOD AND B', 'datetime': datetime.datetime(2019, 12, 3, 18, 34, 14)}
#
#
# success
# message {'_id': ObjectId('5e26db63d64bdc5152d0377b'), 'message': {'text': "ALERT:You've spent Rs.368.00 via Debit Card xx1827 at HUNAN EXPRESS on 2019-12-03:18:43:34.Avl Bal Rs.5610.25.Not you?Call 18002586161.", 'date': 597071625931307008, 'guid': '031FAA31-B67E-D4E0-32A4-CAB169C17852'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 368.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'HUNAN EXPRESS', 'datetime': datetime.datetime(2019, 12, 3, 18, 43, 34)}
#
#
# success
# message {'_id': ObjectId('5e26db67d64bdc5152d037a1'), 'message': {'text': "ALERT:You've spent Rs.636.00 via Debit Card xx1827 at www.bigbasket. on 2019-12-09:22:15:56.Avl Bal Rs.18679.25.Not you?Call 18002586161.", 'date': 597602764862771072, 'guid': '9986B1D4-9628-FB7E-1BB3-54AE8BC66095'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 636.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'www.bigbasket.', 'datetime': datetime.datetime(2019, 12, 9, 22, 15, 56)}
#
#
# success
# message {'_id': ObjectId('5e26db6ad64bdc5152d037b8'), 'message': {'text': "ALERT:You've spent Rs.1337.79 via Debit Card xx1827 at www.bigbasket. on 2019-12-13:22:23:18.Avl Bal Rs.8296.46.Not you?Call 18002586161.", 'date': 597948819769585920, 'guid': 'A3E515FC-574C-D4C4-590C-EF63481583B5'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1337.79, 'payment_mode': 'Debit Card xx1827', 'merchant': 'www.bigbasket.', 'datetime': datetime.datetime(2019, 12, 13, 22, 23, 18)}
#
#
# success
# message {'_id': ObjectId('5e26db6ad64bdc5152d037bd'), 'message': {'text': "ALERT:You've spent Rs.99.00 via Debit Card xx1827 at AMAZON on 2019-12-14:11:43:05.Avl Bal Rs.23197.46.Not you?Call 18002586161.", 'date': 597996793574738048, 'guid': '2E42ECF2-519F-3F75-DE3C-6C5FD1633F9B'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 99.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'AMAZON', 'datetime': datetime.datetime(2019, 12, 14, 11, 43, 5)}
#
#
# success
# message {'_id': ObjectId('5e26db6ed64bdc5152d037dc'), 'message': {'text': "ALERT:You've spent Rs.700.00 via Debit Card xx1827 at SBIETC on 2019-12-20:22:31:08.Avl Bal Rs.1121075.44.Not you?Call 18002586161.", 'date': 598554081227996928, 'guid': 'B2EDB5B8-5C42-BC80-1173-5147A3616E1B'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 700.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'SBIETC', 'datetime': datetime.datetime(2019, 12, 20, 22, 31, 8)}
#
#
# success
# message {'_id': ObjectId('5e26db73d64bdc5152d03806'), 'message': {'text': "ALERT:You've spent Rs.4135.40 via Debit Card xx1827 at IRCTC11779 on 2019-12-28:17:13:22.Avl Bal Rs.502907.04.Not you?Call 18002586161.", 'date': 599226211050910976, 'guid': 'F72E88EF-DD96-B9D5-0CDF-4B6F535FE30F'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 4135.4, 'payment_mode': 'Debit Card xx1827', 'merchant': 'IRCTC11779', 'datetime': datetime.datetime(2019, 12, 28, 17, 13, 22)}
#
#
# success
# message {'_id': ObjectId('5e26db73d64bdc5152d03808'), 'message': {'text': "ALERT:You've spent Rs.4135.40 via Debit Card xx1827 at IRCTC11779 on 2019-12-28:17:18:05.Avl Bal Rs.498771.64.Not you?Call 18002586161.", 'date': 599226490155688064, 'guid': 'D87B233D-5F5C-68CC-3C53-4FB37C095E4F'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 4135.4, 'payment_mode': 'Debit Card xx1827', 'merchant': 'IRCTC11779', 'datetime': datetime.datetime(2019, 12, 28, 17, 18, 5)}
#
#
# success
# message {'_id': ObjectId('5e26db77d64bdc5152d03826'), 'message': {'text': "ALERT:You've spent Rs.600.00 via Debit Card xx1827 at SBIETC on 2020-01-03:10:47:28.Avl Bal Rs.641397.64.Not you?Call 18002586161.", 'date': 599721460718148992, 'guid': '72A2D1FC-B669-C7EF-7E07-87842F4861CA'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 600.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'SBIETC', 'datetime': datetime.datetime(2020, 1, 3, 10, 47, 28)}
#
#
# success
# message {'_id': ObjectId('5e26db79d64bdc5152d03834'), 'message': {'text': "ALERT:You've spent Rs.665.00 via Debit Card xx1827 at AMAZON on 2020-01-04:14:47:23.Avl Bal Rs.640103.64.Not you?Call 18002586161.", 'date': 599822252118995968, 'guid': '1A933F86-1285-76F2-1ED6-3A0C79312667'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 665.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'AMAZON', 'datetime': datetime.datetime(2020, 1, 4, 14, 47, 23)}
#
#
# success
# message {'_id': ObjectId('5e26db79d64bdc5152d03836'), 'message': {'text': "ALERT:You've spent Rs.35.00 via Debit Card xx1827 at AMAZON on 2020-01-04:14:49:46.Avl Bal Rs.640068.64.Not you?Call 18002586161.", 'date': 599822398032150016, 'guid': '5A8A777D-9250-D4C8-B718-CCD0E101EB24'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 35.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'AMAZON', 'datetime': datetime.datetime(2020, 1, 4, 14, 49, 46)}
#
#
# success
# message {'_id': ObjectId('5e26db7bd64bdc5152d0384d'), 'message': {'text': "ALERT:You've spent Rs.993.00 via Debit Card xx1827 at www.bigbasket. on 2020-01-05:19:03:01.Avl Bal Rs.639075.64.Not you?Call 18002586161.", 'date': 599923987727352960, 'guid': '7DA4051D-9F22-5171-2D23-4C4A5949C196'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 993.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'www.bigbasket.', 'datetime': datetime.datetime(2020, 1, 5, 19, 3, 1)}
#
#
# success
# message {'_id': ObjectId('5e26db7fd64bdc5152d0386b'), 'message': {'text': "ALERT:You've spent Rs.334.20 via Debit Card xx1827 at AMAZON on 2020-01-09:16:14:22.Avl Bal Rs.619741.44.Not you?Call 18002586161.", 'date': 600259472615838976, 'guid': '3A6585CE-9AB5-88D4-7B56-5FFCAA63C724'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 334.2, 'payment_mode': 'Debit Card xx1827', 'merchant': 'AMAZON', 'datetime': datetime.datetime(2020, 1, 9, 16, 14, 22)}
#
#
# success
# message {'_id': ObjectId('5e26db7fd64bdc5152d0386e'), 'message': {'text': "ALERT:You've spent Rs.595.00 via Debit Card xx1827 at AMAZON on 2020-01-09:18:52:14.Avl Bal Rs.619146.44.Not you?Call 18002586161.", 'date': 600268944312206976, 'guid': '77F13414-883A-B62C-7321-83A49A68B9F4'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 595.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'AMAZON', 'datetime': datetime.datetime(2020, 1, 9, 18, 52, 14)}
# success
# message {'_id': ObjectId('5e26db85d64bdc5152d0389e'), 'message': {'text': "ALERT:You've spent Rs.12405.00 via Debit Card xx1827 at STAR HEALTH AND ALLIED on 2020-01-17:12:30:39.Avl Bal Rs.605656.54.Not you?Call 18002586161.", 'date': 600937242825741056, 'guid': '792F2F17-B01D-26D5-159B-66CF05DC9035'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 12405.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'STAR HEALTH AND ALLIED', 'datetime': datetime.datetime(2020, 1, 17, 12, 30, 39)}
#
#
# success
# message {'_id': ObjectId('5e3a782e85ce1ed04ce1b6a4'), 'message': {'text': "ALERT:You've spent Rs.1000.00 via Debit Card xx1827 at PAYTM3852398 on 2020-01-29:14:16:01.Avl Bal Rs.592265.31.Not you?Call 18002586161.", 'date': 601980376311264000, 'guid': '3F715858-E057-A50F-992E-8D2C53CB24C6'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 1000.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'PAYTM3852398', 'datetime': datetime.datetime(2020, 1, 29, 14, 16, 1)}
#
#
# success
# message {'_id': ObjectId('5e3a783385ce1ed04ce1b6ca'), 'message': {'text': "ALERT:You've spent Rs.199.00 via Debit Card xx1827 at NETFLIX ENTERTAINMENT on 2020-02-03:19:28:14.Avl Bal Rs.560066.31.Not you?Call 18002586161.", 'date': 602431103646162048, 'guid': '6460C153-1551-DE6A-7FC6-82C15FFAB772'}, 'status': {'analysis_done': True}, 'transaction': {}}
# analysis {'expense_amount': 199.0, 'payment_mode': 'Debit Card xx1827', 'merchant': 'NETFLIX ENTERTAINMENT', 'datetime': datetime.datetime(2020, 2, 3, 19, 28, 14)}
#
#
# success

# %%
year = 2020
month = 2

next_month = 1 if month == 12 else month + 1
next_year = year + 1 if month == 12 else year

monthly = list(enumerate(collection.find({'status': {'analysis_done': True},
                 'transaction.datetime' : {
                     '$gte': datetime.datetime(year,month,1), '$lt': datetime.datetime(next_year,next_month,1)}
                  }, {'transaction': 1})))

monthly_transactions = list(map(extract_transactions, monthly))

# %%
display(HTML(tabulate.tabulate(monthly_transactions, tablefmt='html')))
# Out:
# <table>
# <tbody>
# <tr><td style="text-align: right;">  500   </td><td>CREDIT Card xx3690</td><td>PAYTM                       </td><td>2020-02-02 20:44:58</td><td>272486.89               </td><td style="text-align: right;">27513.1</td><td>5e3a783285ce1ed04ce1b6c3</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  465.5 </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510             </td><td>2020-02-02 20:42:47</td><td>272986.5                </td><td style="text-align: right;">27013.5</td><td>5e3a783285ce1ed04ce1b6c4</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  465.5 </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510 in BANGALORE</td><td>2020-02-02 20:42:48</td><td>5e3a783285ce1ed04ce1b6c5</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  400   </td><td>CREDIT Card xx3690</td><td>PAYTM3852398                </td><td>2020-02-02 20:49:59</td><td>272086.89               </td><td style="text-align: right;">27913.1</td><td>5e3a783285ce1ed04ce1b6c6</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  199   </td><td>Debit Card xx1827 </td><td>NETFLIX ENTERTAINMENT       </td><td>2020-02-03 19:28:14</td><td>5e3a783385ce1ed04ce1b6ca</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  500   </td><td>CREDIT Card xx3690</td><td>PAYTM3852398                </td><td>2020-02-03 23:14:18</td><td>271586.0                </td><td style="text-align: right;">28414  </td><td>5e3a783385ce1ed04ce1b6cb</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;"> 1514.37</td><td>CREDIT Card xx3690</td><td>www.bigbasket.              </td><td>2020-02-06 22:08:21</td><td>270071.63               </td><td style="text-align: right;">29928.4</td><td>5e3e5b35dd2322b0ad5cccfa</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  588   </td><td>CREDIT Card xx3690</td><td>MYNTRA72883                 </td><td>2020-02-06 22:50:28</td><td>269484.52               </td><td style="text-align: right;">30515.5</td><td>5e3e5b35dd2322b0ad5cccfc</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  606   </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510             </td><td>2020-02-07 10:39:43</td><td>268878.0                </td><td style="text-align: right;">31122  </td><td>5e3e5b35dd2322b0ad5cccff</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  606   </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510 in BANGALORE</td><td>2020-02-07 10:39:44</td><td>5e3e5b35dd2322b0ad5ccd00</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;"> 1204.35</td><td>CREDIT Card xx3690</td><td>AJIO                        </td><td>2020-02-07 11:22:23</td><td>267674.17               </td><td style="text-align: right;">32325.8</td><td>5e3e5b36dd2322b0ad5ccd02</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  212   </td><td>CREDIT Card xx3690</td><td>SWIGGY                      </td><td>2020-02-10 10:09:35</td><td>267462.0                </td><td style="text-align: right;">32538  </td><td>5e4255e6112fba20f1b03b67</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  200   </td><td>CREDIT Card xx3690</td><td>SWIGGY                      </td><td>2020-02-10 20:54:05</td><td>267262.17               </td><td style="text-align: right;">32737.8</td><td>5e4255e6112fba20f1b03b6a</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  404   </td><td>CREDIT Card xx3690</td><td>SWIGGY                      </td><td>2020-02-10 22:37:50</td><td>266858.17               </td><td style="text-align: right;">33141.8</td><td>5e4255e7112fba20f1b03b6c</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  610   </td><td>CREDIT Card xx3690</td><td>..MATTO COFFEA_             </td><td>2020-02-11 16:54:42</td><td>266248.0                </td><td style="text-align: right;">33752  </td><td>5e46a6ab435652b77cb5c01d</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  757   </td><td>CREDIT Card xx3690</td><td>NEW FRUIT LAND              </td><td>2020-02-13 17:53:10</td><td>265491.0                </td><td style="text-align: right;">34509  </td><td>5e46a6ab435652b77cb5c024</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;"> 1700   </td><td>CREDIT Card xx3690</td><td>HINDUSTAN PETROLEUM CO      </td><td>2020-02-13 18:08:16</td><td>263791.17               </td><td style="text-align: right;">36208.8</td><td>5e46a6ab435652b77cb5c025</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;"> 1249.56</td><td>CREDIT Card xx3690</td><td>PAYTM                       </td><td>2020-02-14 14:44:35</td><td>262541.44               </td><td style="text-align: right;">37458.6</td><td>5e48f14c4dd52adb3fc0c9e8</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;"> 2198.39</td><td>CREDIT Card xx3690</td><td>www.bigbasket.              </td><td>2020-02-14 16:34:16</td><td>260343.22               </td><td style="text-align: right;">39656.8</td><td>5e48f14c4dd52adb3fc0c9ea</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;"> 1350   </td><td>CREDIT Card xx3690</td><td>Instapay BBPS               </td><td>2020-02-14 20:46:27</td><td>258993.22               </td><td style="text-align: right;">41006.8</td><td>5e48f14c4dd52adb3fc0c9eb</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  869.4 </td><td>CREDIT Card xx3690</td><td>www.ebharatgas.com          </td><td>2020-02-14 21:09:34</td><td>258123.82               </td><td style="text-align: right;">41876.2</td><td>utility                 </td><td>gas      </td><td>5e48f14c4dd52adb3fc0c9ee</td></tr>
# <tr><td style="text-align: right;">16679   </td><td>CREDIT Card xx3690</td><td>LIC                         </td><td>2020-02-15 11:39:04</td><td>241440.96               </td><td style="text-align: right;">58559  </td><td>5e48f14d4dd52adb3fc0c9f1</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  428   </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510 in BANGALORE</td><td>2020-02-15 16:46:51</td><td>5e48f14d4dd52adb3fc0c9f7</td><td style="text-align: right;">       </td><td>                        </td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  428   </td><td>CREDIT Card xx3690</td><td>FRESHTOH3631510             </td><td>2020-02-15 16:46:50</td><td>241013.75               </td><td style="text-align: right;">58986.2</td><td>5e48f14d4dd52adb3fc0c9f8</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  500   </td><td>CREDIT Card xx3690</td><td>PAYTM                       </td><td>2020-02-15 16:48:57</td><td>240513.75               </td><td style="text-align: right;">59486.2</td><td>5e48f14d4dd52adb3fc0c9fa</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: right;">  599   </td><td>CREDIT Card xx3690</td><td>SWIGGY                      </td><td>2020-02-15 19:04:46</td><td>239914.75               </td><td style="text-align: right;">60085.2</td><td>5e48f14d4dd52adb3fc0c9ff</td><td>         </td><td>                        </td></tr>
# <tr><td style="text-align: r

# %%
add_category_info(collection, '5e497fb75bc90c80c1c82a81', category='purchase', sub_category='toys')
# Out:
# success

# %%
# add_comment
# set_action(Debit/Credit/Transfer)
